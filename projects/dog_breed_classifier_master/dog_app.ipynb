# %% [markdown]
# ## Convolutional Neural Networks
#
# ## Project: Write an Algorithm for a Dog Identification App
#
# ---
#
# In this notebook, some template code has already been provided for you, and you will need to implement additional functionality to successfully complete this project. You will not need to modify the included code beyond what is requested. Sections that begin with **'(IMPLEMENTATION)'** in the header indicate that the following block of code will require additional functionality which you must provide. Instructions will be provided for each section, and the specifics of the implementation are marked in the code block with a 'TODO' statement. Please be sure to read the instructions carefully!
#
# > **Note**: Once you have completed all of the code implementations, you need to finalize your work by exporting the iPython Notebook as an HTML document. Before exporting the notebook to html, all of the code cells need to have been run so that reviewers can see the final implementation and output. You can then export the notebook by using the menu above and navigating to  \n",
#     "**File -> Download as -> HTML (.html)**. Include the finished document along with this notebook as your submission.
#
# In addition to implementing code, there will be questions that you must answer which relate to the project and your implementation. Each section where you will answer a question is preceded by a **'Question X'** header. Carefully read each question and provide thorough answers in the following text boxes that begin with **'Answer:'**. Your project submission will be evaluated based on your answers to each of the questions and the implementation you provide.
#
# >**Note:** Code and Markdown cells can be executed using the **Shift + Enter** keyboard shortcut.  Markdown cells can be edited by double-clicking the cell to enter edit mode.
#
# The rubric contains _optional_ "Stand Out Suggestions" for enhancing the project beyond the minimum requirements. If you decide to pursue the "Stand Out Suggestions", you should include the code in this IPython notebook.
#
#
#
# ---
# ### Why We're Here
#
# In this notebook, you will make the first steps towards developing an algorithm that could be used as part of a mobile or web app.  At the end of this project, your code will accept any user-supplied image as input.  If a dog is detected in the image, it will provide an estimate of the dog's breed.  If a human is detected, it will provide an estimate of the dog breed that is most resembling.  The image below displays potential sample output of your finished project (... but we expect that each student's algorithm will behave differently!).
#
# ![Sample Dog Output](images/sample_dog_output.png)
#
# In this real-world setting, you will need to piece together a series of models to perform different tasks; for instance, the algorithm that detects humans in an image will be different from the CNN that infers dog breed.  There are many points of possible failure, and no perfect algorithm exists.  Your imperfect solution will nonetheless create a fun user experience!
#
# ### The Road Ahead
#
# We break the notebook into separate steps.  Feel free to use the links below to navigate the notebook.
#
# * [Step 0](#step0): Import Datasets
# * [Step 1](#step1): Detect Humans
# * [Step 2](#step2): Detect Dogs
# * [Step 3](#step3): Create a CNN to Classify Dog Breeds (from Scratch)
# * [Step 4](#step4): Use a CNN to Classify Dog Breeds (using Transfer Learning)
# * [Step 5](#step5): Create a CNN to Classify Dog Breeds (using Transfer Learning)
# * [Step 6](#step6): Write your Algorithm
# * [Step 7](#step7): Test Your Algorithm
#
# ---
# <a id='step0'></a>
# ## Step 0: Import Datasets
#
# ### Import Dog Dataset
#
# In the code cell below, we import a dataset of dog images.  We populate a few variables through the use of the `load_files` function from the scikit-learn library:
# - `train_files`, `valid_files`, `test_files` - numpy arrays containing file paths to images
# - `train_targets`, `valid_targets`, `test_targets` - numpy arrays containing onehot-encoded classification labels
# - `dog_names` - list of string-valued dog breed names for translating labels

# %%
from sklearn.datasets import load_files       
from keras.utils import np_utils
import numpy as np
from glob import glob

# define function to load train, test, and validation datasets
def load_dataset(path):
    data = load_files(path)
    dog_files = np.array(data['filenames'])
    dog_targets = np_utils.to_categorical(np.array(data['target']), 133)
    return dog_files, dog_targets

# load train, test, and validation datasets
train_files, train_targets = load_dataset(r'D:\Machine_Learning\Udacity Courses\Machine Learning Engineer ND\machine-learning-master\projects\dog_breed_classifier_master\data\dogImages\train')
valid_files, valid_targets = load_dataset(r'D:\Machine_Learning\Udacity Courses\Machine Learning Engineer ND\machine-learning-master\projects\dog_breed_classifier_master\data\dogImages\valid')
test_files, test_targets = load_dataset(r'D:\Machine_Learning\Udacity Courses\Machine Learning Engineer ND\machine-learning-master\projects\dog_breed_classifier_master\data\dogImages\test')

# load list of dog names
dog_names = [item[20:-1] for item in sorted(glob("/data/dog_images/train/*/"))]

# print statistics about the dataset
print('There are %d total dog categories.' % len(dog_names))
print('There are %s total dog images.\n' % len(np.hstack([train_files, valid_files, test_files])))
print('There are %d training dog images.' % len(train_files))
print('There are %d validation dog images.' % len(valid_files))
print('There are %d test dog images.'% len(test_files))
# Out:
# Using TensorFlow backend.
# There are 0 total dog categories.
# There are 8351 total dog images.
#
# There are 6680 training dog images.
# There are 835 validation dog images.
# There are 836 test dog images.

# %% [markdown]
# ### Import Human Dataset
#
# In the code cell below, we import a dataset of human images, where the file paths are stored in the numpy array `human_files`.

# %%
import random
random.seed(8675309)

# load filenames in shuffled human dataset
human_files = np.array(glob(r"D:\Machine_Learning\Udacity Courses\Machine Learning Engineer ND\machine-learning-master\projects\dog_breed_classifier_master\data\lfw/*/*"))
random.shuffle(human_files)

# print statistics about the dataset
print('There are %d total human images.' % len(human_files))
# Out:
# There are 13233 total human images.

# %% [markdown]
# ---
# <a id='step1'></a>
# ## Step 1: Detect Humans
#
# We use OpenCV's implementation of [Haar feature-based cascade classifiers](http://docs.opencv.org/trunk/d7/d8b/tutorial_py_face_detection.html) to detect human faces in images.  OpenCV provides many pre-trained face detectors, stored as XML files on [github](https://github.com/opencv/opencv/tree/master/data/haarcascades).  We have downloaded one of these detectors and stored it in the `haarcascades` directory.
#
# In the next code cell, we demonstrate how to use this detector to find human faces in a sample image.

# %%
import cv2                
import matplotlib.pyplot as plt                        
# %matplotlib inline                               

# extract pre-trained face detector
face_cascade = cv2.CascadeClassifier('haarcascades/haarcascade_frontalface_alt.xml')

# load color (BGR) image
img = cv2.imread(human_files[3])
# convert BGR image to grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# find faces in image
faces = face_cascade.detectMultiScale(gray)

# print number of faces detected in the image
print('Number of faces detected:', len(faces))

# get bounding box for each detected face
for (x,y,w,h) in faces:
    # add bounding box to color image
    cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    
# convert BGR image to RGB for plotting
cv_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# display the image, along with bounding box
plt.imshow(cv_rgb)
plt.show()
# Out:
# Number of faces detected: 1

# %% [markdown]
# Before using any of the face detectors, it is standard procedure to convert the images to grayscale.  The `detectMultiScale` function executes the classifier stored in `face_cascade` and takes the grayscale image as a parameter.
#
# In the above code, `faces` is a numpy array of detected faces, where each row corresponds to a detected face.  Each detected face is a 1D array with four entries that specifies the bounding box of the detected face.  The first two entries in the array (extracted in the above code as `x` and `y`) specify the horizontal and vertical positions of the top left corner of the bounding box.  The last two entries in the array (extracted here as `w` and `h`) specify the width and height of the box.
#
# ### Write a Human Face Detector
#
# We can use this procedure to write a function that returns `True` if a human face is detected in an image and `False` otherwise.  This function, aptly named `face_detector`, takes a string-valued file path to an image as input and appears in the code block below.

# %%
# returns "True" if face is detected in image stored at img_path
def face_detector(img_path):
    img = cv2.imread(img_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray)
    return len(faces) > 0

# %% [markdown]
# ### (IMPLEMENTATION) Assess the Human Face Detector
#
# __Question 1:__ Use the code cell below to test the performance of the `face_detector` function.
# - What percentage of the first 100 images in `human_files` have a detected human face?
# - What percentage of the first 100 images in `dog_files` have a detected human face?
#
# Ideally, we would like 100% of human images with a detected face and 0% of dog images with a detected face.  You will see that our algorithm falls short of this goal, but still gives acceptable performance.  We extract the file paths for the first 100 images from each of the datasets and store them in the numpy arrays `human_files_short` and `dog_files_short`.
#
# __Answer:__

# %%
human_files_short = human_files[:100]
dog_files_short = train_files[:100]
# Do NOT modify the code above this line.

## TODO: Test the performance of the face_detector algorithm 
## on the images in human_files_short and dog_files_short.

def detector_performance(detector, file):
    faces = 0
    for image in file:
        if detector(image):
            faces +=1
    if detector == face_detector:
        print('There were {}% of human faces detected'.format(faces))
    else:
        print('There were {}% of dog faces detected'.format(faces))
        
detector_performance(face_detector, human_files_short)
detector_performance(face_detector, dog_files_short)
# Out:
# There were 99% of human faces detected
# There were 12% of human faces detected

# %% [markdown]
# __Question 2:__ This algorithmic choice necessitates that we communicate to the user that we accept human images only when they provide a clear view of a face (otherwise, we risk having unneccessarily frustrated users!). In your opinion, is this a reasonable expectation to pose on the user? If not, can you think of a way to detect humans in images that does not necessitate an image with a clearly presented face?
#
# __Answer:__
#
# We suggest the face detector from OpenCV as a potential way to detect human images in your algorithm, but you are free to explore other approaches, especially approaches that make use of deep learning :).  Please use the code cell below to design and test your own face detection algorithm.  If you decide to pursue this _optional_ task, report performance on each of the datasets.

# %%
## (Optional) TODO: Report the performance of another  
## face detection algorithm on the LFW dataset
### Feel free to use as many code cells as needed.

# %% [markdown]
# ---
# <a id='step2'></a>
# ## Step 2: Detect Dogs
#
# In this section, we use a pre-trained [ResNet-50](http://ethereon.github.io/netscope/#/gist/db945b393d40bfa26006) model to detect dogs in images.  Our first line of code downloads the ResNet-50 model, along with weights that have been trained on [ImageNet](http://www.image-net.org/), a very large, very popular dataset used for image classification and other vision tasks.  ImageNet contains over 10 million URLs, each linking to an image containing an object from one of [1000 categories](https://gist.github.com/yrevar/942d3a0ac09ec9e5eb3a).  Given an image, this pre-trained ResNet-50 model returns a prediction (derived from the available categories in ImageNet) for the object that is contained in the image.

# %%
from keras.applications.resnet50 import ResNet50

# define ResNet50 model
ResNet50_model = ResNet50(weights='imagenet')

# %% [markdown]
# ### Pre-process the Data
#
# When using TensorFlow as backend, Keras CNNs require a 4D array (which we'll also refer to as a 4D tensor) as input, with shape
#
# $$
# (\text{nb_samples}, \text{rows}, \text{columns}, \text{channels}),
# $$
#
# where `nb_samples` corresponds to the total number of images (or samples), and `rows`, `columns`, and `channels` correspond to the number of rows, columns, and channels for each image, respectively.
#
# The `path_to_tensor` function below takes a string-valued file path to a color image as input and returns a 4D tensor suitable for supplying to a Keras CNN.  The function first loads the image and resizes it to a square image that is $224 \times 224$ pixels.  Next, the image is converted to an array, which is then resized to a 4D tensor.  In this case, since we are working with color images, each image has three channels.  Likewise, since we are processing a single image (or sample), the returned tensor will always have shape
#
# $$
# (1, 224, 224, 3).
# $$
#
# The `paths_to_tensor` function takes a numpy array of string-valued image paths as input and returns a 4D tensor with shape
#
# $$
# (\text{nb_samples}, 224, 224, 3).
# $$
#
# Here, `nb_samples` is the number of samples, or number of images, in the supplied array of image paths.  It is best to think of `nb_samples` as the number of 3D tensors (where each 3D tensor corresponds to a different image) in your dataset!

# %%
from keras.preprocessing import image                  
from tqdm import tqdm

def path_to_tensor(img_path):
    # loads RGB image as PIL.Image.Image type
    img = image.load_img(img_path, target_size=(224, 224))
    # convert PIL.Image.Image type to 3D tensor with shape (224, 224, 3)
    x = image.img_to_array(img)
    # convert 3D tensor to 4D tensor with shape (1, 224, 224, 3) and return 4D tensor
    return np.expand_dims(x, axis=0)

def paths_to_tensor(img_paths):
    list_of_tensors = [path_to_tensor(img_path) for img_path in tqdm(img_paths)]
    return np.vstack(list_of_tensors)

# %% [markdown]
# ### Making Predictions with ResNet-50
#
# Getting the 4D tensor ready for ResNet-50, and for any other pre-trained model in Keras, requires some additional processing.  First, the RGB image is converted to BGR by reordering the channels.  All pre-trained models have the additional normalization step that the mean pixel (expressed in RGB as $[103.939, 116.779, 123.68]$ and calculated from all pixels in all images in ImageNet) must be subtracted from every pixel in each image.  This is implemented in the imported function `preprocess_input`.  If you're curious, you can check the code for `preprocess_input` [here](https://github.com/fchollet/keras/blob/master/keras/applications/imagenet_utils.py).
#
# Now that we have a way to format our image for supplying to ResNet-50, we are now ready to use the model to extract the predictions.  This is accomplished with the `predict` method, which returns an array whose $i$-th entry is the model's predicted probability that the image belongs to the $i$-th ImageNet category.  This is implemented in the `ResNet50_predict_labels` function below.
#
# By taking the argmax of the predicted probability vector, we obtain an integer corresponding to the model's predicted object class, which we can identify with an object category through the use of this [dictionary](https://gist.github.com/yrevar/942d3a0ac09ec9e5eb3a).

# %%
from keras.applications.resnet50 import preprocess_input, decode_predictions

def ResNet50_predict_labels(img_path):
    # returns prediction vector for image located at img_path
    img = preprocess_input(path_to_tensor(img_path))
    return np.argmax(ResNet50_model.predict(img))

# %% [markdown]
# ### Write a Dog Detector
#
# While looking at the [dictionary](https://gist.github.com/yrevar/942d3a0ac09ec9e5eb3a), you will notice that the categories corresponding to dogs appear in an uninterrupted sequence and correspond to dictionary keys 151-268, inclusive, to include all categories from `'Chihuahua'` to `'Mexican hairless'`.  Thus, in order to check to see if an image is predicted to contain a dog by the pre-trained ResNet-50 model, we need only check if the `ResNet50_predict_labels` function above returns a value between 151 and 268 (inclusive).
#
# We use these ideas to complete the `dog_detector` function below, which returns `True` if a dog is detected in an image (and `False` if not).

# %%
### returns "True" if a dog is detected in the image stored at img_path
def dog_detector(img_path):
    prediction = ResNet50_predict_labels(img_path)
    return ((prediction <= 268) & (prediction >= 151))

# %% [markdown]
# ### (IMPLEMENTATION) Assess the Dog Detector
#
# __Question 3:__ Use the code cell below to test the performance of your `dog_detector` function.
# - What percentage of the images in `human_files_short` have a detected dog?
# - What percentage of the images in `dog_files_short` have a detected dog?
#
# __Answer:__

# %%
### TODO: Test the performance of the dog_detector function
### on the images in human_files_short and dog_files_short.

detector_performance(face_detector, human_files_short)
detector_performance(dog_detector, dog_files_short)
# Out:
# There were 99% of human faces detected
# There were 100% of dog faces detected

# %% [markdown]
# ---
# <a id='step3'></a>
# ## Step 3: Create a CNN to Classify Dog Breeds (from Scratch)
#
# Now that we have functions for detecting humans and dogs in images, we need a way to predict breed from images.  In this step, you will create a CNN that classifies dog breeds.  You must create your CNN _from scratch_ (so, you can't use transfer learning _yet_!), and you must attain a test accuracy of at least 1%.  In Step 5 of this notebook, you will have the opportunity to use transfer learning to create a CNN that attains greatly improved accuracy.
#
# Be careful with adding too many trainable layers!  More parameters means longer training, which means you are more likely to need a GPU to accelerate the training process.  Thankfully, Keras provides a handy estimate of the time that each epoch is likely to take; you can extrapolate this estimate to figure out how long it will take for your algorithm to train.
#
# We mention that the task of assigning breed to dogs from images is considered exceptionally challenging.  To see why, consider that *even a human* would have great difficulty in distinguishing between a Brittany and a Welsh Springer Spaniel.
#
# Brittany | Welsh Springer Spaniel
# - | -
# <img src="images/Brittany_02625.jpg" width="100"> | <img src="images/Welsh_springer_spaniel_08203.jpg" width="200">
#
# It is not difficult to find other dog breed pairs with minimal inter-class variation (for instance, Curly-Coated Retrievers and American Water Spaniels).
#
# Curly-Coated Retriever | American Water Spaniel
# - | -
# <img src="images/Curly-coated_retriever_03896.jpg" width="200"> | <img src="images/American_water_spaniel_00648.jpg" width="200">
#
#
# Likewise, recall that labradors come in yellow, chocolate, and black.  Your vision-based algorithm will have to conquer this high intra-class variation to determine how to classify all of these different shades as the same breed.
#
# Yellow Labrador | Chocolate Labrador | Black Labrador
# - | -
# <img src="images/Labrador_retriever_06457.jpg" width="150"> | <img src="images/Labrador_retriever_06455.jpg" width="240"> | <img src="images/Labrador_retriever_06449.jpg" width="220">
#
# We also mention that random chance presents an exceptionally low bar: setting aside the fact that the classes are slightly imabalanced, a random guess will provide a correct answer roughly 1 in 133 times, which corresponds to an accuracy of less than 1%.
#
# Remember that the practice is far ahead of the theory in deep learning.  Experiment with many different architectures, and trust your intuition.  And, of course, have fun!
#
# ### Pre-process the Data
#
# We rescale the images by dividing every pixel in every image by 255.

# %%
from PIL import ImageFile                            
ImageFile.LOAD_TRUNCATED_IMAGES = True                 

# pre-process the data for Keras
train_tensors = paths_to_tensor(train_files).astype('float32')/255
valid_tensors = paths_to_tensor(valid_files).astype('float32')/255
test_tensors = paths_to_tensor(test_files).astype('float32')/255
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 6680/6680 [00:48<00:00, 136.62it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 835/835 [00:05<00:00, 153.94it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 836/836 [00:05<00:00, 154.53it/s]

# %% [markdown]
# ### (IMPLEMENTATION) Model Architecture
#
# Create a CNN to classify dog breed.  At the end of your code cell block, summarize the layers of your model by executing the line:
#
#         model.summary()
#
# We have imported some Python modules to get you started, but feel free to import as many modules as you need.  If you end up getting stuck, here's a hint that specifies a model that trains relatively fast on CPU and attains >1% test accuracy in 5 epochs:
#
# ![Sample CNN](images/sample_cnn.png)
#
# __Question 4:__ Outline the steps you took to get to your final CNN architecture and your reasoning at each step.  If you chose to use the hinted architecture above, describe why you think that CNN architecture should work well for the image classification task.
#
# __Answer:__
#
# The final model is a variation of a VGG-like covnet. The overall structure is a sequence of convolutional layers, each one followed by a BatchNormalization layer (used for normalizing the output of the non-linear layer before it is passed to the linar layer that is the activaion one). The MaxPooling layers are used for reducing the size of the images and, therefore making them lighter for the processing of the neural network, resulting in better performance.
#
# Increasing the filters depth yielded better results but in larger training time. Adding the Batch Normalization layers returned better reusults, both in accuracy and training time. All of this resulted in that there could be added a fourth convolutional layer and therefore an increase in the model's depth.
#
# Later I tried to shrink the layers by a factor of x4 instead of x2, altering the MaxPooling layers, which reduced significantly the number of trainng parameters and increased the training speed. The Dropout layers were added to reduce overfitting.

# %%
from keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D
from keras.layers import Dropout, Flatten, Dense, Activation
from keras.models import Sequential
from keras.layers.normalization import BatchNormalization

model = Sequential()

### TODO: Define your architecture.
model.add(Conv2D(16, (3,3), padding='same', use_bias=False, input_shape=(224,224,3)))
model.add(BatchNormalization(axis=3, scale=False))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(4,4), strides=(4,4), padding='same'))
model.add(Dropout(0.2))

model.add(Conv2D(32, (3,3), padding='same', use_bias=False))
model.add(BatchNormalization(axis=3, scale=False))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(4,4), strides=(4,4), padding='same'))
model.add(Dropout(0.2))

model.add(Conv2D(64, (3,3), padding='same', use_bias=False))
model.add(BatchNormalization(axis=3, scale=False))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(4,4), strides=(4,4), padding='same'))
model.add(Dropout(0.2))

model.add(Conv2D(128, (3,3), padding='same', use_bias=False))
model.add(BatchNormalization(axis=3, scale=False))
model.add(Activation('relu'))
model.add(Flatten())
model.add(Dropout(0.2))

model.add(Dense(512, activation='relu'))
model.add(Dense(133, activation='softmax'))
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 224, 224, 16)      432
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 224, 224, 16)      48
# _________________________________________________________________
# activation_50 (Activation)   (None, 224, 224, 16)      0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 56, 56, 16)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 56, 56, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 56, 56, 32)        4608
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 56, 56, 32)        96
# _________________________________________________________________
# activation_51 (Activation)   (None, 56, 56, 32)        0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 14, 14, 32)        0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 14, 14, 64)        18432
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 14, 14, 64)        192
# _________________________________________________________________
# activation_52 (Activation)   (None, 14, 14, 64)        0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 4, 4, 64)          0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 4, 4, 128)         73728
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 4, 4, 128)         384
# _________________________________________________________________
# activation_53 (Activation)   (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               1049088
# _________________________________________________________________
# dense_2 (Dense)              (None, 133)               68229
# =================================================================
# Total params: 1,215,237
# Trainable params: 1,214,757
# Non-trainable params: 480
# _________________________________________________________________

# %% [markdown]
# ### Compile the Model

# %%
model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ### (IMPLEMENTATION) Train the Model
#
# Train your model in the code cell below.  Use model checkpointing to save the model that attains the best validation loss.
#
# You are welcome to [augment the training data](https://blog.keras.io/building-powerful-image-classification-models-using-very-little-data.html), but this is not a requirement.

# %%
from keras.callbacks import ModelCheckpoint  

### TODO: specify the number of epochs that you would like to use to train the model.

epochs = 10

### Do NOT modify the code below this line.

checkpointer = ModelCheckpoint(filepath=r'D:\Machine_Learning\Udacity Courses\Machine Learning Engineer ND\machine-learning-master\projects\dog_breed_classifier_master\saved_models\weights.best.from_scratch.hdf5', 
                               verbose=1, save_best_only=True)

model.fit(train_tensors, train_targets, 
          validation_data=(valid_tensors, valid_targets),
          epochs=epochs, batch_size=20, callbacks=[checkpointer], verbose=1)
# Out:
# Train on 6680 samples, validate on 835 samples
# Epoch 1/10
# 6680/6680 [==============================] - ETA: 1:36 - loss: 2.6496 - acc: 0.450 - ETA: 1:00 - loss: 3.1204 - acc: 0.275 - ETA: 47s - loss: 2.9695 - acc: 0.283 - ETA: 41s - loss: 2.9914 - acc: 0.30 - ETA: 37s - loss: 2.9970 - acc: 0.29 - ETA: 34s - loss: 3.0747 - acc: 0.30 - ETA: 29s - loss: 3.0739 - acc: 0.27 - ETA: 25s - loss: 3.0090 - acc: 0.28 - ETA: 23s - loss: 3.0160 - acc: 0.27 - ETA: 21s - loss: 3.0599 - acc: 0.26 - ETA: 21s - loss: 3.0636 - acc: 0.25 - ETA: 20s - loss: 3.0747 - acc: 0.25 - ETA: 19s - loss: 3.0903 - acc: 0.24 - ETA: 18s - loss: 3.0896 - acc: 0.24 - ETA: 18s - loss: 3.0842 - acc: 0.24 - ETA: 17s - loss: 3.0507 - acc: 0.23 - ETA: 17s - loss: 3.0480 - acc: 0.24 - ETA: 16s - loss: 3.0475 - acc: 0.24 - ETA: 16s - loss: 3.0566 - acc: 0.24 - ETA: 16s - loss: 3.0826 - acc: 0.23 - ETA: 16s - loss: 3.1077 - acc: 0.23 - ETA: 15s - loss: 3.0942 - acc: 0.23 - ETA: 15s - loss: 3.1093 - acc: 0.23 - ETA: 15s - loss: 3.0935 - acc: 0.23 - ETA: 14s - loss: 3.0683 - acc: 0.23 - ETA: 14s - loss: 3.0691 - acc: 0.23 - ETA: 14s - loss: 3.0607 - acc: 0.24 - ETA: 14s - loss: 3.0584 - acc: 0.24 - ETA: 13s - loss: 3.0613 - acc: 0.24 - ETA: 13s - loss: 3.0355 - acc: 0.24 - ETA: 13s - loss: 3.0539 - acc: 0.24 - ETA: 13s - loss: 3.0477 - acc: 0.24 - ETA: 13s - loss: 3.0570 - acc: 0.24 - ETA: 13s - loss: 3.0620 - acc: 0.24 - ETA: 13s - loss: 3.0656 - acc: 0.24 - ETA: 12s - loss: 3.0652 - acc: 0.24 - ETA: 12s - loss: 3.0737 - acc: 0.23 - ETA: 12s - loss: 3.0661 - acc: 0.23 - ETA: 12s - loss: 3.0525 - acc: 0.24 - ETA: 12s - loss: 3.0501 - acc: 0.24 - ETA: 12s - loss: 3.0560 - acc: 0.24 - ETA: 12s - loss: 3.0588 - acc: 0.24 - ETA: 12s - loss: 3.0594 - acc: 0.24 - ETA: 12s - loss: 3.0579 - acc: 0.24 - ETA: 11s - loss: 3.0595 - acc: 0.24 - ETA: 11s - loss: 3.0657 - acc: 0.23 - ETA: 11s - loss: 3.0712 - acc: 0.23 - ETA: 11s - loss: 3.0675 - acc: 0.23 - ETA: 11s - loss: 3.0742 - acc: 0.23 - ETA: 11s - loss: 3.0705 - acc: 0.23 - ETA: 11s - loss: 3.0749 - acc: 0.24 - ETA: 11s - loss: 3.0766 - acc: 0.23 - ETA: 10s - loss: 3.0846 - acc: 0.24 - ETA: 10s - loss: 3.0917 - acc: 0.23 - ETA: 10s - loss: 3.0985 - acc: 0.23 - ETA: 10s - loss: 3.0987 - acc: 0.23 - ETA: 10s - loss: 3.0994 - acc: 0.23 - ETA: 10s - loss: 3.1002 - acc: 0.23 - ETA: 10s - loss: 3.0935 - acc: 0.23 - ETA: 10s - loss: 3.0892 - acc: 0.23 - ETA: 10s - loss: 3.0917 - acc: 0.23 - ETA: 9s - loss: 3.0963 - acc: 0.2370 - ETA: 9s - loss: 3.0993 - acc: 0.236 - ETA: 9s - loss: 3.0958 - acc: 0.236 - ETA: 9s - loss: 3.0996 - acc: 0.236 - ETA: 9s - loss: 3.1044 - acc: 0.234 - ETA: 9s - loss: 3.1113 - acc: 0.234 - ETA: 9s - loss: 3.1138 - acc: 0.233 - ETA: 9s - loss: 3.1144 - acc: 0.233 - ETA: 9s - loss: 3.1158 - acc: 0.232 - ETA: 9s - loss: 3.1081 - acc: 0.232 - ETA: 9s - loss: 3.1114 - acc: 0.230 - ETA: 8s - loss: 3.1109 - acc: 0.230 - ETA: 8s - loss: 3.1108 - acc: 0.230 - ETA: 8s - loss: 3.1081 - acc: 0.230 - ETA: 8s - loss: 3.1079 - acc: 0.229 - ETA: 8s - loss: 3.1099 - acc: 0.229 - ETA: 8s - loss: 3.1130 - acc: 0.229 - ETA: 8s - loss: 3.1106 - acc: 0.229 - ETA: 8s - loss: 3.1141 - acc: 0.228 - ETA: 8s - loss: 3.1195 - acc: 0.228 - ETA: 8s - loss: 3.1200 - acc: 0.227 - ETA: 8s - loss: 3.1193 - acc: 0.227 - ETA: 8s - loss: 3.1178 - acc: 0.227 - ETA: 7s - loss: 3.1111 - acc: 0.227 - ETA: 7s - loss: 3.1033 - acc: 0.229 - ETA: 7s - loss: 3.1105 - acc: 0.228 - ETA: 7s - loss: 3.1093 - acc: 0.228 - ETA: 7s - loss: 3.1109 - acc: 0.227 - ETA: 7s - loss: 3.1158 - acc: 0.227 - ETA: 7s - loss: 3.1188 - acc: 0.227 - ETA: 7s - loss: 3.1210 - acc: 0.226 - ETA: 7s - loss: 3.1247 - acc: 0.225 - ETA: 7s - loss: 3.1354 - acc: 0.223 - ETA: 7s - loss: 3.1323 - acc: 0.222 - ETA: 7s - loss: 3.1354 - acc: 0.222 - ETA: 6s - loss: 3.1396 - acc: 0.221 - ETA: 6s - loss: 3.1420 - acc: 0.220 - ETA: 6s - loss: 3.1402 - acc: 0.220 - ETA: 6s - loss: 3.1339 - acc: 0.221 - ETA: 6s - loss: 3.1317 - acc: 0.221 - ETA: 6s - loss: 3.1290 - acc: 0.221 - ETA: 6s - loss: 3.1347 - acc: 0.220 - ETA: 6s - loss: 3.1360 - acc: 0.218 ...
#
# Epoch 00001: val_loss improved from inf to 4.36342, saving model to D:\Machine_Learning\Udacity Courses\Machine Learning Engineer ND\machine-learning-master\projects\dog_breed_classifier_master\saved_models\weights.best.from_scratch.hdf5
# Epoch 2/10
# 6680/6680 [==============================] - ETA: 15s - loss: 2.6532 - acc: 0.35 - ETA: 12s - loss: 2.6927 - acc: 0.28 - ETA: 12s - loss: 2.9395 - acc: 0.26 - ETA: 12s - loss: 2.8412 - acc: 0.27 - ETA: 12s - loss: 2.8714 - acc: 0.25 - ETA: 12s - loss: 2.8382 - acc: 0.26 - ETA: 12s - loss: 2.8621 - acc: 0.25 - ETA: 12s - loss: 2.8890 - acc: 0.25 - ETA: 12s - loss: 2.8838 - acc: 0.26 - ETA: 12s - loss: 2.9006 - acc: 0.26 - ETA: 12s - loss: 2.9316 - acc: 0.26 - ETA: 12s - loss: 2.9573 - acc: 0.25 - ETA: 12s - loss: 2.9552 - acc: 0.26 - ETA: 11s - loss: 2.9914 - acc: 0.25 - ETA: 12s - loss: 3.0151 - acc: 0.25 - ETA: 11s - loss: 3.0071 - acc: 0.24 - ETA: 11s - loss: 3.0276 - acc: 0.25 - ETA: 11s - loss: 3.0490 - acc: 0.24 - ETA: 11s - loss: 3.0445 - acc: 0.24 - ETA: 11s - loss: 3.0203 - acc: 0.24 - ETA: 11s - loss: 3.0328 - acc: 0.23 - ETA: 11s - loss: 3.0355 - acc: 0.23 - ETA: 11s - loss: 3.0681 - acc: 0.23 - ETA: 11s - loss: 3.0554 - acc: 0.23 - ETA: 11s - loss: 3.0631 - acc: 0.23 - ETA: 11s - loss: 3.0783 - acc: 0.23 - ETA: 11s - loss: 3.0659 - acc: 0.23 - ETA: 11s - loss: 3.0782 - acc: 0.23 - ETA: 11s - loss: 3.0636 - acc: 0.23 - ETA: 10s - loss: 3.0642 - acc: 0.23 - ETA: 10s - loss: 3.0470 - acc: 0.23 - ETA: 10s - loss: 3.0477 - acc: 0.24 - ETA: 10s - loss: 3.0448 - acc: 0.23 - ETA: 10s - loss: 3.0378 - acc: 0.23 - ETA: 10s - loss: 3.0313 - acc: 0.23 - ETA: 10s - loss: 3.0254 - acc: 0.23 - ETA: 10s - loss: 3.0243 - acc: 0.23 - ETA: 10s - loss: 3.0235 - acc: 0.23 - ETA: 10s - loss: 3.0154 - acc: 0.23 - ETA: 10s - loss: 3.0098 - acc: 0.23 - ETA: 10s - loss: 3.0049 - acc: 0.23 - ETA: 10s - loss: 3.0176 - acc: 0.23 - ETA: 10s - loss: 3.0162 - acc: 0.23 - ETA: 9s - loss: 3.0201 - acc: 0.2342 - ETA: 9s - loss: 3.0285 - acc: 0.233 - ETA: 9s - loss: 3.0271 - acc: 0.234 - ETA: 9s - loss: 3.0309 - acc: 0.232 - ETA: 9s - loss: 3.0420 - acc: 0.230 - ETA: 9s - loss: 3.0407 - acc: 0.230 - ETA: 9s - loss: 3.0426 - acc: 0.230 - ETA: 9s - loss: 3.0393 - acc: 0.230 - ETA: 9s - loss: 3.0345 - acc: 0.231 - ETA: 9s - loss: 3.0325 - acc: 0.233 - ETA: 9s - loss: 3.0322 - acc: 0.234 - ETA: 9s - loss: 3.0251 - acc: 0.235 - ETA: 9s - loss: 3.0279 - acc: 0.235 - ETA: 8s - loss: 3.0295 - acc: 0.233 - ETA: 8s - loss: 3.0305 - acc: 0.231 - ETA: 8s - loss: 3.0332 - acc: 0.232 - ETA: 8s - loss: 3.0359 - acc: 0.233 - ETA: 8s - loss: 3.0324 - acc: 0.235 - ETA: 8s - loss: 3.0390 - acc: 0.233 - ETA: 8s - loss: 3.0350 - acc: 0.235 - ETA: 8s - loss: 3.0339 - acc: 0.234 - ETA: 8s - loss: 3.0252 - acc: 0.237 - ETA: 8s - loss: 3.0256 - acc: 0.237 - ETA: 8s - loss: 3.0170 - acc: 0.238 - ETA: 8s - loss: 3.0164 - acc: 0.238 - ETA: 8s - loss: 3.0236 - acc: 0.237 - ETA: 8s - loss: 3.0213 - acc: 0.237 - ETA: 8s - loss: 3.0186 - acc: 0.237 - ETA: 7s - loss: 3.0225 - acc: 0.236 - ETA: 7s - loss: 3.0322 - acc: 0.235 - ETA: 7s - loss: 3.0317 - acc: 0.236 - ETA: 7s - loss: 3.0258 - acc: 0.237 - ETA: 7s - loss: 3.0356 - acc: 0.237 - ETA: 7s - loss: 3.0367 - acc: 0.237 - ETA: 7s - loss: 3.0403 - acc: 0.236 - ETA: 7s - loss: 3.0423 - acc: 0.237 - ETA: 7s - loss: 3.0416 - acc: 0.238 - ETA: 7s - loss: 3.0403 - acc: 0.238 - ETA: 7s - loss: 3.0441 - acc: 0.238 - ETA: 7s - loss: 3.0496 - acc: 0.238 - ETA: 7s - loss: 3.0508 - acc: 0.238 - ETA: 7s - loss: 3.0503 - acc: 0.238 - ETA: 7s - loss: 3.0527 - acc: 0.237 - ETA: 6s - loss: 3.0585 - acc: 0.236 - ETA: 6s - loss: 3.0593 - acc: 0.236 - ETA: 6s - loss: 3.0597 - acc: 0.237 - ETA: 6s - loss: 3.0621 - acc: 0.237 - ETA: 6s - loss: 3.0597 - acc: 0.237 - ETA: 6s - loss: 3.0586 - acc: 0.237 - ETA: 6s - loss: 3.0595 - acc: 0.237 - ETA: 6s - loss: 3.0588 - acc: 0.237 - ETA: 6s - loss: 3.0572 - acc: 0.237 - ETA: 6s - loss: 3.0553 - acc: 0.238 - ETA: 6s - loss: 3.0548 - acc: 0.237 - ETA: 6s - loss: 3.0535 - acc: 0.237 - ETA: 6s - loss: 3.0593 - acc: 0.236 - ETA: 6s - loss: 3.0638 - acc: 0.236 - ETA: 5s - loss: 3.0623 - acc: 0.235 - ETA: 5s - loss: 3.0624 - acc: 0.235 - ETA: 5s - loss: 3.0653 - acc: 0.235 - ETA: 5s - loss: 3.0662 - acc: 0.235 - ET ...
#
# Epoch 00002: val_loss did not improve from 4.36342
# Epoch 3/10
# 6680/6680 [==============================] - ETA: 12s - loss: 3.6212 - acc: 0.20 - ETA: 12s - loss: 2.9913 - acc: 0.18 - ETA: 11s - loss: 2.9693 - acc: 0.18 - ETA: 12s - loss: 2.9449 - acc: 0.18 - ETA: 11s - loss: 2.9722 - acc: 0.19 - ETA: 12s - loss: 2.9941 - acc: 0.23 - ETA: 11s - loss: 2.9815 - acc: 0.24 - ETA: 11s - loss: 2.9942 - acc: 0.24 - ETA: 12s - loss: 2.9744 - acc: 0.24 - ETA: 11s - loss: 2.8947 - acc: 0.25 - ETA: 11s - loss: 2.8914 - acc: 0.25 - ETA: 11s - loss: 2.8889 - acc: 0.26 - ETA: 11s - loss: 2.9297 - acc: 0.25 - ETA: 11s - loss: 2.9421 - acc: 0.25 - ETA: 11s - loss: 2.9539 - acc: 0.24 - ETA: 11s - loss: 2.9835 - acc: 0.24 - ETA: 11s - loss: 2.9894 - acc: 0.23 - ETA: 11s - loss: 2.9800 - acc: 0.23 - ETA: 11s - loss: 2.9847 - acc: 0.23 - ETA: 11s - loss: 2.9657 - acc: 0.24 - ETA: 11s - loss: 2.9615 - acc: 0.24 - ETA: 11s - loss: 2.9565 - acc: 0.24 - ETA: 11s - loss: 2.9544 - acc: 0.24 - ETA: 10s - loss: 2.9555 - acc: 0.24 - ETA: 10s - loss: 2.9623 - acc: 0.23 - ETA: 10s - loss: 2.9623 - acc: 0.24 - ETA: 10s - loss: 2.9566 - acc: 0.24 - ETA: 10s - loss: 2.9516 - acc: 0.23 - ETA: 10s - loss: 2.9545 - acc: 0.24 - ETA: 10s - loss: 2.9552 - acc: 0.24 - ETA: 10s - loss: 2.9507 - acc: 0.24 - ETA: 10s - loss: 2.9585 - acc: 0.24 - ETA: 10s - loss: 2.9587 - acc: 0.23 - ETA: 10s - loss: 2.9702 - acc: 0.23 - ETA: 10s - loss: 2.9803 - acc: 0.23 - ETA: 10s - loss: 2.9897 - acc: 0.23 - ETA: 10s - loss: 2.9868 - acc: 0.23 - ETA: 10s - loss: 2.9883 - acc: 0.23 - ETA: 9s - loss: 2.9822 - acc: 0.2364 - ETA: 9s - loss: 2.9862 - acc: 0.236 - ETA: 9s - loss: 2.9911 - acc: 0.233 - ETA: 9s - loss: 2.9898 - acc: 0.234 - ETA: 9s - loss: 2.9913 - acc: 0.233 - ETA: 9s - loss: 2.9869 - acc: 0.232 - ETA: 9s - loss: 2.9895 - acc: 0.232 - ETA: 9s - loss: 2.9870 - acc: 0.232 - ETA: 9s - loss: 2.9898 - acc: 0.232 - ETA: 9s - loss: 2.9911 - acc: 0.232 - ETA: 9s - loss: 2.9863 - acc: 0.231 - ETA: 9s - loss: 2.9815 - acc: 0.233 - ETA: 9s - loss: 2.9893 - acc: 0.231 - ETA: 9s - loss: 2.9995 - acc: 0.231 - ETA: 9s - loss: 3.0050 - acc: 0.228 - ETA: 9s - loss: 2.9960 - acc: 0.231 - ETA: 8s - loss: 2.9925 - acc: 0.231 - ETA: 8s - loss: 2.9876 - acc: 0.233 - ETA: 8s - loss: 2.9991 - acc: 0.232 - ETA: 8s - loss: 3.0043 - acc: 0.232 - ETA: 8s - loss: 3.0126 - acc: 0.232 - ETA: 8s - loss: 3.0120 - acc: 0.232 - ETA: 8s - loss: 3.0079 - acc: 0.233 - ETA: 8s - loss: 3.0082 - acc: 0.233 - ETA: 8s - loss: 2.9979 - acc: 0.237 - ETA: 8s - loss: 3.0043 - acc: 0.235 - ETA: 8s - loss: 3.0111 - acc: 0.236 - ETA: 8s - loss: 3.0123 - acc: 0.235 - ETA: 8s - loss: 3.0248 - acc: 0.234 - ETA: 8s - loss: 3.0221 - acc: 0.234 - ETA: 8s - loss: 3.0178 - acc: 0.235 - ETA: 8s - loss: 3.0135 - acc: 0.235 - ETA: 7s - loss: 3.0177 - acc: 0.234 - ETA: 7s - loss: 3.0151 - acc: 0.235 - ETA: 7s - loss: 3.0200 - acc: 0.235 - ETA: 7s - loss: 3.0220 - acc: 0.234 - ETA: 7s - loss: 3.0171 - acc: 0.234 - ETA: 7s - loss: 3.0149 - acc: 0.235 - ETA: 7s - loss: 3.0099 - acc: 0.236 - ETA: 7s - loss: 3.0100 - acc: 0.235 - ETA: 7s - loss: 3.0116 - acc: 0.237 - ETA: 7s - loss: 3.0165 - acc: 0.236 - ETA: 7s - loss: 3.0157 - acc: 0.236 - ETA: 7s - loss: 3.0181 - acc: 0.236 - ETA: 7s - loss: 3.0159 - acc: 0.237 - ETA: 7s - loss: 3.0176 - acc: 0.238 - ETA: 6s - loss: 3.0157 - acc: 0.240 - ETA: 6s - loss: 3.0138 - acc: 0.240 - ETA: 6s - loss: 3.0147 - acc: 0.239 - ETA: 6s - loss: 3.0183 - acc: 0.239 - ETA: 6s - loss: 3.0192 - acc: 0.237 - ETA: 6s - loss: 3.0209 - acc: 0.238 - ETA: 6s - loss: 3.0253 - acc: 0.237 - ETA: 6s - loss: 3.0277 - acc: 0.236 - ETA: 6s - loss: 3.0345 - acc: 0.236 - ETA: 6s - loss: 3.0341 - acc: 0.237 - ETA: 6s - loss: 3.0333 - acc: 0.238 - ETA: 6s - loss: 3.0299 - acc: 0.239 - ETA: 6s - loss: 3.0313 - acc: 0.239 - ETA: 6s - loss: 3.0335 - acc: 0.239 - ETA: 6s - loss: 3.0337 - acc: 0.239 - ETA: 6s - loss: 3.0361 - acc: 0.238 - ETA: 5s - loss: 3.0336 - acc: 0.239 - ETA: 5s - loss: 3.0304 - acc: 0.239 - ETA: 5s - loss: 3.0271 - acc: 0.240 - ETA: 5s - loss: 3.0282 - acc: 0.239 - ET ...
#
# Epoch 00003: val_loss did not improve from 4.36342
# Epoch 4/10
# 6680/6680 [==============================] - ETA: 13s - loss: 2.9565 - acc: 0.25 - ETA: 12s - loss: 2.8249 - acc: 0.28 - ETA: 12s - loss: 3.0263 - acc: 0.27 - ETA: 12s - loss: 3.0563 - acc: 0.28 - ETA: 12s - loss: 2.9585 - acc: 0.29 - ETA: 12s - loss: 2.9384 - acc: 0.31 - ETA: 12s - loss: 2.9091 - acc: 0.30 - ETA: 11s - loss: 2.9176 - acc: 0.30 - ETA: 11s - loss: 2.8777 - acc: 0.31 - ETA: 11s - loss: 2.8287 - acc: 0.31 - ETA: 11s - loss: 2.8324 - acc: 0.31 - ETA: 11s - loss: 2.8710 - acc: 0.29 - ETA: 11s - loss: 2.8791 - acc: 0.29 - ETA: 11s - loss: 2.8902 - acc: 0.30 - ETA: 11s - loss: 2.9025 - acc: 0.28 - ETA: 11s - loss: 2.9445 - acc: 0.29 - ETA: 11s - loss: 2.9141 - acc: 0.28 - ETA: 11s - loss: 2.9265 - acc: 0.28 - ETA: 11s - loss: 2.9298 - acc: 0.28 - ETA: 11s - loss: 2.9267 - acc: 0.28 - ETA: 11s - loss: 2.9419 - acc: 0.27 - ETA: 11s - loss: 2.9381 - acc: 0.27 - ETA: 10s - loss: 2.9329 - acc: 0.27 - ETA: 10s - loss: 2.9285 - acc: 0.27 - ETA: 10s - loss: 2.9315 - acc: 0.27 - ETA: 10s - loss: 2.9335 - acc: 0.27 - ETA: 10s - loss: 2.9060 - acc: 0.27 - ETA: 10s - loss: 2.9041 - acc: 0.27 - ETA: 10s - loss: 2.9067 - acc: 0.26 - ETA: 10s - loss: 2.9026 - acc: 0.26 - ETA: 10s - loss: 2.9202 - acc: 0.26 - ETA: 10s - loss: 2.9137 - acc: 0.27 - ETA: 10s - loss: 2.9360 - acc: 0.26 - ETA: 10s - loss: 2.9322 - acc: 0.26 - ETA: 10s - loss: 2.9238 - acc: 0.26 - ETA: 10s - loss: 2.9192 - acc: 0.26 - ETA: 10s - loss: 2.9134 - acc: 0.26 - ETA: 10s - loss: 2.9244 - acc: 0.26 - ETA: 9s - loss: 2.9353 - acc: 0.2625 - ETA: 9s - loss: 2.9375 - acc: 0.262 - ETA: 9s - loss: 2.9366 - acc: 0.261 - ETA: 9s - loss: 2.9438 - acc: 0.260 - ETA: 9s - loss: 2.9345 - acc: 0.262 - ETA: 9s - loss: 2.9262 - acc: 0.261 - ETA: 9s - loss: 2.9319 - acc: 0.259 - ETA: 9s - loss: 2.9296 - acc: 0.260 - ETA: 9s - loss: 2.9264 - acc: 0.259 - ETA: 9s - loss: 2.9218 - acc: 0.261 - ETA: 9s - loss: 2.9330 - acc: 0.260 - ETA: 9s - loss: 2.9368 - acc: 0.259 - ETA: 9s - loss: 2.9376 - acc: 0.257 - ETA: 9s - loss: 2.9392 - acc: 0.257 - ETA: 9s - loss: 2.9407 - acc: 0.256 - ETA: 9s - loss: 2.9412 - acc: 0.258 - ETA: 8s - loss: 2.9446 - acc: 0.256 - ETA: 8s - loss: 2.9480 - acc: 0.257 - ETA: 8s - loss: 2.9430 - acc: 0.257 - ETA: 8s - loss: 2.9386 - acc: 0.257 - ETA: 8s - loss: 2.9414 - acc: 0.256 - ETA: 8s - loss: 2.9429 - acc: 0.255 - ETA: 8s - loss: 2.9425 - acc: 0.255 - ETA: 8s - loss: 2.9461 - acc: 0.255 - ETA: 8s - loss: 2.9420 - acc: 0.256 - ETA: 8s - loss: 2.9413 - acc: 0.258 - ETA: 8s - loss: 2.9454 - acc: 0.257 - ETA: 8s - loss: 2.9433 - acc: 0.256 - ETA: 8s - loss: 2.9445 - acc: 0.256 - ETA: 8s - loss: 2.9472 - acc: 0.255 - ETA: 8s - loss: 2.9512 - acc: 0.254 - ETA: 8s - loss: 2.9525 - acc: 0.253 - ETA: 8s - loss: 2.9578 - acc: 0.252 - ETA: 7s - loss: 2.9535 - acc: 0.252 - ETA: 7s - loss: 2.9509 - acc: 0.251 - ETA: 7s - loss: 2.9421 - acc: 0.252 - ETA: 7s - loss: 2.9467 - acc: 0.251 - ETA: 7s - loss: 2.9458 - acc: 0.251 - ETA: 7s - loss: 2.9462 - acc: 0.251 - ETA: 7s - loss: 2.9561 - acc: 0.250 - ETA: 7s - loss: 2.9456 - acc: 0.252 - ETA: 7s - loss: 2.9436 - acc: 0.252 - ETA: 7s - loss: 2.9435 - acc: 0.252 - ETA: 7s - loss: 2.9420 - acc: 0.252 - ETA: 7s - loss: 2.9405 - acc: 0.251 - ETA: 7s - loss: 2.9378 - acc: 0.251 - ETA: 7s - loss: 2.9358 - acc: 0.250 - ETA: 7s - loss: 2.9327 - acc: 0.250 - ETA: 6s - loss: 2.9334 - acc: 0.249 - ETA: 6s - loss: 2.9324 - acc: 0.249 - ETA: 6s - loss: 2.9322 - acc: 0.249 - ETA: 6s - loss: 2.9308 - acc: 0.250 - ETA: 6s - loss: 2.9308 - acc: 0.248 - ETA: 6s - loss: 2.9278 - acc: 0.249 - ETA: 6s - loss: 2.9262 - acc: 0.250 - ETA: 6s - loss: 2.9333 - acc: 0.248 - ETA: 6s - loss: 2.9371 - acc: 0.247 - ETA: 6s - loss: 2.9359 - acc: 0.247 - ETA: 6s - loss: 2.9357 - acc: 0.247 - ETA: 6s - loss: 2.9385 - acc: 0.246 - ETA: 6s - loss: 2.9386 - acc: 0.247 - ETA: 6s - loss: 2.9412 - acc: 0.247 - ETA: 6s - loss: 2.9407 - acc: 0.247 - ETA: 6s - loss: 2.9406 - acc: 0.247 - ETA: 5s - loss: 2.9388 - acc: 0.247 - ETA: 5s - loss: 2.9370 - acc: 0.248 - ET ...
#
# Epoch 00004: val_loss improved from 4.36342 to 4.06469, saving model to D:\Machine_Learning\Udacity Courses\Machine Learning Engineer ND\machine-learning-master\projects\dog_breed_classifier_master\saved_models\weights.best.from_scratch.hdf5
# Epoch 5/10
# 6680/6680 [==============================] - ETA: 20s - loss: 2.4976 - acc: 0.25 - ETA: 15s - loss: 2.4344 - acc: 0.31 - ETA: 13s - loss: 2.6693 - acc: 0.30 - ETA: 13s - loss: 2.7500 - acc: 0.27 - ETA: 12s - loss: 2.6888 - acc: 0.27 - ETA: 13s - loss: 2.7282 - acc: 0.27 - ETA: 12s - loss: 2.6615 - acc: 0.29 - ETA: 12s - loss: 2.7388 - acc: 0.28 - ETA: 12s - loss: 2.7298 - acc: 0.28 - ETA: 12s - loss: 2.7400 - acc: 0.28 - ETA: 12s - loss: 2.7333 - acc: 0.28 - ETA: 12s - loss: 2.7469 - acc: 0.27 - ETA: 11s - loss: 2.7495 - acc: 0.28 - ETA: 11s - loss: 2.7584 - acc: 0.27 - ETA: 11s - loss: 2.7237 - acc: 0.28 - ETA: 11s - loss: 2.7340 - acc: 0.29 - ETA: 11s - loss: 2.7512 - acc: 0.28 - ETA: 11s - loss: 2.7645 - acc: 0.29 - ETA: 11s - loss: 2.7545 - acc: 0.28 - ETA: 11s - loss: 2.7729 - acc: 0.28 - ETA: 11s - loss: 2.7729 - acc: 0.29 - ETA: 11s - loss: 2.7822 - acc: 0.28 - ETA: 11s - loss: 2.7840 - acc: 0.28 - ETA: 11s - loss: 2.8083 - acc: 0.27 - ETA: 11s - loss: 2.8138 - acc: 0.28 - ETA: 11s - loss: 2.8010 - acc: 0.28 - ETA: 11s - loss: 2.8080 - acc: 0.28 - ETA: 10s - loss: 2.8169 - acc: 0.28 - ETA: 10s - loss: 2.8112 - acc: 0.28 - ETA: 10s - loss: 2.8028 - acc: 0.28 - ETA: 10s - loss: 2.7923 - acc: 0.28 - ETA: 10s - loss: 2.7787 - acc: 0.29 - ETA: 10s - loss: 2.7621 - acc: 0.29 - ETA: 10s - loss: 2.7572 - acc: 0.29 - ETA: 10s - loss: 2.7534 - acc: 0.29 - ETA: 10s - loss: 2.7565 - acc: 0.29 - ETA: 10s - loss: 2.7762 - acc: 0.29 - ETA: 10s - loss: 2.7806 - acc: 0.29 - ETA: 10s - loss: 2.7827 - acc: 0.29 - ETA: 10s - loss: 2.7871 - acc: 0.29 - ETA: 10s - loss: 2.7953 - acc: 0.29 - ETA: 9s - loss: 2.7793 - acc: 0.2945 - ETA: 9s - loss: 2.7841 - acc: 0.293 - ETA: 9s - loss: 2.7911 - acc: 0.290 - ETA: 9s - loss: 2.7831 - acc: 0.291 - ETA: 9s - loss: 2.7846 - acc: 0.290 - ETA: 9s - loss: 2.7873 - acc: 0.290 - ETA: 9s - loss: 2.7829 - acc: 0.292 - ETA: 9s - loss: 2.7824 - acc: 0.292 - ETA: 9s - loss: 2.7770 - acc: 0.292 - ETA: 9s - loss: 2.7782 - acc: 0.292 - ETA: 9s - loss: 2.7800 - acc: 0.291 - ETA: 9s - loss: 2.7863 - acc: 0.288 - ETA: 9s - loss: 2.7917 - acc: 0.288 - ETA: 9s - loss: 2.7858 - acc: 0.291 - ETA: 9s - loss: 2.7822 - acc: 0.291 - ETA: 9s - loss: 2.7838 - acc: 0.291 - ETA: 8s - loss: 2.7856 - acc: 0.292 - ETA: 8s - loss: 2.7977 - acc: 0.292 - ETA: 8s - loss: 2.7928 - acc: 0.293 - ETA: 8s - loss: 2.7903 - acc: 0.292 - ETA: 8s - loss: 2.7897 - acc: 0.291 - ETA: 8s - loss: 2.7946 - acc: 0.289 - ETA: 8s - loss: 2.7925 - acc: 0.290 - ETA: 8s - loss: 2.8021 - acc: 0.287 - ETA: 8s - loss: 2.8112 - acc: 0.286 - ETA: 8s - loss: 2.8172 - acc: 0.287 - ETA: 8s - loss: 2.8182 - acc: 0.286 - ETA: 8s - loss: 2.8157 - acc: 0.287 - ETA: 8s - loss: 2.8226 - acc: 0.286 - ETA: 8s - loss: 2.8284 - acc: 0.284 - ETA: 7s - loss: 2.8280 - acc: 0.284 - ETA: 7s - loss: 2.8256 - acc: 0.282 - ETA: 7s - loss: 2.8299 - acc: 0.281 - ETA: 7s - loss: 2.8334 - acc: 0.281 - ETA: 7s - loss: 2.8327 - acc: 0.281 - ETA: 7s - loss: 2.8383 - acc: 0.280 - ETA: 7s - loss: 2.8469 - acc: 0.278 - ETA: 7s - loss: 2.8571 - acc: 0.277 - ETA: 7s - loss: 2.8611 - acc: 0.275 - ETA: 7s - loss: 2.8621 - acc: 0.273 - ETA: 7s - loss: 2.8607 - acc: 0.273 - ETA: 7s - loss: 2.8593 - acc: 0.274 - ETA: 7s - loss: 2.8578 - acc: 0.274 - ETA: 7s - loss: 2.8636 - acc: 0.274 - ETA: 7s - loss: 2.8635 - acc: 0.275 - ETA: 6s - loss: 2.8607 - acc: 0.277 - ETA: 6s - loss: 2.8617 - acc: 0.277 - ETA: 6s - loss: 2.8647 - acc: 0.277 - ETA: 6s - loss: 2.8590 - acc: 0.277 - ETA: 6s - loss: 2.8563 - acc: 0.278 - ETA: 6s - loss: 2.8548 - acc: 0.278 - ETA: 6s - loss: 2.8534 - acc: 0.277 - ETA: 6s - loss: 2.8537 - acc: 0.277 - ETA: 6s - loss: 2.8522 - acc: 0.276 - ETA: 6s - loss: 2.8537 - acc: 0.275 - ETA: 6s - loss: 2.8569 - acc: 0.274 - ETA: 6s - loss: 2.8643 - acc: 0.274 - ETA: 6s - loss: 2.8647 - acc: 0.274 - ETA: 6s - loss: 2.8599 - acc: 0.275 - ETA: 5s - loss: 2.8576 - acc: 0.275 - ETA: 5s - loss: 2.8554 - acc: 0.275 - ETA: 5s - loss: 2.8562 - acc: 0.275 - ETA: 5s - loss: 2.8573 - acc: 0.275 - ET ...
#
# Epoch 00005: val_loss did not improve from 4.06469
# Epoch 6/10
# 6680/6680 [==============================] - ETA: 13s - loss: 3.1237 - acc: 0.30 - ETA: 12s - loss: 3.3036 - acc: 0.23 - ETA: 12s - loss: 3.0578 - acc: 0.26 - ETA: 12s - loss: 2.9909 - acc: 0.26 - ETA: 11s - loss: 2.9335 - acc: 0.28 - ETA: 12s - loss: 2.8855 - acc: 0.30 - ETA: 11s - loss: 2.8063 - acc: 0.31 - ETA: 12s - loss: 2.8325 - acc: 0.30 - ETA: 12s - loss: 2.7698 - acc: 0.31 - ETA: 12s - loss: 2.7574 - acc: 0.30 - ETA: 12s - loss: 2.7613 - acc: 0.30 - ETA: 12s - loss: 2.7951 - acc: 0.28 - ETA: 11s - loss: 2.7860 - acc: 0.28 - ETA: 12s - loss: 2.7850 - acc: 0.28 - ETA: 11s - loss: 2.7593 - acc: 0.28 - ETA: 11s - loss: 2.7686 - acc: 0.28 - ETA: 11s - loss: 2.7709 - acc: 0.29 - ETA: 11s - loss: 2.7840 - acc: 0.28 - ETA: 11s - loss: 2.7621 - acc: 0.28 - ETA: 11s - loss: 2.7497 - acc: 0.29 - ETA: 11s - loss: 2.7525 - acc: 0.29 - ETA: 11s - loss: 2.7519 - acc: 0.29 - ETA: 11s - loss: 2.7190 - acc: 0.29 - ETA: 11s - loss: 2.7201 - acc: 0.29 - ETA: 11s - loss: 2.7302 - acc: 0.29 - ETA: 11s - loss: 2.7185 - acc: 0.29 - ETA: 10s - loss: 2.7220 - acc: 0.28 - ETA: 10s - loss: 2.7233 - acc: 0.28 - ETA: 10s - loss: 2.7161 - acc: 0.29 - ETA: 10s - loss: 2.7144 - acc: 0.28 - ETA: 10s - loss: 2.7251 - acc: 0.28 - ETA: 10s - loss: 2.7208 - acc: 0.28 - ETA: 10s - loss: 2.7314 - acc: 0.28 - ETA: 10s - loss: 2.7544 - acc: 0.28 - ETA: 10s - loss: 2.7642 - acc: 0.28 - ETA: 10s - loss: 2.7633 - acc: 0.28 - ETA: 10s - loss: 2.7639 - acc: 0.28 - ETA: 10s - loss: 2.7410 - acc: 0.29 - ETA: 10s - loss: 2.7449 - acc: 0.29 - ETA: 10s - loss: 2.7455 - acc: 0.29 - ETA: 9s - loss: 2.7411 - acc: 0.2932 - ETA: 9s - loss: 2.7367 - acc: 0.292 - ETA: 9s - loss: 2.7416 - acc: 0.291 - ETA: 9s - loss: 2.7406 - acc: 0.291 - ETA: 9s - loss: 2.7531 - acc: 0.290 - ETA: 9s - loss: 2.7463 - acc: 0.294 - ETA: 9s - loss: 2.7404 - acc: 0.295 - ETA: 9s - loss: 2.7436 - acc: 0.294 - ETA: 9s - loss: 2.7428 - acc: 0.293 - ETA: 9s - loss: 2.7435 - acc: 0.293 - ETA: 9s - loss: 2.7545 - acc: 0.290 - ETA: 9s - loss: 2.7516 - acc: 0.292 - ETA: 9s - loss: 2.7573 - acc: 0.292 - ETA: 9s - loss: 2.7596 - acc: 0.291 - ETA: 8s - loss: 2.7678 - acc: 0.288 - ETA: 8s - loss: 2.7626 - acc: 0.290 - ETA: 8s - loss: 2.7672 - acc: 0.288 - ETA: 8s - loss: 2.7708 - acc: 0.290 - ETA: 8s - loss: 2.7666 - acc: 0.291 - ETA: 8s - loss: 2.7694 - acc: 0.292 - ETA: 8s - loss: 2.7630 - acc: 0.293 - ETA: 8s - loss: 2.7606 - acc: 0.292 - ETA: 8s - loss: 2.7659 - acc: 0.292 - ETA: 8s - loss: 2.7610 - acc: 0.293 - ETA: 8s - loss: 2.7570 - acc: 0.293 - ETA: 8s - loss: 2.7537 - acc: 0.293 - ETA: 8s - loss: 2.7591 - acc: 0.293 - ETA: 8s - loss: 2.7654 - acc: 0.293 - ETA: 8s - loss: 2.7643 - acc: 0.292 - ETA: 8s - loss: 2.7606 - acc: 0.293 - ETA: 8s - loss: 2.7594 - acc: 0.294 - ETA: 7s - loss: 2.7595 - acc: 0.294 - ETA: 7s - loss: 2.7624 - acc: 0.293 - ETA: 7s - loss: 2.7618 - acc: 0.293 - ETA: 7s - loss: 2.7614 - acc: 0.294 - ETA: 7s - loss: 2.7619 - acc: 0.294 - ETA: 7s - loss: 2.7674 - acc: 0.294 - ETA: 7s - loss: 2.7689 - acc: 0.294 - ETA: 7s - loss: 2.7696 - acc: 0.293 - ETA: 7s - loss: 2.7706 - acc: 0.294 - ETA: 7s - loss: 2.7782 - acc: 0.292 - ETA: 7s - loss: 2.7770 - acc: 0.291 - ETA: 7s - loss: 2.7756 - acc: 0.291 - ETA: 7s - loss: 2.7770 - acc: 0.290 - ETA: 7s - loss: 2.7732 - acc: 0.291 - ETA: 6s - loss: 2.7755 - acc: 0.289 - ETA: 6s - loss: 2.7735 - acc: 0.288 - ETA: 6s - loss: 2.7704 - acc: 0.289 - ETA: 6s - loss: 2.7670 - acc: 0.289 - ETA: 6s - loss: 2.7661 - acc: 0.290 - ETA: 6s - loss: 2.7640 - acc: 0.291 - ETA: 6s - loss: 2.7712 - acc: 0.290 - ETA: 6s - loss: 2.7694 - acc: 0.291 - ETA: 6s - loss: 2.7759 - acc: 0.290 - ETA: 6s - loss: 2.7757 - acc: 0.290 - ETA: 6s - loss: 2.7775 - acc: 0.290 - ETA: 6s - loss: 2.7785 - acc: 0.289 - ETA: 6s - loss: 2.7782 - acc: 0.289 - ETA: 6s - loss: 2.7773 - acc: 0.290 - ETA: 6s - loss: 2.7745 - acc: 0.291 - ETA: 5s - loss: 2.7811 - acc: 0.290 - ETA: 5s - loss: 2.7817 - acc: 0.289 - ETA: 5s - loss: 2.7841 - acc: 0.288 - ETA: 5s - loss: 2.7859 - acc: 0.288 - ET ...
#
# Epoch 00006: val_loss did not improve from 4.06469
# Epoch 7/10
# 6680/6680 [==============================] - ETA: 14s - loss: 2.6071 - acc: 0.25 - ETA: 12s - loss: 2.6154 - acc: 0.33 - ETA: 13s - loss: 2.6377 - acc: 0.30 - ETA: 12s - loss: 2.5939 - acc: 0.34 - ETA: 12s - loss: 2.6286 - acc: 0.33 - ETA: 12s - loss: 2.5890 - acc: 0.33 - ETA: 12s - loss: 2.6569 - acc: 0.32 - ETA: 12s - loss: 2.6497 - acc: 0.33 - ETA: 12s - loss: 2.6250 - acc: 0.32 - ETA: 12s - loss: 2.6034 - acc: 0.32 - ETA: 12s - loss: 2.5944 - acc: 0.32 - ETA: 11s - loss: 2.6189 - acc: 0.31 - ETA: 11s - loss: 2.5682 - acc: 0.32 - ETA: 11s - loss: 2.5791 - acc: 0.32 - ETA: 11s - loss: 2.6094 - acc: 0.31 - ETA: 11s - loss: 2.6338 - acc: 0.31 - ETA: 11s - loss: 2.6609 - acc: 0.30 - ETA: 11s - loss: 2.6745 - acc: 0.29 - ETA: 11s - loss: 2.6712 - acc: 0.29 - ETA: 11s - loss: 2.6790 - acc: 0.29 - ETA: 11s - loss: 2.6995 - acc: 0.28 - ETA: 11s - loss: 2.7074 - acc: 0.28 - ETA: 11s - loss: 2.7299 - acc: 0.28 - ETA: 11s - loss: 2.7371 - acc: 0.28 - ETA: 11s - loss: 2.7156 - acc: 0.28 - ETA: 11s - loss: 2.7113 - acc: 0.29 - ETA: 11s - loss: 2.7184 - acc: 0.28 - ETA: 10s - loss: 2.7169 - acc: 0.29 - ETA: 10s - loss: 2.7009 - acc: 0.29 - ETA: 10s - loss: 2.7121 - acc: 0.29 - ETA: 10s - loss: 2.7159 - acc: 0.29 - ETA: 10s - loss: 2.7073 - acc: 0.30 - ETA: 10s - loss: 2.6896 - acc: 0.30 - ETA: 10s - loss: 2.6938 - acc: 0.30 - ETA: 10s - loss: 2.6925 - acc: 0.30 - ETA: 10s - loss: 2.6972 - acc: 0.30 - ETA: 10s - loss: 2.6706 - acc: 0.30 - ETA: 10s - loss: 2.6665 - acc: 0.30 - ETA: 10s - loss: 2.6675 - acc: 0.30 - ETA: 10s - loss: 2.6656 - acc: 0.30 - ETA: 10s - loss: 2.6763 - acc: 0.30 - ETA: 10s - loss: 2.6766 - acc: 0.30 - ETA: 10s - loss: 2.6839 - acc: 0.30 - ETA: 9s - loss: 2.6844 - acc: 0.3019 - ETA: 9s - loss: 2.6927 - acc: 0.300 - ETA: 9s - loss: 2.7011 - acc: 0.298 - ETA: 9s - loss: 2.7046 - acc: 0.296 - ETA: 9s - loss: 2.7157 - acc: 0.296 - ETA: 9s - loss: 2.7300 - acc: 0.295 - ETA: 9s - loss: 2.7295 - acc: 0.296 - ETA: 9s - loss: 2.7243 - acc: 0.296 - ETA: 9s - loss: 2.7308 - acc: 0.294 - ETA: 9s - loss: 2.7343 - acc: 0.295 - ETA: 9s - loss: 2.7307 - acc: 0.295 - ETA: 9s - loss: 2.7272 - acc: 0.297 - ETA: 9s - loss: 2.7245 - acc: 0.297 - ETA: 8s - loss: 2.7191 - acc: 0.297 - ETA: 8s - loss: 2.7233 - acc: 0.296 - ETA: 8s - loss: 2.7262 - acc: 0.296 - ETA: 8s - loss: 2.7365 - acc: 0.294 - ETA: 8s - loss: 2.7447 - acc: 0.291 - ETA: 8s - loss: 2.7459 - acc: 0.291 - ETA: 8s - loss: 2.7490 - acc: 0.290 - ETA: 8s - loss: 2.7534 - acc: 0.290 - ETA: 8s - loss: 2.7555 - acc: 0.289 - ETA: 8s - loss: 2.7587 - acc: 0.288 - ETA: 8s - loss: 2.7577 - acc: 0.290 - ETA: 8s - loss: 2.7622 - acc: 0.290 - ETA: 8s - loss: 2.7651 - acc: 0.290 - ETA: 8s - loss: 2.7646 - acc: 0.291 - ETA: 8s - loss: 2.7617 - acc: 0.290 - ETA: 7s - loss: 2.7698 - acc: 0.289 - ETA: 7s - loss: 2.7666 - acc: 0.290 - ETA: 7s - loss: 2.7642 - acc: 0.292 - ETA: 7s - loss: 2.7603 - acc: 0.293 - ETA: 7s - loss: 2.7665 - acc: 0.292 - ETA: 7s - loss: 2.7687 - acc: 0.292 - ETA: 7s - loss: 2.7730 - acc: 0.291 - ETA: 7s - loss: 2.7741 - acc: 0.292 - ETA: 7s - loss: 2.7714 - acc: 0.292 - ETA: 7s - loss: 2.7725 - acc: 0.291 - ETA: 7s - loss: 2.7685 - acc: 0.293 - ETA: 7s - loss: 2.7674 - acc: 0.293 - ETA: 7s - loss: 2.7724 - acc: 0.291 - ETA: 7s - loss: 2.7703 - acc: 0.292 - ETA: 7s - loss: 2.7708 - acc: 0.291 - ETA: 7s - loss: 2.7696 - acc: 0.291 - ETA: 6s - loss: 2.7714 - acc: 0.290 - ETA: 6s - loss: 2.7716 - acc: 0.290 - ETA: 6s - loss: 2.7745 - acc: 0.288 - ETA: 6s - loss: 2.7776 - acc: 0.289 - ETA: 6s - loss: 2.7729 - acc: 0.289 - ETA: 6s - loss: 2.7734 - acc: 0.288 - ETA: 6s - loss: 2.7725 - acc: 0.287 - ETA: 6s - loss: 2.7723 - acc: 0.288 - ETA: 6s - loss: 2.7721 - acc: 0.288 - ETA: 6s - loss: 2.7747 - acc: 0.288 - ETA: 6s - loss: 2.7793 - acc: 0.288 - ETA: 6s - loss: 2.7765 - acc: 0.289 - ETA: 6s - loss: 2.7789 - acc: 0.288 - ETA: 6s - loss: 2.7801 - acc: 0.288 - ETA: 6s - loss: 2.7797 - acc: 0.288 - ETA: 6s - loss: 2.7777 - acc: 0.288 - ETA: 5s - loss: 2.7789 - acc: 0.289 - ET ...
#
# Epoch 00007: val_loss did not improve from 4.06469
# Epoch 8/10
# 6680/6680 [==============================] - ETA: 10s - loss: 1.8038 - acc: 0.35 - ETA: 12s - loss: 2.3612 - acc: 0.36 - ETA: 12s - loss: 2.6524 - acc: 0.30 - ETA: 12s - loss: 2.7273 - acc: 0.29 - ETA: 12s - loss: 2.7513 - acc: 0.31 - ETA: 12s - loss: 2.7867 - acc: 0.30 - ETA: 12s - loss: 2.6873 - acc: 0.33 - ETA: 12s - loss: 2.6665 - acc: 0.32 - ETA: 12s - loss: 2.6909 - acc: 0.31 - ETA: 12s - loss: 2.7170 - acc: 0.30 - ETA: 12s - loss: 2.7082 - acc: 0.29 - ETA: 11s - loss: 2.7008 - acc: 0.28 - ETA: 11s - loss: 2.6921 - acc: 0.28 - ETA: 11s - loss: 2.6810 - acc: 0.29 - ETA: 11s - loss: 2.6784 - acc: 0.29 - ETA: 11s - loss: 2.6474 - acc: 0.29 - ETA: 11s - loss: 2.6125 - acc: 0.30 - ETA: 11s - loss: 2.6276 - acc: 0.30 - ETA: 11s - loss: 2.6070 - acc: 0.31 - ETA: 11s - loss: 2.5947 - acc: 0.31 - ETA: 11s - loss: 2.5970 - acc: 0.31 - ETA: 11s - loss: 2.6123 - acc: 0.31 - ETA: 11s - loss: 2.6059 - acc: 0.31 - ETA: 11s - loss: 2.6106 - acc: 0.31 - ETA: 11s - loss: 2.5959 - acc: 0.32 - ETA: 11s - loss: 2.6048 - acc: 0.32 - ETA: 11s - loss: 2.5997 - acc: 0.32 - ETA: 10s - loss: 2.6086 - acc: 0.31 - ETA: 11s - loss: 2.6108 - acc: 0.32 - ETA: 10s - loss: 2.6239 - acc: 0.31 - ETA: 10s - loss: 2.6208 - acc: 0.32 - ETA: 10s - loss: 2.6119 - acc: 0.32 - ETA: 10s - loss: 2.6009 - acc: 0.32 - ETA: 10s - loss: 2.6079 - acc: 0.32 - ETA: 10s - loss: 2.6080 - acc: 0.32 - ETA: 10s - loss: 2.6058 - acc: 0.32 - ETA: 10s - loss: 2.6040 - acc: 0.32 - ETA: 10s - loss: 2.6080 - acc: 0.31 - ETA: 10s - loss: 2.6004 - acc: 0.31 - ETA: 10s - loss: 2.5959 - acc: 0.31 - ETA: 10s - loss: 2.6018 - acc: 0.31 - ETA: 10s - loss: 2.6082 - acc: 0.31 - ETA: 10s - loss: 2.6061 - acc: 0.31 - ETA: 9s - loss: 2.5941 - acc: 0.3189 - ETA: 9s - loss: 2.5949 - acc: 0.318 - ETA: 9s - loss: 2.5860 - acc: 0.321 - ETA: 9s - loss: 2.5793 - acc: 0.321 - ETA: 9s - loss: 2.5814 - acc: 0.323 - ETA: 9s - loss: 2.5813 - acc: 0.320 - ETA: 9s - loss: 2.5790 - acc: 0.318 - ETA: 9s - loss: 2.5849 - acc: 0.320 - ETA: 9s - loss: 2.5860 - acc: 0.322 - ETA: 9s - loss: 2.5889 - acc: 0.320 - ETA: 9s - loss: 2.5995 - acc: 0.322 - ETA: 9s - loss: 2.6000 - acc: 0.322 - ETA: 9s - loss: 2.6040 - acc: 0.318 - ETA: 9s - loss: 2.6093 - acc: 0.318 - ETA: 9s - loss: 2.6140 - acc: 0.316 - ETA: 8s - loss: 2.6085 - acc: 0.316 - ETA: 8s - loss: 2.6075 - acc: 0.316 - ETA: 8s - loss: 2.6140 - acc: 0.316 - ETA: 8s - loss: 2.6204 - acc: 0.316 - ETA: 8s - loss: 2.6307 - acc: 0.315 - ETA: 8s - loss: 2.6342 - acc: 0.315 - ETA: 8s - loss: 2.6410 - acc: 0.314 - ETA: 8s - loss: 2.6390 - acc: 0.314 - ETA: 8s - loss: 2.6395 - acc: 0.314 - ETA: 8s - loss: 2.6349 - acc: 0.315 - ETA: 8s - loss: 2.6378 - acc: 0.315 - ETA: 8s - loss: 2.6413 - acc: 0.315 - ETA: 8s - loss: 2.6431 - acc: 0.314 - ETA: 8s - loss: 2.6414 - acc: 0.314 - ETA: 8s - loss: 2.6337 - acc: 0.315 - ETA: 8s - loss: 2.6376 - acc: 0.315 - ETA: 8s - loss: 2.6398 - acc: 0.315 - ETA: 7s - loss: 2.6390 - acc: 0.315 - ETA: 7s - loss: 2.6359 - acc: 0.316 - ETA: 7s - loss: 2.6336 - acc: 0.316 - ETA: 7s - loss: 2.6324 - acc: 0.318 - ETA: 7s - loss: 2.6324 - acc: 0.317 - ETA: 7s - loss: 2.6335 - acc: 0.316 - ETA: 7s - loss: 2.6359 - acc: 0.315 - ETA: 7s - loss: 2.6374 - acc: 0.315 - ETA: 7s - loss: 2.6336 - acc: 0.314 - ETA: 7s - loss: 2.6362 - acc: 0.315 - ETA: 7s - loss: 2.6384 - acc: 0.314 - ETA: 7s - loss: 2.6399 - acc: 0.314 - ETA: 7s - loss: 2.6427 - acc: 0.312 - ETA: 7s - loss: 2.6396 - acc: 0.312 - ETA: 7s - loss: 2.6385 - acc: 0.313 - ETA: 7s - loss: 2.6403 - acc: 0.313 - ETA: 6s - loss: 2.6387 - acc: 0.312 - ETA: 6s - loss: 2.6331 - acc: 0.313 - ETA: 6s - loss: 2.6338 - acc: 0.313 - ETA: 6s - loss: 2.6295 - acc: 0.314 - ETA: 6s - loss: 2.6288 - acc: 0.313 - ETA: 6s - loss: 2.6298 - acc: 0.313 - ETA: 6s - loss: 2.6371 - acc: 0.311 - ETA: 6s - loss: 2.6392 - acc: 0.312 - ETA: 6s - loss: 2.6349 - acc: 0.313 - ETA: 6s - loss: 2.6376 - acc: 0.312 - ETA: 6s - loss: 2.6412 - acc: 0.312 - ETA: 6s - loss: 2.6432 - acc: 0.312 - ETA: 6s - loss: 2.6457 - acc: 0.312 - ET ...
#
# Epoch 00008: val_loss did not improve from 4.06469
# Epoch 9/10
# 6680/6680 [==============================] - ETA: 16s - loss: 2.6491 - acc: 0.35 - ETA: 13s - loss: 2.7270 - acc: 0.30 - ETA: 12s - loss: 2.5774 - acc: 0.30 - ETA: 13s - loss: 2.5363 - acc: 0.30 - ETA: 12s - loss: 2.5517 - acc: 0.31 - ETA: 13s - loss: 2.6554 - acc: 0.29 - ETA: 12s - loss: 2.5736 - acc: 0.31 - ETA: 12s - loss: 2.5541 - acc: 0.32 - ETA: 12s - loss: 2.5733 - acc: 0.32 - ETA: 12s - loss: 2.6146 - acc: 0.31 - ETA: 12s - loss: 2.6172 - acc: 0.31 - ETA: 12s - loss: 2.5832 - acc: 0.32 - ETA: 12s - loss: 2.5507 - acc: 0.33 - ETA: 12s - loss: 2.5238 - acc: 0.33 - ETA: 12s - loss: 2.5435 - acc: 0.33 - ETA: 12s - loss: 2.5150 - acc: 0.34 - ETA: 12s - loss: 2.4944 - acc: 0.36 - ETA: 12s - loss: 2.5076 - acc: 0.36 - ETA: 12s - loss: 2.5107 - acc: 0.36 - ETA: 11s - loss: 2.4727 - acc: 0.37 - ETA: 12s - loss: 2.4913 - acc: 0.37 - ETA: 11s - loss: 2.5312 - acc: 0.36 - ETA: 11s - loss: 2.5315 - acc: 0.35 - ETA: 11s - loss: 2.5338 - acc: 0.36 - ETA: 11s - loss: 2.5327 - acc: 0.36 - ETA: 11s - loss: 2.5443 - acc: 0.35 - ETA: 11s - loss: 2.5378 - acc: 0.35 - ETA: 11s - loss: 2.5445 - acc: 0.34 - ETA: 11s - loss: 2.5591 - acc: 0.34 - ETA: 11s - loss: 2.5450 - acc: 0.34 - ETA: 11s - loss: 2.5384 - acc: 0.35 - ETA: 11s - loss: 2.5392 - acc: 0.35 - ETA: 11s - loss: 2.5336 - acc: 0.35 - ETA: 11s - loss: 2.5290 - acc: 0.35 - ETA: 11s - loss: 2.5221 - acc: 0.35 - ETA: 10s - loss: 2.5364 - acc: 0.34 - ETA: 10s - loss: 2.5432 - acc: 0.34 - ETA: 10s - loss: 2.5495 - acc: 0.34 - ETA: 10s - loss: 2.5501 - acc: 0.34 - ETA: 10s - loss: 2.5547 - acc: 0.34 - ETA: 10s - loss: 2.5503 - acc: 0.34 - ETA: 10s - loss: 2.5591 - acc: 0.34 - ETA: 10s - loss: 2.5577 - acc: 0.34 - ETA: 10s - loss: 2.5517 - acc: 0.34 - ETA: 10s - loss: 2.5465 - acc: 0.34 - ETA: 10s - loss: 2.5448 - acc: 0.34 - ETA: 10s - loss: 2.5409 - acc: 0.34 - ETA: 10s - loss: 2.5386 - acc: 0.34 - ETA: 10s - loss: 2.5265 - acc: 0.34 - ETA: 10s - loss: 2.5379 - acc: 0.34 - ETA: 9s - loss: 2.5326 - acc: 0.3488 - ETA: 9s - loss: 2.5326 - acc: 0.348 - ETA: 9s - loss: 2.5326 - acc: 0.346 - ETA: 9s - loss: 2.5452 - acc: 0.343 - ETA: 9s - loss: 2.5511 - acc: 0.341 - ETA: 9s - loss: 2.5434 - acc: 0.340 - ETA: 9s - loss: 2.5450 - acc: 0.340 - ETA: 9s - loss: 2.5408 - acc: 0.341 - ETA: 9s - loss: 2.5402 - acc: 0.341 - ETA: 9s - loss: 2.5417 - acc: 0.339 - ETA: 9s - loss: 2.5423 - acc: 0.339 - ETA: 9s - loss: 2.5416 - acc: 0.339 - ETA: 9s - loss: 2.5473 - acc: 0.338 - ETA: 9s - loss: 2.5491 - acc: 0.340 - ETA: 9s - loss: 2.5415 - acc: 0.342 - ETA: 8s - loss: 2.5354 - acc: 0.345 - ETA: 8s - loss: 2.5408 - acc: 0.344 - ETA: 8s - loss: 2.5413 - acc: 0.344 - ETA: 8s - loss: 2.5362 - acc: 0.345 - ETA: 8s - loss: 2.5389 - acc: 0.343 - ETA: 8s - loss: 2.5424 - acc: 0.341 - ETA: 8s - loss: 2.5492 - acc: 0.342 - ETA: 8s - loss: 2.5644 - acc: 0.340 - ETA: 8s - loss: 2.5684 - acc: 0.338 - ETA: 8s - loss: 2.5665 - acc: 0.337 - ETA: 8s - loss: 2.5654 - acc: 0.337 - ETA: 8s - loss: 2.5654 - acc: 0.337 - ETA: 8s - loss: 2.5604 - acc: 0.337 - ETA: 8s - loss: 2.5613 - acc: 0.336 - ETA: 8s - loss: 2.5673 - acc: 0.335 - ETA: 8s - loss: 2.5754 - acc: 0.334 - ETA: 7s - loss: 2.5773 - acc: 0.331 - ETA: 7s - loss: 2.5777 - acc: 0.332 - ETA: 7s - loss: 2.5806 - acc: 0.330 - ETA: 7s - loss: 2.5729 - acc: 0.332 - ETA: 7s - loss: 2.5699 - acc: 0.334 - ETA: 7s - loss: 2.5721 - acc: 0.335 - ETA: 7s - loss: 2.5739 - acc: 0.334 - ETA: 7s - loss: 2.5705 - acc: 0.335 - ETA: 7s - loss: 2.5716 - acc: 0.335 - ETA: 7s - loss: 2.5796 - acc: 0.335 - ETA: 7s - loss: 2.5783 - acc: 0.336 - ETA: 7s - loss: 2.5837 - acc: 0.336 - ETA: 7s - loss: 2.5835 - acc: 0.335 - ETA: 6s - loss: 2.5880 - acc: 0.333 - ETA: 6s - loss: 2.5888 - acc: 0.333 - ETA: 6s - loss: 2.5915 - acc: 0.333 - ETA: 6s - loss: 2.5871 - acc: 0.334 - ETA: 6s - loss: 2.5893 - acc: 0.332 - ETA: 6s - loss: 2.5890 - acc: 0.333 - ETA: 6s - loss: 2.5903 - acc: 0.331 - ETA: 6s - loss: 2.5881 - acc: 0.332 - ETA: 6s - loss: 2.5862 - acc: 0.333 - ETA: 6s - loss: 2.5886 - acc: 0.332 - ET ...
#
# Epoch 00009: val_loss did not improve from 4.06469
# Epoch 10/10
# 6680/6680 [==============================] - ETA: 17s - loss: 2.1004 - acc: 0.30 - ETA: 12s - loss: 2.4605 - acc: 0.30 - ETA: 14s - loss: 2.3956 - acc: 0.36 - ETA: 13s - loss: 2.3982 - acc: 0.37 - ETA: 12s - loss: 2.3892 - acc: 0.38 - ETA: 13s - loss: 2.3786 - acc: 0.39 - ETA: 12s - loss: 2.3452 - acc: 0.40 - ETA: 13s - loss: 2.3718 - acc: 0.40 - ETA: 12s - loss: 2.4329 - acc: 0.37 - ETA: 12s - loss: 2.4641 - acc: 0.37 - ETA: 12s - loss: 2.4314 - acc: 0.37 - ETA: 12s - loss: 2.3869 - acc: 0.37 - ETA: 12s - loss: 2.3781 - acc: 0.36 - ETA: 12s - loss: 2.3976 - acc: 0.36 - ETA: 12s - loss: 2.4061 - acc: 0.36 - ETA: 12s - loss: 2.3967 - acc: 0.35 - ETA: 12s - loss: 2.3633 - acc: 0.37 - ETA: 12s - loss: 2.3714 - acc: 0.37 - ETA: 12s - loss: 2.3649 - acc: 0.37 - ETA: 11s - loss: 2.3643 - acc: 0.37 - ETA: 11s - loss: 2.3873 - acc: 0.36 - ETA: 11s - loss: 2.4132 - acc: 0.35 - ETA: 11s - loss: 2.4098 - acc: 0.35 - ETA: 11s - loss: 2.4173 - acc: 0.36 - ETA: 11s - loss: 2.4102 - acc: 0.36 - ETA: 11s - loss: 2.4128 - acc: 0.35 - ETA: 11s - loss: 2.4175 - acc: 0.36 - ETA: 11s - loss: 2.4108 - acc: 0.36 - ETA: 11s - loss: 2.4418 - acc: 0.35 - ETA: 11s - loss: 2.4468 - acc: 0.35 - ETA: 11s - loss: 2.4341 - acc: 0.35 - ETA: 11s - loss: 2.4417 - acc: 0.35 - ETA: 11s - loss: 2.4460 - acc: 0.35 - ETA: 10s - loss: 2.4594 - acc: 0.35 - ETA: 11s - loss: 2.4641 - acc: 0.34 - ETA: 10s - loss: 2.4720 - acc: 0.34 - ETA: 10s - loss: 2.4717 - acc: 0.33 - ETA: 10s - loss: 2.4850 - acc: 0.33 - ETA: 10s - loss: 2.4837 - acc: 0.33 - ETA: 10s - loss: 2.4981 - acc: 0.33 - ETA: 10s - loss: 2.4907 - acc: 0.33 - ETA: 10s - loss: 2.4841 - acc: 0.33 - ETA: 10s - loss: 2.5080 - acc: 0.33 - ETA: 10s - loss: 2.5105 - acc: 0.33 - ETA: 10s - loss: 2.5050 - acc: 0.34 - ETA: 10s - loss: 2.4971 - acc: 0.34 - ETA: 10s - loss: 2.5038 - acc: 0.34 - ETA: 10s - loss: 2.5025 - acc: 0.34 - ETA: 10s - loss: 2.4934 - acc: 0.34 - ETA: 9s - loss: 2.4833 - acc: 0.3475 - ETA: 9s - loss: 2.4889 - acc: 0.345 - ETA: 9s - loss: 2.4906 - acc: 0.345 - ETA: 9s - loss: 2.4883 - acc: 0.345 - ETA: 9s - loss: 2.4924 - acc: 0.346 - ETA: 9s - loss: 2.4951 - acc: 0.345 - ETA: 9s - loss: 2.4831 - acc: 0.346 - ETA: 9s - loss: 2.4842 - acc: 0.346 - ETA: 9s - loss: 2.4906 - acc: 0.346 - ETA: 9s - loss: 2.4927 - acc: 0.345 - ETA: 9s - loss: 2.4863 - acc: 0.347 - ETA: 9s - loss: 2.4870 - acc: 0.346 - ETA: 9s - loss: 2.4931 - acc: 0.346 - ETA: 9s - loss: 2.4908 - acc: 0.345 - ETA: 9s - loss: 2.4873 - acc: 0.345 - ETA: 9s - loss: 2.4839 - acc: 0.346 - ETA: 9s - loss: 2.4794 - acc: 0.346 - ETA: 8s - loss: 2.4799 - acc: 0.347 - ETA: 8s - loss: 2.4840 - acc: 0.346 - ETA: 8s - loss: 2.4867 - acc: 0.349 - ETA: 8s - loss: 2.4911 - acc: 0.346 - ETA: 8s - loss: 2.4971 - acc: 0.344 - ETA: 8s - loss: 2.5019 - acc: 0.343 - ETA: 8s - loss: 2.5080 - acc: 0.343 - ETA: 8s - loss: 2.5081 - acc: 0.342 - ETA: 8s - loss: 2.5078 - acc: 0.341 - ETA: 8s - loss: 2.5098 - acc: 0.340 - ETA: 8s - loss: 2.5056 - acc: 0.342 - ETA: 8s - loss: 2.5064 - acc: 0.341 - ETA: 8s - loss: 2.5073 - acc: 0.341 - ETA: 8s - loss: 2.5102 - acc: 0.342 - ETA: 8s - loss: 2.5070 - acc: 0.344 - ETA: 8s - loss: 2.5059 - acc: 0.343 - ETA: 8s - loss: 2.5084 - acc: 0.343 - ETA: 7s - loss: 2.5033 - acc: 0.343 - ETA: 7s - loss: 2.4979 - acc: 0.345 - ETA: 7s - loss: 2.4991 - acc: 0.344 - ETA: 7s - loss: 2.4925 - acc: 0.344 - ETA: 7s - loss: 2.4870 - acc: 0.346 - ETA: 7s - loss: 2.4928 - acc: 0.346 - ETA: 7s - loss: 2.4892 - acc: 0.346 - ETA: 7s - loss: 2.4930 - acc: 0.344 - ETA: 7s - loss: 2.4921 - acc: 0.344 - ETA: 7s - loss: 2.4966 - acc: 0.344 - ETA: 7s - loss: 2.4988 - acc: 0.344 - ETA: 7s - loss: 2.5027 - acc: 0.344 - ETA: 7s - loss: 2.4987 - acc: 0.344 - ETA: 7s - loss: 2.5007 - acc: 0.344 - ETA: 7s - loss: 2.4985 - acc: 0.345 - ETA: 6s - loss: 2.5032 - acc: 0.344 - ETA: 6s - loss: 2.5034 - acc: 0.343 - ETA: 6s - loss: 2.5044 - acc: 0.343 - ETA: 6s - loss: 2.5058 - acc: 0.343 - ETA: 6s - loss: 2.5101 - acc: 0.342 - ETA: 6s - loss: 2.5140 - acc: 0.342 - ET ...
#
# Epoch 00010: val_loss did not improve from 4.06469

# %% [markdown]
# ### Load the Model with the Best Validation Loss

# %%
model.load_weights('saved_models\weights.best.from_scratch.hdf5')

# %% [markdown]
# ### Test the Model
#
# Try out your model on the test dataset of dog images.  Ensure that your test accuracy is greater than 1%.

# %%
# get index of predicted dog breed for each image in test set
dog_breed_predictions = [np.argmax(model.predict(np.expand_dims(tensor, axis=0))) for tensor in test_tensors]

# report test accuracy
test_accuracy = 100*np.sum(np.array(dog_breed_predictions)==np.argmax(test_targets, axis=1))/len(dog_breed_predictions)
print('Test accuracy: %.4f%%' % test_accuracy)
# Out:
# Test accuracy: 12.7990%

# %% [markdown]
# ---
# <a id='step4'></a>
# ## Step 4: Use a CNN to Classify Dog Breeds
#
# To reduce training time without sacrificing accuracy, we show you how to train a CNN using transfer learning.  In the following step, you will get a chance to use transfer learning to train your own CNN.
#
# ### Obtain Bottleneck Features

# %%
### TODO: Obtain bottleneck features from another pre-trained CNN.
bottleneck_features = np.load(r'D:\Machine_Learning\Udacity Courses\Machine Learning Engineer ND\machine-learning-master\projects\dog_breed_classifier_master\bottleneck_features/DogVGG16Data.npz')
train_VGG16 = bottleneck_features['train']
valid_VGG16 = bottleneck_features['valid']
test_VGG16 = bottleneck_features['test']

# %% [markdown]
# ### Model Architecture
#
# The model uses the the pre-trained VGG-16 model as a fixed feature extractor, where the last convolutional output of VGG-16 is fed as input to our model.  We only add a global average pooling layer and a fully connected layer, where the latter contains one node for each dog category and is equipped with a softmax.

# %%
VGG16_model = Sequential()
VGG16_model.add(GlobalAveragePooling2D(input_shape=train_VGG16.shape[1:]))
VGG16_model.add(Dense(133, activation='softmax'))

VGG16_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# global_average_pooling2d_1 ( (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 133)               68229
# =================================================================
# Total params: 68,229
# Trainable params: 68,229
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Compile the Model

# %%
VGG16_model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

# %% [markdown]
# ### Train the Model

# %%
checkpointer = ModelCheckpoint(filepath=r'D:\Machine_Learning\Udacity Courses\Machine Learning Engineer ND\machine-learning-master\projects\dog_breed_classifier_master\saved_models/weights.best.VGG16.hdf5', 
                               verbose=1, save_best_only=True)

VGG16_model.fit(train_VGG16, train_targets, 
          validation_data=(valid_VGG16, valid_targets),
          epochs=20, batch_size=20, callbacks=[checkpointer], verbose=1)
# Out:
# Train on 6680 samples, validate on 835 samples
# Epoch 1/20
# 6680/6680 [==============================] - ETA: 4:45 - loss: 14.5691 - acc: 0.0000e+ - ETA: 42s - loss: 14.8724 - acc: 0.0143     - ETA: 20s - loss: 14.9784 - acc: 0.006 - ETA: 13s - loss: 15.0290 - acc: 0.010 - ETA: 10s - loss: 15.0576 - acc: 0.010 - ETA: 8s - loss: 14.9752 - acc: 0.012 - ETA: 6s - loss: 14.7417 - acc: 0.01 - ETA: 5s - loss: 14.5791 - acc: 0.01 - ETA: 4s - loss: 14.3847 - acc: 0.02 - ETA: 4s - loss: 14.2811 - acc: 0.02 - ETA: 3s - loss: 14.1997 - acc: 0.03 - ETA: 3s - loss: 14.0932 - acc: 0.03 - ETA: 3s - loss: 13.9977 - acc: 0.03 - ETA: 2s - loss: 13.8699 - acc: 0.04 - ETA: 2s - loss: 13.7814 - acc: 0.05 - ETA: 2s - loss: 13.6980 - acc: 0.05 - ETA: 2s - loss: 13.6778 - acc: 0.05 - ETA: 1s - loss: 13.5371 - acc: 0.06 - ETA: 1s - loss: 13.4582 - acc: 0.06 - ETA: 1s - loss: 13.3932 - acc: 0.07 - ETA: 1s - loss: 13.3615 - acc: 0.07 - ETA: 1s - loss: 13.2937 - acc: 0.07 - ETA: 1s - loss: 13.2389 - acc: 0.07 - ETA: 1s - loss: 13.1770 - acc: 0.07 - ETA: 0s - loss: 13.1047 - acc: 0.08 - ETA: 0s - loss: 13.0208 - acc: 0.08 - ETA: 0s - loss: 12.9698 - acc: 0.09 - ETA: 0s - loss: 12.9108 - acc: 0.09 - ETA: 0s - loss: 12.8699 - acc: 0.09 - ETA: 0s - loss: 12.7929 - acc: 0.10 - ETA: 0s - loss: 12.7614 - acc: 0.10 - ETA: 0s - loss: 12.6820 - acc: 0.10 - ETA: 0s - loss: 12.6414 - acc: 0.10 - 3s 440us/step - loss: 12.5749 - acc: 0.1115 - val_loss: 11.0339 - val_acc: 0.1916
#
# Epoch 00001: val_loss improved from inf to 11.03392, saving model to D:\Machine_Learning\Udacity Courses\Machine Learning Engineer ND\machine-learning-master\projects\dog_breed_classifier_master\saved_models/weights.best.VGG16.hdf5
# Epoch 2/20
# 6680/6680 [==============================] - ETA: 5s - loss: 7.7193 - acc: 0.350 - ETA: 2s - loss: 10.2186 - acc: 0.26 - ETA: 2s - loss: 10.7212 - acc: 0.23 - ETA: 2s - loss: 11.0024 - acc: 0.22 - ETA: 2s - loss: 10.8278 - acc: 0.22 - ETA: 1s - loss: 10.7298 - acc: 0.22 - ETA: 1s - loss: 10.6679 - acc: 0.23 - ETA: 1s - loss: 10.6438 - acc: 0.23 - ETA: 1s - loss: 10.5855 - acc: 0.24 - ETA: 1s - loss: 10.4415 - acc: 0.25 - ETA: 1s - loss: 10.5194 - acc: 0.24 - ETA: 1s - loss: 10.5427 - acc: 0.24 - ETA: 1s - loss: 10.5546 - acc: 0.24 - ETA: 1s - loss: 10.5622 - acc: 0.24 - ETA: 1s - loss: 10.5729 - acc: 0.24 - ETA: 1s - loss: 10.5830 - acc: 0.24 - ETA: 1s - loss: 10.5783 - acc: 0.24 - ETA: 1s - loss: 10.5975 - acc: 0.24 - ETA: 1s - loss: 10.5665 - acc: 0.24 - ETA: 0s - loss: 10.5229 - acc: 0.24 - ETA: 0s - loss: 10.4829 - acc: 0.24 - ETA: 0s - loss: 10.4722 - acc: 0.24 - ETA: 0s - loss: 10.4679 - acc: 0.25 - ETA: 0s - loss: 10.4605 - acc: 0.25 - ETA: 0s - loss: 10.4722 - acc: 0.25 - ETA: 0s - loss: 10.4822 - acc: 0.25 - ETA: 0s - loss: 10.4292 - acc: 0.25 - ETA: 0s - loss: 10.4080 - acc: 0.25 - ETA: 0s - loss: 10.4289 - acc: 0.25 - ETA: 0s - loss: 10.3696 - acc: 0.26 - ETA: 0s - loss: 10.3609 - acc: 0.26 - ETA: 0s - loss: 10.3549 - acc: 0.26 - ETA: 0s - loss: 10.3557 - acc: 0.26 - ETA: 0s - loss: 10.3713 - acc: 0.26 - ETA: 0s - loss: 10.3811 - acc: 0.26 - ETA: 0s - loss: 10.3442 - acc: 0.26 - ETA: 0s - loss: 10.3211 - acc: 0.26 - 2s 317us/step - loss: 10.3241 - acc: 0.2680 - val_loss: 10.1310 - val_acc: 0.2862
#
# Epoch 00002: val_loss improved from 11.03392 to 10.13097, saving model to D:\Machine_Learning\Udacity Courses\Machine Learning Engineer ND\machine-learning-master\projects\dog_breed_classifier_master\saved_models/weights.best.VGG16.hdf5
# Epoch 3/20
# 6680/6680 [==============================] - ETA: 6s - loss: 6.8882 - acc: 0.450 - ETA: 2s - loss: 9.0939 - acc: 0.350 - ETA: 2s - loss: 9.1989 - acc: 0.350 - ETA: 2s - loss: 9.2919 - acc: 0.342 - ETA: 2s - loss: 9.3967 - acc: 0.345 - ETA: 1s - loss: 9.4936 - acc: 0.342 - ETA: 1s - loss: 9.5209 - acc: 0.344 - ETA: 1s - loss: 9.5257 - acc: 0.344 - ETA: 1s - loss: 9.5051 - acc: 0.345 - ETA: 1s - loss: 9.5017 - acc: 0.350 - ETA: 1s - loss: 9.5729 - acc: 0.347 - ETA: 1s - loss: 9.5823 - acc: 0.345 - ETA: 1s - loss: 9.5608 - acc: 0.347 - ETA: 1s - loss: 9.5444 - acc: 0.347 - ETA: 1s - loss: 9.5914 - acc: 0.344 - ETA: 1s - loss: 9.6594 - acc: 0.341 - ETA: 1s - loss: 9.5908 - acc: 0.345 - ETA: 1s - loss: 9.5594 - acc: 0.348 - ETA: 0s - loss: 9.5663 - acc: 0.347 - ETA: 0s - loss: 9.6427 - acc: 0.344 - ETA: 0s - loss: 9.6758 - acc: 0.342 - ETA: 0s - loss: 9.6882 - acc: 0.341 - ETA: 0s - loss: 9.6984 - acc: 0.339 - ETA: 0s - loss: 9.7411 - acc: 0.337 - ETA: 0s - loss: 9.7346 - acc: 0.338 - ETA: 0s - loss: 9.7350 - acc: 0.337 - ETA: 0s - loss: 9.7341 - acc: 0.337 - ETA: 0s - loss: 9.7118 - acc: 0.337 - ETA: 0s - loss: 9.7281 - acc: 0.337 - ETA: 0s - loss: 9.7130 - acc: 0.337 - ETA: 0s - loss: 9.7126 - acc: 0.338 - ETA: 0s - loss: 9.6995 - acc: 0.339 - ETA: 0s - loss: 9.6708 - acc: 0.341 - ETA: 0s - loss: 9.6790 - acc: 0.341 - ETA: 0s - loss: 9.6854 - acc: 0.340 - 2s 306us/step - loss: 9.6642 - acc: 0.3422 - val_loss: 9.8130 - val_acc: 0.3006
#
# Epoch 00003: val_loss improved from 10.13097 to 9.81296, saving model to D:\Machine_Learning\Udacity Courses\Machine Learning Engineer ND\machine-learning-master\projects\dog_breed_classifier_master\saved_models/weights.best.VGG16.hdf5
# Epoch 4/20
# 6680/6680 [==============================] - ETA: 7s - loss: 10.5199 - acc: 0.35 - ETA: 3s - loss: 9.6135 - acc: 0.3687 - ETA: 2s - loss: 9.6046 - acc: 0.350 - ETA: 2s - loss: 9.6248 - acc: 0.359 - ETA: 2s - loss: 9.4958 - acc: 0.369 - ETA: 2s - loss: 9.6589 - acc: 0.362 - ETA: 2s - loss: 9.6093 - acc: 0.366 - ETA: 1s - loss: 9.5793 - acc: 0.365 - ETA: 1s - loss: 9.5763 - acc: 0.366 - ETA: 1s - loss: 9.5569 - acc: 0.368 - ETA: 1s - loss: 9.4072 - acc: 0.378 - ETA: 1s - loss: 9.3023 - acc: 0.384 - ETA: 1s - loss: 9.3636 - acc: 0.380 - ETA: 1s - loss: 9.3132 - acc: 0.383 - ETA: 1s - loss: 9.3714 - acc: 0.380 - ETA: 1s - loss: 9.3559 - acc: 0.379 - ETA: 1s - loss: 9.3298 - acc: 0.380 - ETA: 1s - loss: 9.3111 - acc: 0.380 - ETA: 1s - loss: 9.2554 - acc: 0.385 - ETA: 1s - loss: 9.2670 - acc: 0.383 - ETA: 0s - loss: 9.2931 - acc: 0.381 - ETA: 0s - loss: 9.3256 - acc: 0.379 - ETA: 0s - loss: 9.2809 - acc: 0.383 - ETA: 0s - loss: 9.2718 - acc: 0.384 - ETA: 0s - loss: 9.2725 - acc: 0.383 - ETA: 0s - loss: 9.3246 - acc: 0.380 - ETA: 0s - loss: 9.3658 - acc: 0.378 - ETA: 0s - loss: 9.3643 - acc: 0.378 - ETA: 0s - loss: 9.3719 - acc: 0.376 - ETA: 0s - loss: 9.3717 - acc: 0.376 - ETA: 0s - loss: 9.3747 - acc: 0.375 - ETA: 0s - loss: 9.3916 - acc: 0.374 - ETA: 0s - loss: 9.3760 - acc: 0.374 - ETA: 0s - loss: 9.3864 - acc: 0.373 - ETA: 0s - loss: 9.3665 - acc: 0.375 - ETA: 0s - loss: 9.3786 - acc: 0.374 - 2s 310us/step - loss: 9.3680 - acc: 0.3751 - val_loss: 9.6300 - val_acc: 0.3174
#
# Epoch 00004: val_loss improved from 9.81296 to 9.62995, saving model to D:\Machine_Learning\Udacity Courses\Machine Learning Engineer ND\machine-learning-master\projects\dog_breed_classifier_master\saved_models/weights.best.VGG16.hdf5
# Epoch 5/20
# 6680/6680 [==============================] - ETA: 2s - loss: 8.8668 - acc: 0.450 - ETA: 2s - loss: 8.9971 - acc: 0.422 - ETA: 2s - loss: 9.3214 - acc: 0.403 - ETA: 2s - loss: 9.3701 - acc: 0.391 - ETA: 2s - loss: 8.9845 - acc: 0.416 - ETA: 1s - loss: 9.1167 - acc: 0.408 - ETA: 1s - loss: 9.1586 - acc: 0.403 - ETA: 1s - loss: 9.1436 - acc: 0.403 - ETA: 1s - loss: 9.1409 - acc: 0.401 - ETA: 1s - loss: 9.1657 - acc: 0.400 - ETA: 1s - loss: 9.1197 - acc: 0.403 - ETA: 1s - loss: 9.0850 - acc: 0.405 - ETA: 1s - loss: 9.0716 - acc: 0.406 - ETA: 1s - loss: 9.0310 - acc: 0.407 - ETA: 1s - loss: 9.0636 - acc: 0.406 - ETA: 1s - loss: 9.0555 - acc: 0.405 - ETA: 1s - loss: 9.1154 - acc: 0.402 - ETA: 1s - loss: 9.1189 - acc: 0.403 - ETA: 1s - loss: 9.0768 - acc: 0.403 - ETA: 0s - loss: 9.0916 - acc: 0.402 - ETA: 0s - loss: 9.0966 - acc: 0.401 - ETA: 0s - loss: 9.0955 - acc: 0.401 - ETA: 0s - loss: 9.0418 - acc: 0.405 - ETA: 0s - loss: 9.0881 - acc: 0.401 - ETA: 0s - loss: 9.1110 - acc: 0.400 - ETA: 0s - loss: 9.1392 - acc: 0.399 - ETA: 0s - loss: 9.1508 - acc: 0.398 - ETA: 0s - loss: 9.1667 - acc: 0.396 - ETA: 0s - loss: 9.1807 - acc: 0.395 - ETA: 0s - loss: 9.1974 - acc: 0.394 - ETA: 0s - loss: 9.2242 - acc: 0.393 - ETA: 0s - loss: 9.2010 - acc: 0.394 - ETA: 0s - loss: 9.1965 - acc: 0.394 - ETA: 0s - loss: 9.1871 - acc: 0.394 - ETA: 0s - loss: 9.1782 - acc: 0.395 - ETA: 0s - loss: 9.1892 - acc: 0.394 - 2s 308us/step - loss: 9.1745 - acc: 0.3963 - val_loss: 9.5077 - val_acc: 0.3377
#
# Epoch 00005: val_loss improved from 9.62995 to 9.50773, saving model to D:\Machine_Learning\Udacity Courses\Machine Learning Engineer ND\machine-learning-master\projects\dog_breed_classifier_master\saved_models/weights.best.VGG16.hdf5
# Epoch 6/20
# 6680/6680 [==============================] - ETA: 1s - loss: 8.3013 - acc: 0.450 - ETA: 1s - loss: 8.6421 - acc: 0.435 - ETA: 1s - loss: 9.3746 - acc: 0.392 - ETA: 1s - loss: 9.4485 - acc: 0.389 - ETA: 1s - loss: 9.2107 - acc: 0.402 - ETA: 1s - loss: 9.2122 - acc: 0.401 - ETA: 1s - loss: 9.0515 - acc: 0.409 - ETA: 1s - loss: 9.0145 - acc: 0.413 - ETA: 1s - loss: 9.0567 - acc: 0.409 - ETA: 1s - loss: 9.1219 - acc: 0.406 - ETA: 1s - loss: 8.9841 - acc: 0.412 - ETA: 1s - loss: 8.9533 - acc: 0.415 - ETA: 1s - loss: 9.0365 - acc: 0.409 - ETA: 1s - loss: 8.9838 - acc: 0.412 - ETA: 1s - loss: 8.9986 - acc: 0.408 - ETA: 1s - loss: 8.9970 - acc: 0.408 - ETA: 1s - loss: 8.9756 - acc: 0.408 - ETA: 1s - loss: 8.9088 - acc: 0.412 - ETA: 0s - loss: 8.9454 - acc: 0.407 - ETA: 0s - loss: 8.9026 - acc: 0.410 - ETA: 0s - loss: 8.8669 - acc: 0.411 - ETA: 0s - loss: 8.8512 - acc: 0.412 - ETA: 0s - loss: 8.8877 - acc: 0.410 - ETA: 0s - loss: 8.8632 - acc: 0.411 - ETA: 0s - loss: 8.8639 - acc: 0.411 - ETA: 0s - loss: 8.8517 - acc: 0.412 - ETA: 0s - loss: 8.8611 - acc: 0.411 - ETA: 0s - loss: 8.8366 - acc: 0.413 - ETA: 0s - loss: 8.8362 - acc: 0.413 - ETA: 0s - loss: 8.8363 - acc: 0.413 - ETA: 0s - loss: 8.8311 - acc: 0.413 - ETA: 0s - loss: 8.8126 - acc: 0.415 - ETA: 0s - loss: 8.8282 - acc: 0.413 - ETA: 0s - loss: 8.8185 - acc: 0.413 - ETA: 0s - loss: 8.8243 - acc: 0.412 - 2s 293us/step - loss: 8.8295 - acc: 0.4121 - val_loss: 9.0643 - val_acc: 0.3521
#
# Epoch 00006: val_loss improved from 9.50773 to 9.06427, saving model to D:\Machine_Learning\Udacity Courses\Machine Learning Engineer ND\machine-learning-master\projects\dog_breed_classifier_master\saved_models/weights.best.VGG16.hdf5
# Epoch 7/20
# 6680/6680 [==============================] - ETA: 8s - loss: 8.6699 - acc: 0.400 - ETA: 3s - loss: 8.3652 - acc: 0.450 - ETA: 2s - loss: 8.3510 - acc: 0.450 - ETA: 2s - loss: 8.5709 - acc: 0.434 - ETA: 2s - loss: 8.6926 - acc: 0.425 - ETA: 2s - loss: 8.6311 - acc: 0.428 - ETA: 2s - loss: 8.5793 - acc: 0.429 - ETA: 1s - loss: 8.6166 - acc: 0.425 - ETA: 1s - loss: 8.6287 - acc: 0.423 - ETA: 1s - loss: 8.6061 - acc: 0.423 - ETA: 1s - loss: 8.6057 - acc: 0.424 - ETA: 1s - loss: 8.6094 - acc: 0.423 - ETA: 1s - loss: 8.5754 - acc: 0.426 - ETA: 1s - loss: 8.5378 - acc: 0.428 - ETA: 1s - loss: 8.4708 - acc: 0.430 - ETA: 1s - loss: 8.3753 - acc: 0.434 - ETA: 1s - loss: 8.3479 - acc: 0.436 - ETA: 1s - loss: 8.3159 - acc: 0.440 - ETA: 1s - loss: 8.3426 - acc: 0.439 - ETA: 1s - loss: 8.3587 - acc: 0.439 - ETA: 1s - loss: 8.3719 - acc: 0.437 - ETA: 0s - loss: 8.3658 - acc: 0.439 - ETA: 0s - loss: 8.3420 - acc: 0.441 - ETA: 0s - loss: 8.3531 - acc: 0.441 - ETA: 0s - loss: 8.3896 - acc: 0.439 - ETA: 0s - loss: 8.4047 - acc: 0.439 - ETA: 0s - loss: 8.4361 - acc: 0.437 - ETA: 0s - loss: 8.4333 - acc: 0.438 - ETA: 0s - loss: 8.4107 - acc: 0.438 - ETA: 0s - loss: 8.4333 - acc: 0.437 - ETA: 0s - loss: 8.4179 - acc: 0.437 - ETA: 0s - loss: 8.4184 - acc: 0.437 - ETA: 0s - loss: 8.4463 - acc: 0.436 - ETA: 0s - loss: 8.4512 - acc: 0.435 - ETA: 0s - loss: 8.4367 - acc: 0.436 - ETA: 0s - loss: 8.4441 - acc: 0.436 - ETA: 0s - loss: 8.4374 - acc: 0.437 - ETA: 0s - loss: 8.4690 - acc: 0.435 - 2s 315us/step - loss: 8.4760 - acc: 0.4352 - val_loss: 8.8437 - val_acc: 0.3737
#
# Epoch 00007: val_loss improved from 9.06427 to 8.84368, saving model to D:\Machine_Learning\Udacity Courses\Machine Learning Engineer ND\machine-learning-master\projects\dog_breed_classifier_master\saved_models/weights.best.VGG16.hdf5
# Epoch 8/20
# 6680/6680 [==============================] - ETA: 5s - loss: 9.1747 - acc: 0.400 - ETA: 2s - loss: 8.7722 - acc: 0.425 - ETA: 2s - loss: 8.4002 - acc: 0.452 - ETA: 1s - loss: 8.4110 - acc: 0.455 - ETA: 1s - loss: 8.4772 - acc: 0.454 - ETA: 1s - loss: 8.3930 - acc: 0.459 - ETA: 1s - loss: 8.3717 - acc: 0.462 - ETA: 1s - loss: 8.4410 - acc: 0.454 - ETA: 1s - loss: 8.4396 - acc: 0.454 - ETA: 1s - loss: 8.4227 - acc: 0.453 - ETA: 1s - loss: 8.3558 - acc: 0.455 - ETA: 1s - loss: 8.4088 - acc: 0.452 - ETA: 1s - loss: 8.4170 - acc: 0.453 - ETA: 1s - loss: 8.4641 - acc: 0.451 - ETA: 1s - loss: 8.4313 - acc: 0.454 - ETA: 1s - loss: 8.4198 - acc: 0.455 - ETA: 1s - loss: 8.4056 - acc: 0.456 - ETA: 0s - loss: 8.3878 - acc: 0.457 - ETA: 0s - loss: 8.3301 - acc: 0.461 - ETA: 0s - loss: 8.2877 - acc: 0.463 - ETA: 0s - loss: 8.2819 - acc: 0.463 - ETA: 0s - loss: 8.3224 - acc: 0.459 - ETA: 0s - loss: 8.3106 - acc: 0.460 - ETA: 0s - loss: 8.3184 - acc: 0.459 - ETA: 0s - loss: 8.2831 - acc: 0.462 - ETA: 0s - loss: 8.2712 - acc: 0.463 - ETA: 0s - loss: 8.2873 - acc: 0.462 - ETA: 0s - loss: 8.3245 - acc: 0.459 - ETA: 0s - loss: 8.3442 - acc: 0.458 - ETA: 0s - loss: 8.3255 - acc: 0.458 - ETA: 0s - loss: 8.2950 - acc: 0.461 - ETA: 0s - loss: 8.2879 - acc: 0.461 - ETA: 0s - loss: 8.3290 - acc: 0.458 - ETA: 0s - loss: 8.3360 - acc: 0.458 - 2s 293us/step - loss: 8.3562 - acc: 0.4567 - val_loss: 8.8757 - val_acc: 0.3713
#
# Epoch 00008: val_loss did not improve from 8.84368
# Epoch 9/20
# 6680/6680 [==============================] - ETA: 1s - loss: 8.8864 - acc: 0.450 - ETA: 1s - loss: 8.2291 - acc: 0.478 - ETA: 1s - loss: 8.2736 - acc: 0.477 - ETA: 1s - loss: 8.0111 - acc: 0.490 - ETA: 1s - loss: 8.1097 - acc: 0.484 - ETA: 1s - loss: 8.2186 - acc: 0.478 - ETA: 1s - loss: 8.2316 - acc: 0.474 - ETA: 1s - loss: 8.1434 - acc: 0.478 - ETA: 1s - loss: 8.1408 - acc: 0.478 - ETA: 1s - loss: 8.1403 - acc: 0.480 - ETA: 1s - loss: 8.1604 - acc: 0.479 - ETA: 1s - loss: 8.2559 - acc: 0.473 - ETA: 1s - loss: 8.2988 - acc: 0.469 - ETA: 0s - loss: 8.2661 - acc: 0.470 - ETA: 0s - loss: 8.2166 - acc: 0.474 - ETA: 0s - loss: 8.2587 - acc: 0.470 - ETA: 0s - loss: 8.2284 - acc: 0.472 - ETA: 0s - loss: 8.2415 - acc: 0.471 - ETA: 0s - loss: 8.2295 - acc: 0.472 - ETA: 0s - loss: 8.2700 - acc: 0.469 - ETA: 0s - loss: 8.2577 - acc: 0.470 - ETA: 0s - loss: 8.2826 - acc: 0.468 - ETA: 0s - loss: 8.2644 - acc: 0.469 - ETA: 0s - loss: 8.2620 - acc: 0.469 - ETA: 0s - loss: 8.2739 - acc: 0.467 - ETA: 0s - loss: 8.2640 - acc: 0.467 - ETA: 0s - loss: 8.2881 - acc: 0.466 - ETA: 0s - loss: 8.2873 - acc: 0.466 - ETA: 0s - loss: 8.3013 - acc: 0.465 - ETA: 0s - loss: 8.2938 - acc: 0.465 - ETA: 0s - loss: 8.2888 - acc: 0.465 - ETA: 0s - loss: 8.2802 - acc: 0.465 - 2s 269us/step - loss: 8.2848 - acc: 0.4654 - val_loss: 8.7734 - val_acc: 0.3737
# Epoch 00009: val_loss improved from 8.84368 to 8.77335, saving model to D:\Machine_Learning\Udacity Courses\Machine Learning Engineer ND\machine-learning-master\projects\dog_breed_classifier_master\saved_models/weights.best.VGG16.hdf5
# Epoch 10/20
# 6680/6680 [==============================] - ETA: 6s - loss: 7.2886 - acc: 0.550 - ETA: 2s - loss: 8.0727 - acc: 0.475 - ETA: 2s - loss: 8.5851 - acc: 0.452 - ETA: 2s - loss: 8.6136 - acc: 0.448 - ETA: 2s - loss: 8.5404 - acc: 0.451 - ETA: 1s - loss: 8.2707 - acc: 0.465 - ETA: 1s - loss: 8.2687 - acc: 0.465 - ETA: 1s - loss: 8.4456 - acc: 0.455 - ETA: 1s - loss: 8.5788 - acc: 0.446 - ETA: 1s - loss: 8.5667 - acc: 0.446 - ETA: 1s - loss: 8.5717 - acc: 0.445 - ETA: 1s - loss: 8.4761 - acc: 0.451 - ETA: 1s - loss: 8.3303 - acc: 0.459 - ETA: 1s - loss: 8.3286 - acc: 0.460 - ETA: 1s - loss: 8.2712 - acc: 0.462 - ETA: 1s - loss: 8.1979 - acc: 0.467 - ETA: 1s - loss: 8.1918 - acc: 0.467 - ETA: 1s - loss: 8.1619 - acc: 0.469 - ETA: 0s - loss: 8.1827 - acc: 0.467 - ETA: 0s - loss: 8.1390 - acc: 0.470 - ETA: 0s - loss: 8.1484 - acc: 0.468 - ETA: 0s - loss: 8.1667 - acc: 0.466 - ETA: 0s - loss: 8.1320 - acc: 0.467 - ETA: 0s - loss: 8.1216 - acc: 0.468 - ETA: 0s - loss: 8.1074 - acc: 0.468 - ETA: 0s - loss: 8.1164 - acc: 0.467 - ETA: 0s - loss: 8.1193 - acc: 0.467 - ETA: 0s - loss: 8.1193 - acc: 0.467 - ETA: 0s - loss: 8.1338 - acc: 0.466 - ETA: 0s - loss: 8.1130 - acc: 0.467 - ETA: 0s - loss: 8.0977 - acc: 0.468 - ETA: 0s - loss: 8.0881 - acc: 0.468 - ETA: 0s - loss: 8.0835 - acc: 0.468 - ETA: 0s - loss: 8.0773 - acc: 0.469 - ETA: 0s - loss: 8.0684 - acc: 0.469 - 2s 305us/step - loss: 8.0722 - acc: 0.4683 - val_loss: 8.6532 - val_acc: 0.3832
#
# Epoch 00010: val_loss improved from 8.77335 to 8.65320, saving model to D:\Machine_Learning\Udacity Courses\Machine Learning Engineer ND\machine-learning-master\projects\dog_breed_classifier_master\saved_models/weights.best.VGG16.hdf5
# Epoch 11/20
# 6680/6680 [==============================] - ETA: 1s - loss: 4.6090 - acc: 0.650 - ETA: 1s - loss: 7.6891 - acc: 0.485 - ETA: 1s - loss: 8.0678 - acc: 0.457 - ETA: 1s - loss: 8.1207 - acc: 0.460 - ETA: 1s - loss: 7.9746 - acc: 0.473 - ETA: 1s - loss: 7.8788 - acc: 0.482 - ETA: 1s - loss: 7.9639 - acc: 0.473 - ETA: 1s - loss: 7.9126 - acc: 0.477 - ETA: 1s - loss: 7.8695 - acc: 0.480 - ETA: 1s - loss: 7.8617 - acc: 0.481 - ETA: 1s - loss: 7.7596 - acc: 0.487 - ETA: 1s - loss: 7.7276 - acc: 0.490 - ETA: 1s - loss: 7.7343 - acc: 0.490 - ETA: 1s - loss: 7.7396 - acc: 0.488 - ETA: 1s - loss: 7.7304 - acc: 0.489 - ETA: 0s - loss: 7.7466 - acc: 0.487 - ETA: 0s - loss: 7.7622 - acc: 0.487 - ETA: 0s - loss: 7.7742 - acc: 0.487 - ETA: 0s - loss: 7.7626 - acc: 0.488 - ETA: 0s - loss: 7.7577 - acc: 0.489 - ETA: 0s - loss: 7.7804 - acc: 0.488 - ETA: 0s - loss: 7.7565 - acc: 0.490 - ETA: 0s - loss: 7.7370 - acc: 0.492 - ETA: 0s - loss: 7.7406 - acc: 0.491 - ETA: 0s - loss: 7.7329 - acc: 0.490 - ETA: 0s - loss: 7.7577 - acc: 0.489 - ETA: 0s - loss: 7.7760 - acc: 0.487 - ETA: 0s - loss: 7.7758 - acc: 0.486 - ETA: 0s - loss: 7.7491 - acc: 0.488 - ETA: 0s - loss: 7.7578 - acc: 0.487 - ETA: 0s - loss: 7.7381 - acc: 0.488 - ETA: 0s - loss: 7.7374 - acc: 0.489 - 2s 283us/step - loss: 7.7213 - acc: 0.4903 - val_loss: 8.1607 - val_acc: 0.4120
#
# Epoch 00011: val_loss improved from 8.65320 to 8.16070, saving model to D:\Machine_Learning\Udacity Courses\Machine Learning Engineer ND\machine-learning-master\projects\dog_breed_classifier_master\saved_models/weights.best.VGG16.hdf5
# Epoch 12/20
# 6680/6680 [==============================] - ETA: 1s - loss: 8.0781 - acc: 0.500 - ETA: 1s - loss: 7.8075 - acc: 0.495 - ETA: 1s - loss: 7.3618 - acc: 0.520 - ETA: 1s - loss: 7.2770 - acc: 0.524 - ETA: 1s - loss: 7.2037 - acc: 0.527 - ETA: 1s - loss: 7.3720 - acc: 0.516 - ETA: 1s - loss: 7.6302 - acc: 0.501 - ETA: 1s - loss: 7.7372 - acc: 0.492 - ETA: 1s - loss: 7.7301 - acc: 0.490 - ETA: 1s - loss: 7.7030 - acc: 0.493 - ETA: 1s - loss: 7.7965 - acc: 0.487 - ETA: 1s - loss: 7.7333 - acc: 0.489 - ETA: 1s - loss: 7.8354 - acc: 0.483 - ETA: 1s - loss: 7.8714 - acc: 0.480 - ETA: 1s - loss: 7.7880 - acc: 0.486 - ETA: 0s - loss: 7.6828 - acc: 0.493 - ETA: 0s - loss: 7.7298 - acc: 0.490 - ETA: 0s - loss: 7.7792 - acc: 0.486 - ETA: 0s - loss: 7.7807 - acc: 0.487 - ETA: 0s - loss: 7.8056 - acc: 0.486 - ETA: 0s - loss: 7.7881 - acc: 0.487 - ETA: 0s - loss: 7.7507 - acc: 0.489 - ETA: 0s - loss: 7.7033 - acc: 0.493 - ETA: 0s - loss: 7.6909 - acc: 0.494 - ETA: 0s - loss: 7.7068 - acc: 0.494 - ETA: 0s - loss: 7.6912 - acc: 0.495 - ETA: 0s - loss: 7.6475 - acc: 0.497 - ETA: 0s - loss: 7.6047 - acc: 0.500 - ETA: 0s - loss: 7.5848 - acc: 0.502 - ETA: 0s - loss: 7.5813 - acc: 0.502 - ETA: 0s - loss: 7.5909 - acc: 0.501 - ETA: 0s - loss: 7.5437 - acc: 0.504 - 2s 279us/step - loss: 7.5171 - acc: 0.5067 - val_loss: 8.1314 - val_acc: 0.4180
#
# Epoch 00012: val_loss improved from 8.16070 to 8.13144, saving model to D:\Machine_Learning\Udacity Courses\Machine Learning Engineer ND\machine-learning-master\projects\dog_breed_classifier_master\saved_models/weights.best.VGG16.hdf5
# Epoch 13/20
# 6680/6680 [==============================] - ETA: 6s - loss: 8.5302 - acc: 0.450 - ETA: 3s - loss: 6.9858 - acc: 0.564 - ETA: 2s - loss: 7.4145 - acc: 0.533 - ETA: 2s - loss: 7.3415 - acc: 0.533 - ETA: 2s - loss: 7.3180 - acc: 0.533 - ETA: 1s - loss: 7.3778 - acc: 0.532 - ETA: 1s - loss: 7.3753 - acc: 0.530 - ETA: 1s - loss: 7.5229 - acc: 0.521 - ETA: 1s - loss: 7.5379 - acc: 0.521 - ETA: 1s - loss: 7.5459 - acc: 0.520 - ETA: 1s - loss: 7.5414 - acc: 0.519 - ETA: 1s - loss: 7.4426 - acc: 0.522 - ETA: 1s - loss: 7.4531 - acc: 0.521 - ETA: 1s - loss: 7.3817 - acc: 0.526 - ETA: 1s - loss: 7.3977 - acc: 0.525 - ETA: 1s - loss: 7.3621 - acc: 0.527 - ETA: 1s - loss: 7.4250 - acc: 0.523 - ETA: 1s - loss: 7.4980 - acc: 0.518 - ETA: 0s - loss: 7.5161 - acc: 0.517 - ETA: 0s - loss: 7.5107 - acc: 0.517 - ETA: 0s - loss: 7.5236 - acc: 0.516 - ETA: 0s - loss: 7.5082 - acc: 0.517 - ETA: 0s - loss: 7.5067 - acc: 0.517 - ETA: 0s - loss: 7.5158 - acc: 0.517 - ETA: 0s - loss: 7.4640 - acc: 0.520 - ETA: 0s - loss: 7.4328 - acc: 0.521 - ETA: 0s - loss: 7.4339 - acc: 0.521 - ETA: 0s - loss: 7.4354 - acc: 0.521 - ETA: 0s - loss: 7.4493 - acc: 0.520 - ETA: 0s - loss: 7.4285 - acc: 0.522 - ETA: 0s - loss: 7.4237 - acc: 0.522 - ETA: 0s - loss: 7.4430 - acc: 0.521 - ETA: 0s - loss: 7.4182 - acc: 0.522 - ETA: 0s - loss: 7.4158 - acc: 0.522 - ETA: 0s - loss: 7.4271 - acc: 0.520 - 2s 302us/step - loss: 7.4245 - acc: 0.5207 - val_loss: 8.0081 - val_acc: 0.4299
#
# Epoch 00013: val_loss improved from 8.13144 to 8.00809, saving model to D:\Machine_Learning\Udacity Courses\Machine Learning Engineer ND\machine-learning-master\projects\dog_breed_classifier_master\saved_models/weights.best.VGG16.hdf5
# Epoch 14/20
# 6680/6680 [==============================] - ETA: 1s - loss: 8.8681 - acc: 0.450 - ETA: 1s - loss: 7.8935 - acc: 0.495 - ETA: 1s - loss: 7.4405 - acc: 0.525 - ETA: 1s - loss: 7.4638 - acc: 0.525 - ETA: 1s - loss: 7.5274 - acc: 0.519 - ETA: 1s - loss: 7.4231 - acc: 0.526 - ETA: 1s - loss: 7.5785 - acc: 0.517 - ETA: 1s - loss: 7.5026 - acc: 0.522 - ETA: 1s - loss: 7.6262 - acc: 0.515 - ETA: 1s - loss: 7.4748 - acc: 0.523 - ETA: 1s - loss: 7.5148 - acc: 0.520 - ETA: 1s - loss: 7.5124 - acc: 0.520 - ETA: 1s - loss: 7.5292 - acc: 0.518 - ETA: 1s - loss: 7.5004 - acc: 0.520 - ETA: 1s - loss: 7.5113 - acc: 0.520 - ETA: 0s - loss: 7.4850 - acc: 0.521 - ETA: 0s - loss: 7.4967 - acc: 0.520 - ETA: 0s - loss: 7.4604 - acc: 0.522 - ETA: 0s - loss: 7.4515 - acc: 0.523 - ETA: 0s - loss: 7.4240 - acc: 0.525 - ETA: 0s - loss: 7.4277 - acc: 0.525 - ETA: 0s - loss: 7.3986 - acc: 0.526 - ETA: 0s - loss: 7.3678 - acc: 0.529 - ETA: 0s - loss: 7.3539 - acc: 0.530 - ETA: 0s - loss: 7.3505 - acc: 0.530 - ETA: 0s - loss: 7.3536 - acc: 0.530 - ETA: 0s - loss: 7.3493 - acc: 0.529 - ETA: 0s - loss: 7.3320 - acc: 0.530 - ETA: 0s - loss: 7.3377 - acc: 0.529 - ETA: 0s - loss: 7.3423 - acc: 0.529 - ETA: 0s - loss: 7.3234 - acc: 0.530 - ETA: 0s - loss: 7.3192 - acc: 0.530 - ETA: 0s - loss: 7.3097 - acc: 0.530 - 2s 282us/step - loss: 7.3050 - acc: 0.5302 - val_loss: 8.0293 - val_acc: 0.4299
# Epoch 00014: val_loss did not improve from 8.00809
# Epoch 15/20
# 6680/6680 [==============================] - ETA: 2s - loss: 9.2290 - acc: 0.350 - ETA: 1s - loss: 7.3869 - acc: 0.530 - ETA: 1s - loss: 7.0007 - acc: 0.560 - ETA: 1s - loss: 7.2813 - acc: 0.541 - ETA: 1s - loss: 7.4192 - acc: 0.533 - ETA: 1s - loss: 7.3287 - acc: 0.538 - ETA: 1s - loss: 7.2532 - acc: 0.543 - ETA: 1s - loss: 7.3707 - acc: 0.535 - ETA: 1s - loss: 7.2500 - acc: 0.541 - ETA: 1s - loss: 7.2921 - acc: 0.539 - ETA: 1s - loss: 7.3625 - acc: 0.535 - ETA: 1s - loss: 7.3876 - acc: 0.533 - ETA: 1s - loss: 7.3794 - acc: 0.534 - ETA: 1s - loss: 7.3379 - acc: 0.537 - ETA: 0s - loss: 7.3230 - acc: 0.537 - ETA: 0s - loss: 7.3311 - acc: 0.537 - ETA: 0s - loss: 7.3271 - acc: 0.537 - ETA: 0s - loss: 7.3102 - acc: 0.538 - ETA: 0s - loss: 7.3025 - acc: 0.538 - ETA: 0s - loss: 7.3080 - acc: 0.537 - ETA: 0s - loss: 7.2939 - acc: 0.538 - ETA: 0s - loss: 7.2837 - acc: 0.539 - ETA: 0s - loss: 7.2747 - acc: 0.539 - ETA: 0s - loss: 7.2865 - acc: 0.538 - ETA: 0s - loss: 7.3046 - acc: 0.537 - ETA: 0s - loss: 7.2786 - acc: 0.539 - ETA: 0s - loss: 7.2821 - acc: 0.538 - ETA: 0s - loss: 7.2684 - acc: 0.539 - ETA: 0s - loss: 7.2741 - acc: 0.539 - ETA: 0s - loss: 7.2841 - acc: 0.538 - ETA: 0s - loss: 7.2987 - acc: 0.537 - ETA: 0s - loss: 7.2764 - acc: 0.539 - 2s 276us/step - loss: 7.2691 - acc: 0.5395 - val_loss: 8.0166 - val_acc: 0.4395
#
# Epoch 00015: val_loss did not improve from 8.00809
# Epoch 16/20
# 6680/6680 [==============================] - ETA: 1s - loss: 8.0669 - acc: 0.500 - ETA: 1s - loss: 7.9280 - acc: 0.504 - ETA: 1s - loss: 7.5852 - acc: 0.528 - ETA: 1s - loss: 7.3691 - acc: 0.538 - ETA: 1s - loss: 7.3904 - acc: 0.537 - ETA: 1s - loss: 7.2769 - acc: 0.544 - ETA: 1s - loss: 7.4659 - acc: 0.531 - ETA: 1s - loss: 7.4043 - acc: 0.535 - ETA: 1s - loss: 7.3510 - acc: 0.538 - ETA: 1s - loss: 7.4164 - acc: 0.533 - ETA: 1s - loss: 7.3034 - acc: 0.540 - ETA: 1s - loss: 7.2878 - acc: 0.540 - ETA: 1s - loss: 7.2780 - acc: 0.541 - ETA: 0s - loss: 7.2277 - acc: 0.544 - ETA: 0s - loss: 7.2390 - acc: 0.543 - ETA: 0s - loss: 7.2809 - acc: 0.541 - ETA: 0s - loss: 7.3503 - acc: 0.536 - ETA: 0s - loss: 7.3415 - acc: 0.536 - ETA: 0s - loss: 7.3887 - acc: 0.534 - ETA: 0s - loss: 7.3333 - acc: 0.537 - ETA: 0s - loss: 7.3199 - acc: 0.538 - ETA: 0s - loss: 7.3419 - acc: 0.537 - ETA: 0s - loss: 7.3429 - acc: 0.537 - ETA: 0s - loss: 7.3584 - acc: 0.536 - ETA: 0s - loss: 7.3495 - acc: 0.536 - ETA: 0s - loss: 7.3225 - acc: 0.538 - ETA: 0s - loss: 7.3118 - acc: 0.539 - ETA: 0s - loss: 7.3014 - acc: 0.540 - ETA: 0s - loss: 7.2986 - acc: 0.539 - ETA: 0s - loss: 7.2792 - acc: 0.540 - ETA: 0s - loss: 7.2511 - acc: 0.542 - 2s 270us/step - loss: 7.2515 - acc: 0.5425 - val_loss: 7.9716 - val_acc: 0.4467
#
# Epoch 00016: val_loss improved from 8.00809 to 7.97164, saving model to D:\Machine_Learning\Udacity Courses\Machine Learning Engineer ND\machine-learning-master\projects\dog_breed_classifier_master\saved_models/weights.best.VGG16.hdf5
# Epoch 17/20
# 6680/6680 [==============================] - ETA: 2s - loss: 6.4853 - acc: 0.600 - ETA: 1s - loss: 7.7949 - acc: 0.509 - ETA: 1s - loss: 7.3136 - acc: 0.540 - ETA: 1s - loss: 7.1858 - acc: 0.550 - ETA: 1s - loss: 7.4641 - acc: 0.532 - ETA: 1s - loss: 7.5087 - acc: 0.530 - ETA: 1s - loss: 7.4847 - acc: 0.530 - ETA: 1s - loss: 7.4636 - acc: 0.532 - ETA: 1s - loss: 7.4615 - acc: 0.532 - ETA: 1s - loss: 7.3766 - acc: 0.538 - ETA: 1s - loss: 7.3251 - acc: 0.540 - ETA: 1s - loss: 7.3512 - acc: 0.538 - ETA: 1s - loss: 7.3702 - acc: 0.536 - ETA: 1s - loss: 7.3809 - acc: 0.535 - ETA: 1s - loss: 7.3448 - acc: 0.537 - ETA: 1s - loss: 7.3446 - acc: 0.537 - ETA: 0s - loss: 7.3289 - acc: 0.539 - ETA: 0s - loss: 7.3549 - acc: 0.537 - ETA: 0s - loss: 7.3546 - acc: 0.537 - ETA: 0s - loss: 7.3233 - acc: 0.539 - ETA: 0s - loss: 7.3201 - acc: 0.539 - ETA: 0s - loss: 7.2985 - acc: 0.541 - ETA: 0s - loss: 7.2874 - acc: 0.541 - ETA: 0s - loss: 7.2632 - acc: 0.543 - ETA: 0s - loss: 7.3113 - acc: 0.540 - ETA: 0s - loss: 7.3151 - acc: 0.539 - ETA: 0s - loss: 7.2740 - acc: 0.542 - ETA: 0s - loss: 7.2683 - acc: 0.542 - ETA: 0s - loss: 7.2421 - acc: 0.543 - ETA: 0s - loss: 7.2220 - acc: 0.544 - ETA: 0s - loss: 7.2210 - acc: 0.544 - ETA: 0s - loss: 7.2234 - acc: 0.544 - ETA: 0s - loss: 7.2179 - acc: 0.544 - 2s 296us/step - loss: 7.2230 - acc: 0.5436 - val_loss: 7.9745 - val_acc: 0.4371
#
# Epoch 00017: val_loss did not improve from 7.97164
# Epoch 18/20
# 6680/6680 [==============================] - ETA: 1s - loss: 7.2534 - acc: 0.550 - ETA: 1s - loss: 7.3801 - acc: 0.529 - ETA: 1s - loss: 7.3736 - acc: 0.527 - ETA: 1s - loss: 7.0696 - acc: 0.547 - ETA: 1s - loss: 6.9150 - acc: 0.558 - ETA: 1s - loss: 6.7786 - acc: 0.567 - ETA: 1s - loss: 6.7916 - acc: 0.566 - ETA: 1s - loss: 6.7524 - acc: 0.564 - ETA: 1s - loss: 6.7244 - acc: 0.566 - ETA: 1s - loss: 6.8861 - acc: 0.557 - ETA: 1s - loss: 6.9321 - acc: 0.554 - ETA: 1s - loss: 6.9248 - acc: 0.555 - ETA: 1s - loss: 7.0010 - acc: 0.550 - ETA: 1s - loss: 7.0284 - acc: 0.548 - ETA: 1s - loss: 7.0192 - acc: 0.549 - ETA: 1s - loss: 7.0135 - acc: 0.549 - ETA: 0s - loss: 7.0090 - acc: 0.549 - ETA: 0s - loss: 7.0684 - acc: 0.546 - ETA: 0s - loss: 7.0776 - acc: 0.545 - ETA: 0s - loss: 7.1009 - acc: 0.544 - ETA: 0s - loss: 7.1265 - acc: 0.542 - ETA: 0s - loss: 7.1466 - acc: 0.541 - ETA: 0s - loss: 7.1697 - acc: 0.540 - ETA: 0s - loss: 7.1161 - acc: 0.544 - ETA: 0s - loss: 7.0802 - acc: 0.546 - ETA: 0s - loss: 7.0653 - acc: 0.548 - ETA: 0s - loss: 7.0743 - acc: 0.547 - ETA: 0s - loss: 7.1038 - acc: 0.545 - ETA: 0s - loss: 7.0952 - acc: 0.546 - ETA: 0s - loss: 7.0943 - acc: 0.546 - ETA: 0s - loss: 7.0988 - acc: 0.546 - ETA: 0s - loss: 7.0743 - acc: 0.547 - ETA: 0s - loss: 7.0707 - acc: 0.548 - 2s 284us/step - loss: 7.0582 - acc: 0.5488 - val_loss: 7.7647 - val_acc: 0.4599
#
# Epoch 00018: val_loss improved from 7.97164 to 7.76474, saving model to D:\Machine_Learning\Udacity Courses\Machine Learning Engineer ND\machine-learning-master\projects\dog_breed_classifier_master\saved_models/weights.best.VGG16.hdf5
# Epoch 19/20
# 6680/6680 [==============================] - ETA: 6s - loss: 6.4478 - acc: 0.600 - ETA: 2s - loss: 8.5362 - acc: 0.465 - ETA: 1s - loss: 7.4386 - acc: 0.531 - ETA: 1s - loss: 7.0983 - acc: 0.553 - ETA: 1s - loss: 7.0378 - acc: 0.557 - ETA: 1s - loss: 6.9563 - acc: 0.562 - ETA: 1s - loss: 6.9099 - acc: 0.563 - ETA: 1s - loss: 6.7665 - acc: 0.572 - ETA: 1s - loss: 6.7650 - acc: 0.573 - ETA: 1s - loss: 6.9092 - acc: 0.565 - ETA: 1s - loss: 6.8407 - acc: 0.569 - ETA: 1s - loss: 6.8706 - acc: 0.567 - ETA: 1s - loss: 6.9154 - acc: 0.564 - ETA: 1s - loss: 6.9003 - acc: 0.563 - ETA: 1s - loss: 6.9242 - acc: 0.562 - ETA: 0s - loss: 6.9954 - acc: 0.558 - ETA: 0s - loss: 6.9997 - acc: 0.557 - ETA: 0s - loss: 7.0081 - acc: 0.556 - ETA: 0s - loss: 7.0192 - acc: 0.555 - ETA: 0s - loss: 7.0021 - acc: 0.556 - ETA: 0s - loss: 7.0141 - acc: 0.555 - ETA: 0s - loss: 6.9634 - acc: 0.558 - ETA: 0s - loss: 6.9200 - acc: 0.560 - ETA: 0s - loss: 6.9218 - acc: 0.559 - ETA: 0s - loss: 6.9459 - acc: 0.557 - ETA: 0s - loss: 6.9484 - acc: 0.557 - ETA: 0s - loss: 6.9243 - acc: 0.558 - ETA: 0s - loss: 6.8934 - acc: 0.559 - ETA: 0s - loss: 6.8794 - acc: 0.560 - ETA: 0s - loss: 6.9162 - acc: 0.557 - ETA: 0s - loss: 6.9145 - acc: 0.557 - ETA: 0s - loss: 6.9137 - acc: 0.557 - ETA: 0s - loss: 6.8960 - acc: 0.558 - 2s 279us/step - loss: 6.8944 - acc: 0.5587 - val_loss: 7.5366 - val_acc: 0.4587
#
# Epoch 00019: val_loss improved from 7.76474 to 7.53657, saving model to D:\Machine_Learning\Udacity Courses\Machine Learning Engineer ND\machine-learning-master\projects\dog_breed_classifier_master\saved_models/weights.best.VGG16.hdf5
# Epoch 20/20
# 6680/6680 [==============================] - ETA: 1s - loss: 7.2553 - acc: 0.550 - ETA: 1s - loss: 6.7957 - acc: 0.572 - ETA: 1s - loss: 6.8535 - acc: 0.565 - ETA: 1s - loss: 6.5699 - acc: 0.581 - ETA: 1s - loss: 6.5030 - acc: 0.586 - ETA: 1s - loss: 6.4999 - acc: 0.588 - ETA: 1s - loss: 6.5451 - acc: 0.585 - ETA: 1s - loss: 6.6115 - acc: 0.580 - ETA: 1s - loss: 6.6337 - acc: 0.579 - ETA: 1s - loss: 6.6650 - acc: 0.577 - ETA: 1s - loss: 6.6044 - acc: 0.581 - ETA: 1s - loss: 6.6837 - acc: 0.575 - ETA: 1s - loss: 6.6715 - acc: 0.577 - ETA: 1s - loss: 6.6401 - acc: 0.578 - ETA: 1s - loss: 6.6373 - acc: 0.577 - ETA: 1s - loss: 6.5901 - acc: 0.579 - ETA: 1s - loss: 6.5322 - acc: 0.582 - ETA: 0s - loss: 6.5370 - acc: 0.581 - ETA: 0s - loss: 6.5456 - acc: 0.580 - ETA: 0s - loss: 6.5051 - acc: 0.582 - ETA: 0s - loss: 6.5701 - acc: 0.578 - ETA: 0s - loss: 6.5818 - acc: 0.577 - ETA: 0s - loss: 6.5954 - acc: 0.576 - ETA: 0s - loss: 6.5931 - acc: 0.576 - ETA: 0s - loss: 6.5938 - acc: 0.575 - ETA: 0s - loss: 6.5827 - acc: 0.575 - ETA: 0s - loss: 6.6021 - acc: 0.574 - ETA: 0s - loss: 6.5986 - acc: 0.574 - ETA: 0s - loss: 6.5944 - acc: 0.574 - ETA: 0s - loss: 6.5839 - acc: 0.574 - ETA: 0s - loss: 6.5583 - acc: 0.576 - ETA: 0s - loss: 6.5369 - acc: 0.577 - ETA: 0s - loss: 6.5757 - acc: 0.574 - 2s 284us/step - loss: 6.5779 - acc: 0.5747 - val_loss: 7.3217 - val_acc: 0.4659
#
# Epoch 00020: val_loss improved from 7.53657 to 7.32172, saving model to D:\Machine_Learning\Udacity Courses\Machine Learning Engineer ND\machine-learning-master\projects\dog_breed_classifier_master\saved_models/weights.best.VGG16.hdf5

# %% [markdown]
# ### Load the Model with the Best Validation Loss

# %%
VGG16_model.load_weights(r'D:\Machine_Learning\Udacity Courses\Machine Learning Engineer ND\machine-learning-master\projects\dog_breed_classifier_master\saved_models/weights.best.VGG16.hdf5')

# %% [markdown]
# ### Test the Model
#
# Now, we can use the CNN to test how well it identifies breed within our test dataset of dog images.  We print the test accuracy below.

# %%
# get index of predicted dog breed for each image in test set
VGG16_predictions = [np.argmax(VGG16_model.predict(np.expand_dims(feature, axis=0))) for feature in test_VGG16]

# report test accuracy
test_accuracy = 100*np.sum(np.array(VGG16_predictions)==np.argmax(test_targets, axis=1))/len(VGG16_predictions)
print('Test accuracy: %.4f%%' % test_accuracy)
# Out:
# Test accuracy: 46.1722%

# %% [markdown]
# ### Predict Dog Breed with the Model

# %%
from extract_bottleneck_features import *

def VGG16_predict_breed(img_path):
    # extract bottleneck features
    bottleneck_feature = extract_VGG16(path_to_tensor(img_path))
    # obtain predicted vector
    predicted_vector = VGG16_model.predict(bottleneck_feature)
    # return dog breed that is predicted by the model
    return dog_names[np.argmax(predicted_vector)]

# %% [markdown]
# ---
# <a id='step5'></a>
# ## Step 5: Create a CNN to Classify Dog Breeds (using Transfer Learning)
#
# You will now use transfer learning to create a CNN that can identify dog breed from images.  Your CNN must attain at least 60% accuracy on the test set.
#
# In Step 4, we used transfer learning to create a CNN using VGG-16 bottleneck features.  In this section, you must use the bottleneck features from a different pre-trained model.  To make things easier for you, we have pre-computed the features for all of the networks that are currently available in Keras.  These are already in the workspace, at /data/bottleneck_features.  If you wish to download them on a different machine, they can be found at:
# - [VGG-19](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/DogVGG19Data.npz) bottleneck features
# - [ResNet-50](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/DogResnet50Data.npz) bottleneck features
# - [Inception](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/DogInceptionV3Data.npz) bottleneck features
# - [Xception](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/DogXceptionData.npz) bottleneck features
#
# The files are encoded as such:
#
#     Dog{network}Data.npz
#
# where `{network}`, in the above filename, can be one of `VGG19`, `Resnet50`, `InceptionV3`, or `Xception`.
#
# The above architectures are downloaded and stored for you in the `/data/bottleneck_features/` folder.
#
# This means the following will be in the `/data/bottleneck_features/` folder:
#
# `DogVGG19Data.npz`
# `DogResnet50Data.npz`
# `DogInceptionV3Data.npz`
# `DogXceptionData.npz`
#
#
#
# ### (IMPLEMENTATION) Obtain Bottleneck Features
#
# In the code block below, extract the bottleneck features corresponding to the train, test, and validation sets by running the following:
#
#     bottleneck_features = np.load('/data/bottleneck_features/Dog{network}Data.npz')
#     train_{network} = bottleneck_features['train']
#     valid_{network} = bottleneck_features['valid']
#     test_{network} = bottleneck_features['test']

# %%
### TODO: Obtain bottleneck features from another pre-trained CNN.
bottleneck_features = np.load(r'D:\Machine_Learning\Udacity Courses\Machine Learning Engineer ND\machine-learning-master\projects\dog_breed_classifier_master\bottleneck_features/DogResnet50Data.npz')
train_Resnet50 = bottleneck_features['train']
valid_Resnet50 = bottleneck_features['valid']
test_Resnet50 = bottleneck_features['test']

print(train_Resnet50.shape) # 6680 samples 1x1x2048  |----- . 
print(train_Resnet50.shape[1:])
# Out:
# (6680, 1, 1, 2048)
# (1, 1, 2048)

# %% [markdown]
# ### (IMPLEMENTATION) Model Architecture
#
# Create a CNN to classify dog breed.  At the end of your code cell block, summarize the layers of your model by executing the line:
#
#         <your model's name>.summary()
#
# __Question 5:__ Outline the steps you took to get to your final CNN architecture and your reasoning at each step.  Describe why you think the architecture is suitable for the current problem.
#
# __Answer:__
#
# I used the architecture of step 4 as reference adding a Dropout layer to reduce overfitting. After triying different dropout values, the chosen one has been 0.2 as it yields an accuracy on test data above 80%.

# %%
### TODO: Define your architecture
Resnet50_model = Sequential()
Resnet50_model.add(GlobalAveragePooling2D(input_shape=train_Resnet50.shape[1:]))
Resnet50_model.add(Dropout(0.2))
Resnet50_model.add(Dense(133, activation='softmax'))

Resnet50_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# global_average_pooling2d_4 ( (None, 2048)              0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 133)               272517
# =================================================================
# Total params: 272,517
# Trainable params: 272,517
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### (IMPLEMENTATION) Compile the Model

# %%
### TODO: Compile the model.
Resnet50_model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ### (IMPLEMENTATION) Train the Model
#
# Train your model in the code cell below.  Use model checkpointing to save the model that attains the best validation loss.
#
# You are welcome to [augment the training data](https://blog.keras.io/building-powerful-image-classification-models-using-very-little-data.html), but this is not a requirement.

# %%
### TODO: Train the model.
checkpointer = ModelCheckpoint(filepath='saved_models/weights.best.Resnet50.hdf5', 
                               verbose=1, save_best_only=True)

Resnet50_model.fit(train_Resnet50, train_targets, 
          validation_data=(valid_Resnet50, valid_targets),
          epochs=20, batch_size=20, callbacks=[checkpointer], verbose=1)
# Out:
# Train on 6680 samples, validate on 835 samples
# Epoch 1/20
# 6680/6680 [==============================] - ETA: 9:38 - loss: 5.6025 - acc: 0.050 - ETA: 1:13 - loss: 6.0463 - acc: 0.031 - ETA: 30s - loss: 5.3964 - acc: 0.081 - ETA: 21s - loss: 5.0721 - acc: 0.09 - ETA: 15s - loss: 4.6569 - acc: 0.13 - ETA: 11s - loss: 4.2794 - acc: 0.18 - ETA: 9s - loss: 4.0268 - acc: 0.2076 - ETA: 7s - loss: 3.7410 - acc: 0.248 - ETA: 6s - loss: 3.5601 - acc: 0.269 - ETA: 6s - loss: 3.4017 - acc: 0.292 - ETA: 5s - loss: 3.2582 - acc: 0.311 - ETA: 4s - loss: 3.1176 - acc: 0.334 - ETA: 4s - loss: 2.9758 - acc: 0.355 - ETA: 3s - loss: 2.8871 - acc: 0.368 - ETA: 3s - loss: 2.7804 - acc: 0.386 - ETA: 3s - loss: 2.6803 - acc: 0.405 - ETA: 2s - loss: 2.5968 - acc: 0.417 - ETA: 2s - loss: 2.5000 - acc: 0.429 - ETA: 2s - loss: 2.4368 - acc: 0.440 - ETA: 2s - loss: 2.3725 - acc: 0.451 - ETA: 1s - loss: 2.3184 - acc: 0.458 - ETA: 1s - loss: 2.2648 - acc: 0.468 - ETA: 1s - loss: 2.2143 - acc: 0.477 - ETA: 1s - loss: 2.1685 - acc: 0.487 - ETA: 1s - loss: 2.1207 - acc: 0.496 - ETA: 1s - loss: 2.0771 - acc: 0.505 - ETA: 0s - loss: 2.0310 - acc: 0.514 - ETA: 0s - loss: 1.9917 - acc: 0.523 - ETA: 0s - loss: 1.9531 - acc: 0.529 - ETA: 0s - loss: 1.9241 - acc: 0.534 - ETA: 0s - loss: 1.8955 - acc: 0.538 - ETA: 0s - loss: 1.8582 - acc: 0.546 - ETA: 0s - loss: 1.8284 - acc: 0.551 - ETA: 0s - loss: 1.8005 - acc: 0.557 - 4s 572us/step - loss: 1.7850 - acc: 0.5606 - val_loss: 0.8013 - val_acc: 0.7485
#
# Epoch 00001: val_loss improved from inf to 0.80132, saving model to saved_models/weights.best.Resnet50.hdf5
# Epoch 2/20
# 6680/6680 [==============================] - ETA: 5s - loss: 0.3844 - acc: 0.850 - ETA: 2s - loss: 0.5185 - acc: 0.854 - ETA: 1s - loss: 0.5244 - acc: 0.840 - ETA: 1s - loss: 0.5080 - acc: 0.845 - ETA: 1s - loss: 0.5083 - acc: 0.841 - ETA: 1s - loss: 0.5041 - acc: 0.851 - ETA: 1s - loss: 0.4897 - acc: 0.854 - ETA: 1s - loss: 0.4993 - acc: 0.849 - ETA: 1s - loss: 0.4991 - acc: 0.849 - ETA: 1s - loss: 0.5050 - acc: 0.846 - ETA: 1s - loss: 0.5070 - acc: 0.845 - ETA: 1s - loss: 0.5114 - acc: 0.844 - ETA: 1s - loss: 0.5165 - acc: 0.842 - ETA: 1s - loss: 0.5204 - acc: 0.840 - ETA: 1s - loss: 0.5256 - acc: 0.839 - ETA: 0s - loss: 0.5222 - acc: 0.839 - ETA: 0s - loss: 0.5211 - acc: 0.840 - ETA: 0s - loss: 0.5189 - acc: 0.840 - ETA: 0s - loss: 0.5266 - acc: 0.838 - ETA: 0s - loss: 0.5290 - acc: 0.837 - ETA: 0s - loss: 0.5258 - acc: 0.837 - ETA: 0s - loss: 0.5295 - acc: 0.836 - ETA: 0s - loss: 0.5330 - acc: 0.835 - ETA: 0s - loss: 0.5283 - acc: 0.836 - ETA: 0s - loss: 0.5328 - acc: 0.834 - ETA: 0s - loss: 0.5327 - acc: 0.834 - ETA: 0s - loss: 0.5321 - acc: 0.834 - ETA: 0s - loss: 0.5315 - acc: 0.834 - ETA: 0s - loss: 0.5304 - acc: 0.834 - ETA: 0s - loss: 0.5278 - acc: 0.835 - ETA: 0s - loss: 0.5265 - acc: 0.835 - ETA: 0s - loss: 0.5263 - acc: 0.835 - 2s 276us/step - loss: 0.5243 - acc: 0.8358 - val_loss: 0.7035 - val_acc: 0.7784
#
# Epoch 00002: val_loss improved from 0.80132 to 0.70353, saving model to saved_models/weights.best.Resnet50.hdf5
# Epoch 3/20
# 6680/6680 [==============================] - ETA: 9s - loss: 0.4379 - acc: 0.950 - ETA: 4s - loss: 0.3420 - acc: 0.900 - ETA: 2s - loss: 0.3223 - acc: 0.876 - ETA: 2s - loss: 0.2937 - acc: 0.895 - ETA: 2s - loss: 0.2876 - acc: 0.901 - ETA: 1s - loss: 0.2998 - acc: 0.898 - ETA: 1s - loss: 0.3003 - acc: 0.899 - ETA: 1s - loss: 0.3117 - acc: 0.898 - ETA: 1s - loss: 0.3197 - acc: 0.901 - ETA: 1s - loss: 0.3110 - acc: 0.902 - ETA: 1s - loss: 0.3142 - acc: 0.901 - ETA: 1s - loss: 0.3183 - acc: 0.898 - ETA: 1s - loss: 0.3179 - acc: 0.900 - ETA: 1s - loss: 0.3267 - acc: 0.896 - ETA: 0s - loss: 0.3240 - acc: 0.896 - ETA: 0s - loss: 0.3253 - acc: 0.897 - ETA: 0s - loss: 0.3253 - acc: 0.896 - ETA: 0s - loss: 0.3292 - acc: 0.894 - ETA: 0s - loss: 0.3318 - acc: 0.893 - ETA: 0s - loss: 0.3320 - acc: 0.893 - ETA: 0s - loss: 0.3319 - acc: 0.892 - ETA: 0s - loss: 0.3338 - acc: 0.891 - ETA: 0s - loss: 0.3395 - acc: 0.890 - ETA: 0s - loss: 0.3424 - acc: 0.889 - ETA: 0s - loss: 0.3421 - acc: 0.890 - ETA: 0s - loss: 0.3428 - acc: 0.890 - ETA: 0s - loss: 0.3459 - acc: 0.889 - ETA: 0s - loss: 0.3431 - acc: 0.890 - ETA: 0s - loss: 0.3474 - acc: 0.889 - ETA: 0s - loss: 0.3519 - acc: 0.888 - ETA: 0s - loss: 0.3507 - acc: 0.888 - 2s 270us/step - loss: 0.3531 - acc: 0.8879 - val_loss: 0.6894 - val_acc: 0.7880
#
# Epoch 00003: val_loss improved from 0.70353 to 0.68936, saving model to saved_models/weights.best.Resnet50.hdf5
# Epoch 4/20
# 6680/6680 [==============================] - ETA: 5s - loss: 0.3623 - acc: 0.900 - ETA: 2s - loss: 0.2805 - acc: 0.887 - ETA: 2s - loss: 0.2275 - acc: 0.917 - ETA: 2s - loss: 0.2358 - acc: 0.915 - ETA: 1s - loss: 0.2255 - acc: 0.920 - ETA: 1s - loss: 0.2232 - acc: 0.922 - ETA: 1s - loss: 0.2182 - acc: 0.925 - ETA: 1s - loss: 0.2140 - acc: 0.925 - ETA: 1s - loss: 0.2152 - acc: 0.925 - ETA: 1s - loss: 0.2181 - acc: 0.927 - ETA: 1s - loss: 0.2160 - acc: 0.927 - ETA: 1s - loss: 0.2212 - acc: 0.923 - ETA: 1s - loss: 0.2217 - acc: 0.924 - ETA: 1s - loss: 0.2177 - acc: 0.924 - ETA: 1s - loss: 0.2264 - acc: 0.923 - ETA: 1s - loss: 0.2289 - acc: 0.922 - ETA: 1s - loss: 0.2334 - acc: 0.922 - ETA: 0s - loss: 0.2332 - acc: 0.923 - ETA: 0s - loss: 0.2375 - acc: 0.922 - ETA: 0s - loss: 0.2378 - acc: 0.922 - ETA: 0s - loss: 0.2416 - acc: 0.922 - ETA: 0s - loss: 0.2408 - acc: 0.923 - ETA: 0s - loss: 0.2423 - acc: 0.921 - ETA: 0s - loss: 0.2459 - acc: 0.919 - ETA: 0s - loss: 0.2474 - acc: 0.919 - ETA: 0s - loss: 0.2445 - acc: 0.919 - ETA: 0s - loss: 0.2405 - acc: 0.920 - ETA: 0s - loss: 0.2436 - acc: 0.920 - ETA: 0s - loss: 0.2452 - acc: 0.918 - ETA: 0s - loss: 0.2465 - acc: 0.918 - ETA: 0s - loss: 0.2459 - acc: 0.919 - ETA: 0s - loss: 0.2506 - acc: 0.918 - ETA: 0s - loss: 0.2519 - acc: 0.918 - ETA: 0s - loss: 0.2558 - acc: 0.916 - 2s 288us/step - loss: 0.2555 - acc: 0.9165 - val_loss: 0.7009 - val_acc: 0.7856
#
# Epoch 00004: val_loss did not improve from 0.68936
# Epoch 5/20
# 6680/6680 [==============================] - ETA: 2s - loss: 0.2999 - acc: 0.900 - ETA: 1s - loss: 0.2093 - acc: 0.925 - ETA: 1s - loss: 0.1945 - acc: 0.931 - ETA: 1s - loss: 0.1861 - acc: 0.931 - ETA: 1s - loss: 0.1814 - acc: 0.931 - ETA: 1s - loss: 0.1820 - acc: 0.934 - ETA: 1s - loss: 0.1996 - acc: 0.927 - ETA: 1s - loss: 0.2019 - acc: 0.928 - ETA: 1s - loss: 0.2013 - acc: 0.931 - ETA: 1s - loss: 0.2055 - acc: 0.933 - ETA: 1s - loss: 0.1983 - acc: 0.934 - ETA: 1s - loss: 0.1984 - acc: 0.935 - ETA: 1s - loss: 0.1925 - acc: 0.936 - ETA: 1s - loss: 0.1898 - acc: 0.938 - ETA: 0s - loss: 0.1863 - acc: 0.939 - ETA: 0s - loss: 0.1862 - acc: 0.939 - ETA: 0s - loss: 0.1869 - acc: 0.937 - ETA: 0s - loss: 0.1904 - acc: 0.937 - ETA: 0s - loss: 0.1879 - acc: 0.937 - ETA: 0s - loss: 0.1926 - acc: 0.936 - ETA: 0s - loss: 0.1939 - acc: 0.935 - ETA: 0s - loss: 0.1949 - acc: 0.935 - ETA: 0s - loss: 0.1975 - acc: 0.933 - ETA: 0s - loss: 0.1976 - acc: 0.934 - ETA: 0s - loss: 0.1962 - acc: 0.934 - ETA: 0s - loss: 0.1976 - acc: 0.933 - ETA: 0s - loss: 0.1944 - acc: 0.935 - ETA: 0s - loss: 0.1979 - acc: 0.933 - ETA: 0s - loss: 0.1970 - acc: 0.933 - ETA: 0s - loss: 0.1962 - acc: 0.933 - ETA: 0s - loss: 0.1961 - acc: 0.933 - 2s 266us/step - loss: 0.1979 - acc: 0.9328 - val_loss: 0.6989 - val_acc: 0.8084
#
# Epoch 00005: val_loss did not improve from 0.68936
# Epoch 6/20
# 6680/6680 [==============================] - ETA: 1s - loss: 0.2277 - acc: 0.900 - ETA: 1s - loss: 0.2163 - acc: 0.931 - ETA: 1s - loss: 0.1679 - acc: 0.942 - ETA: 1s - loss: 0.1550 - acc: 0.948 - ETA: 1s - loss: 0.1369 - acc: 0.957 - ETA: 1s - loss: 0.1391 - acc: 0.952 - ETA: 1s - loss: 0.1384 - acc: 0.953 - ETA: 1s - loss: 0.1352 - acc: 0.955 - ETA: 1s - loss: 0.1325 - acc: 0.956 - ETA: 1s - loss: 0.1397 - acc: 0.954 - ETA: 1s - loss: 0.1504 - acc: 0.951 - ETA: 1s - loss: 0.1597 - acc: 0.950 - ETA: 1s - loss: 0.1597 - acc: 0.949 - ETA: 1s - loss: 0.1628 - acc: 0.949 - ETA: 0s - loss: 0.1583 - acc: 0.951 - ETA: 0s - loss: 0.1582 - acc: 0.950 - ETA: 0s - loss: 0.1561 - acc: 0.952 - ETA: 0s - loss: 0.1595 - acc: 0.951 - ETA: 0s - loss: 0.1632 - acc: 0.950 - ETA: 0s - loss: 0.1682 - acc: 0.949 - ETA: 0s - loss: 0.1664 - acc: 0.949 - ETA: 0s - loss: 0.1649 - acc: 0.949 - ETA: 0s - loss: 0.1629 - acc: 0.949 - ETA: 0s - loss: 0.1657 - acc: 0.949 - ETA: 0s - loss: 0.1671 - acc: 0.949 - ETA: 0s - loss: 0.1651 - acc: 0.950 - ETA: 0s - loss: 0.1619 - acc: 0.951 - ETA: 0s - loss: 0.1618 - acc: 0.951 - ETA: 0s - loss: 0.1606 - acc: 0.951 - ETA: 0s - loss: 0.1624 - acc: 0.951 - ETA: 0s - loss: 0.1653 - acc: 0.950 - 2s 262us/step - loss: 0.1644 - acc: 0.9506 - val_loss: 0.6884 - val_acc: 0.8120
#
# Epoch 00006: val_loss improved from 0.68936 to 0.68840, saving model to saved_models/weights.best.Resnet50.hdf5
# Epoch 7/20
# 6680/6680 [==============================] - ETA: 2s - loss: 0.0778 - acc: 0.950 - ETA: 1s - loss: 0.1233 - acc: 0.960 - ETA: 1s - loss: 0.1160 - acc: 0.960 - ETA: 1s - loss: 0.1081 - acc: 0.966 - ETA: 1s - loss: 0.1030 - acc: 0.964 - ETA: 1s - loss: 0.1170 - acc: 0.958 - ETA: 1s - loss: 0.1161 - acc: 0.960 - ETA: 1s - loss: 0.1119 - acc: 0.961 - ETA: 1s - loss: 0.1162 - acc: 0.959 - ETA: 1s - loss: 0.1236 - acc: 0.960 - ETA: 1s - loss: 0.1229 - acc: 0.960 - ETA: 1s - loss: 0.1229 - acc: 0.960 - ETA: 1s - loss: 0.1260 - acc: 0.959 - ETA: 1s - loss: 0.1289 - acc: 0.958 - ETA: 1s - loss: 0.1241 - acc: 0.960 - ETA: 1s - loss: 0.1230 - acc: 0.961 - ETA: 1s - loss: 0.1263 - acc: 0.960 - ETA: 0s - loss: 0.1240 - acc: 0.961 - ETA: 0s - loss: 0.1218 - acc: 0.961 - ETA: 0s - loss: 0.1248 - acc: 0.959 - ETA: 0s - loss: 0.1240 - acc: 0.960 - ETA: 0s - loss: 0.1257 - acc: 0.959 - ETA: 0s - loss: 0.1284 - acc: 0.959 - ETA: 0s - loss: 0.1274 - acc: 0.959 - ETA: 0s - loss: 0.1271 - acc: 0.959 - ETA: 0s - loss: 0.1260 - acc: 0.960 - ETA: 0s - loss: 0.1242 - acc: 0.960 - ETA: 0s - loss: 0.1273 - acc: 0.959 - ETA: 0s - loss: 0.1281 - acc: 0.959 - ETA: 0s - loss: 0.1323 - acc: 0.957 - ETA: 0s - loss: 0.1327 - acc: 0.957 - ETA: 0s - loss: 0.1347 - acc: 0.957 - ETA: 0s - loss: 0.1343 - acc: 0.957 - 2s 284us/step - loss: 0.1341 - acc: 0.9570 - val_loss: 0.7005 - val_acc: 0.8180
#
# Epoch 00007: val_loss did not improve from 0.68840
# Epoch 8/20
# 6680/6680 [==============================] - ETA: 1s - loss: 0.1590 - acc: 0.950 - ETA: 1s - loss: 0.1090 - acc: 0.972 - ETA: 1s - loss: 0.1149 - acc: 0.969 - ETA: 1s - loss: 0.1069 - acc: 0.966 - ETA: 1s - loss: 0.1088 - acc: 0.964 - ETA: 1s - loss: 0.1014 - acc: 0.966 - ETA: 1s - loss: 0.1079 - acc: 0.963 - ETA: 1s - loss: 0.1024 - acc: 0.966 - ETA: 1s - loss: 0.1005 - acc: 0.965 - ETA: 1s - loss: 0.0967 - acc: 0.966 - ETA: 1s - loss: 0.0970 - acc: 0.965 - ETA: 1s - loss: 0.0987 - acc: 0.964 - ETA: 1s - loss: 0.0964 - acc: 0.965 - ETA: 0s - loss: 0.0998 - acc: 0.964 - ETA: 0s - loss: 0.1020 - acc: 0.964 - ETA: 0s - loss: 0.1025 - acc: 0.964 - ETA: 0s - loss: 0.1044 - acc: 0.964 - ETA: 0s - loss: 0.1038 - acc: 0.963 - ETA: 0s - loss: 0.1032 - acc: 0.964 - ETA: 0s - loss: 0.1046 - acc: 0.965 - ETA: 0s - loss: 0.1043 - acc: 0.965 - ETA: 0s - loss: 0.1035 - acc: 0.965 - ETA: 0s - loss: 0.1047 - acc: 0.964 - ETA: 0s - loss: 0.1052 - acc: 0.964 - ETA: 0s - loss: 0.1049 - acc: 0.964 - ETA: 0s - loss: 0.1043 - acc: 0.965 - ETA: 0s - loss: 0.1037 - acc: 0.965 - ETA: 0s - loss: 0.1050 - acc: 0.965 - ETA: 0s - loss: 0.1089 - acc: 0.964 - ETA: 0s - loss: 0.1082 - acc: 0.964 - 2s 254us/step - loss: 0.1084 - acc: 0.9642 - val_loss: 0.6842 - val_acc: 0.8275
#
# Epoch 00008: val_loss improved from 0.68840 to 0.68419, saving model to saved_models/weights.best.Resnet50.hdf5
# Epoch 9/20
# 6680/6680 [==============================] - ETA: 4s - loss: 0.2320 - acc: 0.900 - ETA: 2s - loss: 0.1694 - acc: 0.956 - ETA: 2s - loss: 0.1233 - acc: 0.961 - ETA: 1s - loss: 0.0999 - acc: 0.967 - ETA: 1s - loss: 0.0906 - acc: 0.969 - ETA: 1s - loss: 0.0871 - acc: 0.969 - ETA: 1s - loss: 0.0855 - acc: 0.969 - ETA: 1s - loss: 0.0868 - acc: 0.968 - ETA: 1s - loss: 0.0825 - acc: 0.969 - ETA: 1s - loss: 0.0805 - acc: 0.969 - ETA: 1s - loss: 0.0814 - acc: 0.968 - ETA: 1s - loss: 0.0801 - acc: 0.970 - ETA: 1s - loss: 0.0788 - acc: 0.970 - ETA: 1s - loss: 0.0759 - acc: 0.971 - ETA: 1s - loss: 0.0795 - acc: 0.970 - ETA: 1s - loss: 0.0789 - acc: 0.972 - ETA: 0s - loss: 0.0771 - acc: 0.973 - ETA: 0s - loss: 0.0780 - acc: 0.972 - ETA: 0s - loss: 0.0807 - acc: 0.972 - ETA: 0s - loss: 0.0837 - acc: 0.972 - ETA: 0s - loss: 0.0841 - acc: 0.972 - ETA: 0s - loss: 0.0829 - acc: 0.972 - ETA: 0s - loss: 0.0877 - acc: 0.971 - ETA: 0s - loss: 0.0890 - acc: 0.971 - ETA: 0s - loss: 0.0904 - acc: 0.970 - ETA: 0s - loss: 0.0911 - acc: 0.970 - ETA: 0s - loss: 0.0910 - acc: 0.970 - ETA: 0s - loss: 0.0901 - acc: 0.970 - ETA: 0s - loss: 0.0921 - acc: 0.969 - ETA: 0s - loss: 0.0938 - acc: 0.969 - ETA: 0s - loss: 0.0940 - acc: 0.969 - ETA: 0s - loss: 0.0937 - acc: 0.969 - ETA: 0s - loss: 0.0932 - acc: 0.970 - 2s 284us/step - loss: 0.0928 - acc: 0.9704 - val_loss: 0.6822 - val_acc: 0.8168
#
# Epoch 00009: val_loss improved from 0.68419 to 0.68225, saving model to saved_models/weights.best.Resnet50.hdf5
# Epoch 10/20
# 6680/6680 [==============================] - ETA: 7s - loss: 0.0283 - acc: 1.000 - ETA: 3s - loss: 0.0515 - acc: 0.992 - ETA: 2s - loss: 0.0468 - acc: 0.987 - ETA: 2s - loss: 0.0583 - acc: 0.976 - ETA: 1s - loss: 0.0571 - acc: 0.977 - ETA: 1s - loss: 0.0538 - acc: 0.980 - ETA: 1s - loss: 0.0647 - acc: 0.977 - ETA: 1s - loss: 0.0696 - acc: 0.977 - ETA: 1s - loss: 0.0720 - acc: 0.976 - ETA: 1s - loss: 0.0764 - acc: 0.974 - ETA: 1s - loss: 0.0757 - acc: 0.974 - ETA: 1s - loss: 0.0758 - acc: 0.975 - ETA: 1s - loss: 0.0797 - acc: 0.975 - ETA: 1s - loss: 0.0799 - acc: 0.975 - ETA: 1s - loss: 0.0789 - acc: 0.975 - ETA: 1s - loss: 0.0785 - acc: 0.975 - ETA: 1s - loss: 0.0766 - acc: 0.976 - ETA: 0s - loss: 0.0747 - acc: 0.977 - ETA: 0s - loss: 0.0764 - acc: 0.976 - ETA: 0s - loss: 0.0765 - acc: 0.976 - ETA: 0s - loss: 0.0768 - acc: 0.977 - ETA: 0s - loss: 0.0751 - acc: 0.978 - ETA: 0s - loss: 0.0743 - acc: 0.978 - ETA: 0s - loss: 0.0768 - acc: 0.977 - ETA: 0s - loss: 0.0770 - acc: 0.976 - ETA: 0s - loss: 0.0770 - acc: 0.976 - ETA: 0s - loss: 0.0787 - acc: 0.976 - ETA: 0s - loss: 0.0788 - acc: 0.976 - ETA: 0s - loss: 0.0787 - acc: 0.977 - ETA: 0s - loss: 0.0789 - acc: 0.976 - ETA: 0s - loss: 0.0794 - acc: 0.976 - ETA: 0s - loss: 0.0788 - acc: 0.976 - ETA: 0s - loss: 0.0793 - acc: 0.976 - ETA: 0s - loss: 0.0786 - acc: 0.976 - ETA: 0s - loss: 0.0778 - acc: 0.977 - 2s 292us/step - loss: 0.0800 - acc: 0.9765 - val_loss: 0.7614 - val_acc: 0.8036
#
# Epoch 00010: val_loss did not improve from 0.68225
# Epoch 11/20
# 6680/6680 [==============================] - ETA: 1s - loss: 0.0220 - acc: 1.000 - ETA: 1s - loss: 0.0453 - acc: 0.987 - ETA: 1s - loss: 0.0502 - acc: 0.981 - ETA: 1s - loss: 0.0600 - acc: 0.979 - ETA: 1s - loss: 0.0513 - acc: 0.983 - ETA: 1s - loss: 0.0568 - acc: 0.981 - ETA: 1s - loss: 0.0598 - acc: 0.981 - ETA: 1s - loss: 0.0603 - acc: 0.981 - ETA: 1s - loss: 0.0574 - acc: 0.982 - ETA: 1s - loss: 0.0591 - acc: 0.981 - ETA: 1s - loss: 0.0653 - acc: 0.979 - ETA: 1s - loss: 0.0654 - acc: 0.979 - ETA: 0s - loss: 0.0626 - acc: 0.980 - ETA: 0s - loss: 0.0636 - acc: 0.980 - ETA: 0s - loss: 0.0618 - acc: 0.980 - ETA: 0s - loss: 0.0657 - acc: 0.979 - ETA: 0s - loss: 0.0655 - acc: 0.979 - ETA: 0s - loss: 0.0662 - acc: 0.978 - ETA: 0s - loss: 0.0667 - acc: 0.978 - ETA: 0s - loss: 0.0658 - acc: 0.978 - ETA: 0s - loss: 0.0662 - acc: 0.978 - ETA: 0s - loss: 0.0660 - acc: 0.978 - ETA: 0s - loss: 0.0668 - acc: 0.978 - ETA: 0s - loss: 0.0670 - acc: 0.977 - ETA: 0s - loss: 0.0680 - acc: 0.977 - ETA: 0s - loss: 0.0706 - acc: 0.977 - ETA: 0s - loss: 0.0700 - acc: 0.977 - ETA: 0s - loss: 0.0690 - acc: 0.977 - ETA: 0s - loss: 0.0683 - acc: 0.977 - 2s 244us/step - loss: 0.0713 - acc: 0.9768 - val_loss: 0.7893 - val_acc: 0.7988
#
# Epoch 00011: val_loss did not improve from 0.68225
# Epoch 12/20
# 6680/6680 [==============================] - ETA: 1s - loss: 0.0616 - acc: 1.000 - ETA: 1s - loss: 0.0556 - acc: 0.982 - ETA: 1s - loss: 0.0551 - acc: 0.984 - ETA: 1s - loss: 0.0478 - acc: 0.985 - ETA: 1s - loss: 0.0476 - acc: 0.984 - ETA: 1s - loss: 0.0475 - acc: 0.983 - ETA: 1s - loss: 0.0504 - acc: 0.984 - ETA: 1s - loss: 0.0500 - acc: 0.984 - ETA: 1s - loss: 0.0470 - acc: 0.985 - ETA: 1s - loss: 0.0468 - acc: 0.984 - ETA: 1s - loss: 0.0465 - acc: 0.985 - ETA: 0s - loss: 0.0476 - acc: 0.984 - ETA: 0s - loss: 0.0476 - acc: 0.984 - ETA: 0s - loss: 0.0461 - acc: 0.985 - ETA: 0s - loss: 0.0463 - acc: 0.984 - ETA: 0s - loss: 0.0486 - acc: 0.983 - ETA: 0s - loss: 0.0493 - acc: 0.983 - ETA: 0s - loss: 0.0495 - acc: 0.982 - ETA: 0s - loss: 0.0492 - acc: 0.982 - ETA: 0s - loss: 0.0498 - acc: 0.982 - ETA: 0s - loss: 0.0527 - acc: 0.982 - ETA: 0s - loss: 0.0566 - acc: 0.981 - ETA: 0s - loss: 0.0579 - acc: 0.981 - ETA: 0s - loss: 0.0565 - acc: 0.982 - ETA: 0s - loss: 0.0584 - acc: 0.981 - ETA: 0s - loss: 0.0586 - acc: 0.981 - ETA: 0s - loss: 0.0581 - acc: 0.981 - ETA: 0s - loss: 0.0582 - acc: 0.981 - ETA: 0s - loss: 0.0600 - acc: 0.980 - ETA: 0s - loss: 0.0606 - acc: 0.980 - ETA: 0s - loss: 0.0606 - acc: 0.979 - 2s 266us/step - loss: 0.0603 - acc: 0.9798 - val_loss: 0.7519 - val_acc: 0.8180
#
# Epoch 00012: val_loss did not improve from 0.68225
# Epoch 13/20
# 6680/6680 [==============================] - ETA: 1s - loss: 0.0776 - acc: 0.950 - ETA: 1s - loss: 0.0839 - acc: 0.977 - ETA: 1s - loss: 0.0673 - acc: 0.977 - ETA: 1s - loss: 0.0566 - acc: 0.978 - ETA: 1s - loss: 0.0540 - acc: 0.980 - ETA: 1s - loss: 0.0539 - acc: 0.981 - ETA: 1s - loss: 0.0571 - acc: 0.981 - ETA: 1s - loss: 0.0568 - acc: 0.982 - ETA: 1s - loss: 0.0645 - acc: 0.981 - ETA: 1s - loss: 0.0638 - acc: 0.982 - ETA: 1s - loss: 0.0601 - acc: 0.983 - ETA: 1s - loss: 0.0601 - acc: 0.983 - ETA: 1s - loss: 0.0589 - acc: 0.983 - ETA: 1s - loss: 0.0618 - acc: 0.982 - ETA: 0s - loss: 0.0607 - acc: 0.982 - ETA: 0s - loss: 0.0591 - acc: 0.983 - ETA: 0s - loss: 0.0623 - acc: 0.982 - ETA: 0s - loss: 0.0627 - acc: 0.981 - ETA: 0s - loss: 0.0628 - acc: 0.981 - ETA: 0s - loss: 0.0631 - acc: 0.981 - ETA: 0s - loss: 0.0632 - acc: 0.981 - ETA: 0s - loss: 0.0616 - acc: 0.982 - ETA: 0s - loss: 0.0615 - acc: 0.981 - ETA: 0s - loss: 0.0609 - acc: 0.982 - ETA: 0s - loss: 0.0607 - acc: 0.982 - ETA: 0s - loss: 0.0598 - acc: 0.982 - ETA: 0s - loss: 0.0596 - acc: 0.982 - ETA: 0s - loss: 0.0581 - acc: 0.982 - ETA: 0s - loss: 0.0575 - acc: 0.982 - ETA: 0s - loss: 0.0593 - acc: 0.982 - ETA: 0s - loss: 0.0614 - acc: 0.981 - ETA: 0s - loss: 0.0614 - acc: 0.982 - 2s 275us/step - loss: 0.0611 - acc: 0.9822 - val_loss: 0.7322 - val_acc: 0.8287
#
# Epoch 00013: val_loss did not improve from 0.68225
# Epoch 14/20
# 6680/6680 [==============================] - ETA: 1s - loss: 0.0166 - acc: 1.000 - ETA: 1s - loss: 0.0311 - acc: 0.987 - ETA: 1s - loss: 0.0286 - acc: 0.988 - ETA: 1s - loss: 0.0245 - acc: 0.991 - ETA: 1s - loss: 0.0334 - acc: 0.989 - ETA: 1s - loss: 0.0322 - acc: 0.990 - ETA: 1s - loss: 0.0289 - acc: 0.991 - ETA: 1s - loss: 0.0320 - acc: 0.989 - ETA: 1s - loss: 0.0327 - acc: 0.989 - ETA: 1s - loss: 0.0336 - acc: 0.988 - ETA: 1s - loss: 0.0373 - acc: 0.986 - ETA: 1s - loss: 0.0349 - acc: 0.987 - ETA: 1s - loss: 0.0341 - acc: 0.987 - ETA: 1s - loss: 0.0362 - acc: 0.986 - ETA: 0s - loss: 0.0379 - acc: 0.986 - ETA: 0s - loss: 0.0393 - acc: 0.985 - ETA: 0s - loss: 0.0398 - acc: 0.985 - ETA: 0s - loss: 0.0458 - acc: 0.984 - ETA: 0s - loss: 0.0474 - acc: 0.984 - ETA: 0s - loss: 0.0508 - acc: 0.983 - ETA: 0s - loss: 0.0497 - acc: 0.984 - ETA: 0s - loss: 0.0493 - acc: 0.984 - ETA: 0s - loss: 0.0498 - acc: 0.984 - ETA: 0s - loss: 0.0487 - acc: 0.984 - ETA: 0s - loss: 0.0474 - acc: 0.985 - ETA: 0s - loss: 0.0483 - acc: 0.984 - ETA: 0s - loss: 0.0476 - acc: 0.984 - ETA: 0s - loss: 0.0476 - acc: 0.984 - ETA: 0s - loss: 0.0473 - acc: 0.984 - ETA: 0s - loss: 0.0472 - acc: 0.984 - ETA: 0s - loss: 0.0477 - acc: 0.984 - ETA: 0s - loss: 0.0500 - acc: 0.983 - 2s 276us/step - loss: 0.0507 - acc: 0.9840 - val_loss: 0.8058 - val_acc: 0.8228
#
# Epoch 00014: val_loss did not improve from 0.68225
# Epoch 15/20
# 6680/6680 [==============================] - ETA: 1s - loss: 0.0068 - acc: 1.000 - ETA: 1s - loss: 0.0479 - acc: 0.990 - ETA: 1s - loss: 0.0410 - acc: 0.990 - ETA: 1s - loss: 0.0341 - acc: 0.991 - ETA: 1s - loss: 0.0330 - acc: 0.992 - ETA: 1s - loss: 0.0310 - acc: 0.992 - ETA: 1s - loss: 0.0280 - acc: 0.993 - ETA: 1s - loss: 0.0269 - acc: 0.992 - ETA: 1s - loss: 0.0278 - acc: 0.991 - ETA: 1s - loss: 0.0264 - acc: 0.992 - ETA: 1s - loss: 0.0278 - acc: 0.991 - ETA: 1s - loss: 0.0283 - acc: 0.991 - ETA: 1s - loss: 0.0277 - acc: 0.992 - ETA: 1s - loss: 0.0336 - acc: 0.991 - ETA: 0s - loss: 0.0334 - acc: 0.990 - ETA: 0s - loss: 0.0324 - acc: 0.990 - ETA: 0s - loss: 0.0362 - acc: 0.989 - ETA: 0s - loss: 0.0381 - acc: 0.988 - ETA: 0s - loss: 0.0382 - acc: 0.988 - ETA: 0s - loss: 0.0398 - acc: 0.987 - ETA: 0s - loss: 0.0390 - acc: 0.988 - ETA: 0s - loss: 0.0404 - acc: 0.987 - ETA: 0s - loss: 0.0407 - acc: 0.987 - ETA: 0s - loss: 0.0408 - acc: 0.987 - ETA: 0s - loss: 0.0405 - acc: 0.988 - ETA: 0s - loss: 0.0416 - acc: 0.987 - ETA: 0s - loss: 0.0412 - acc: 0.987 - ETA: 0s - loss: 0.0403 - acc: 0.987 - ETA: 0s - loss: 0.0421 - acc: 0.987 - ETA: 0s - loss: 0.0417 - acc: 0.987 - ETA: 0s - loss: 0.0417 - acc: 0.987 - 2s 265us/step - loss: 0.0420 - acc: 0.9876 - val_loss: 0.8088 - val_acc: 0.8180
#
# Epoch 00015: val_loss did not improve from 0.68225
# Epoch 16/20
# 6680/6680 [==============================] - ETA: 1s - loss: 6.7586e-04 - acc: 1.000 - ETA: 1s - loss: 0.0118 - acc: 1.0000    - ETA: 1s - loss: 0.0176 - acc: 0.997 - ETA: 1s - loss: 0.0211 - acc: 0.995 - ETA: 1s - loss: 0.0310 - acc: 0.990 - ETA: 1s - loss: 0.0311 - acc: 0.990 - ETA: 1s - loss: 0.0319 - acc: 0.989 - ETA: 1s - loss: 0.0287 - acc: 0.991 - ETA: 1s - loss: 0.0295 - acc: 0.991 - ETA: 1s - loss: 0.0296 - acc: 0.991 - ETA: 1s - loss: 0.0286 - acc: 0.991 - ETA: 1s - loss: 0.0278 - acc: 0.991 - ETA: 0s - loss: 0.0282 - acc: 0.991 - ETA: 0s - loss: 0.0268 - acc: 0.992 - ETA: 0s - loss: 0.0310 - acc: 0.991 - ETA: 0s - loss: 0.0330 - acc: 0.990 - ETA: 0s - loss: 0.0332 - acc: 0.990 - ETA: 0s - loss: 0.0322 - acc: 0.991 - ETA: 0s - loss: 0.0313 - acc: 0.991 - ETA: 0s - loss: 0.0317 - acc: 0.991 - ETA: 0s - loss: 0.0339 - acc: 0.990 - ETA: 0s - loss: 0.0332 - acc: 0.990 - ETA: 0s - loss: 0.0349 - acc: 0.990 - ETA: 0s - loss: 0.0361 - acc: 0.990 - ETA: 0s - loss: 0.0355 - acc: 0.990 - ETA: 0s - loss: 0.0353 - acc: 0.990 - ETA: 0s - loss: 0.0351 - acc: 0.990 - ETA: 0s - loss: 0.0352 - acc: 0.990 - ETA: 0s - loss: 0.0347 - acc: 0.990 - ETA: 0s - loss: 0.0346 - acc: 0.990 - ETA: 0s - loss: 0.0350 - acc: 0.990 - 2s 259us/step - loss: 0.0350 - acc: 0.9903 - val_loss: 0.8043 - val_acc: 0.8240
#
# Epoch 00016: val_loss did not improve from 0.68225
# Epoch 17/20
# 6680/6680 [==============================] - ETA: 1s - loss: 0.0012 - acc: 1.000 - ETA: 1s - loss: 0.0332 - acc: 0.991 - ETA: 1s - loss: 0.0238 - acc: 0.993 - ETA: 1s - loss: 0.0290 - acc: 0.992 - ETA: 1s - loss: 0.0286 - acc: 0.993 - ETA: 1s - loss: 0.0266 - acc: 0.993 - ETA: 1s - loss: 0.0239 - acc: 0.994 - ETA: 1s - loss: 0.0307 - acc: 0.992 - ETA: 1s - loss: 0.0304 - acc: 0.992 - ETA: 1s - loss: 0.0299 - acc: 0.993 - ETA: 1s - loss: 0.0293 - acc: 0.992 - ETA: 1s - loss: 0.0315 - acc: 0.991 - ETA: 0s - loss: 0.0310 - acc: 0.991 - ETA: 0s - loss: 0.0303 - acc: 0.991 - ETA: 0s - loss: 0.0290 - acc: 0.991 - ETA: 0s - loss: 0.0284 - acc: 0.991 - ETA: 0s - loss: 0.0273 - acc: 0.992 - ETA: 0s - loss: 0.0283 - acc: 0.991 - ETA: 0s - loss: 0.0298 - acc: 0.991 - ETA: 0s - loss: 0.0292 - acc: 0.992 - ETA: 0s - loss: 0.0295 - acc: 0.991 - ETA: 0s - loss: 0.0296 - acc: 0.991 - ETA: 0s - loss: 0.0330 - acc: 0.991 - ETA: 0s - loss: 0.0327 - acc: 0.991 - ETA: 0s - loss: 0.0341 - acc: 0.991 - ETA: 0s - loss: 0.0333 - acc: 0.991 - ETA: 0s - loss: 0.0338 - acc: 0.991 - ETA: 0s - loss: 0.0349 - acc: 0.991 - ETA: 0s - loss: 0.0342 - acc: 0.991 - 2s 247us/step - loss: 0.0347 - acc: 0.9909 - val_loss: 0.8584 - val_acc: 0.8192
#
# Epoch 00017: val_loss did not improve from 0.68225
# Epoch 18/20
# 6680/6680 [==============================] - ETA: 1s - loss: 0.0400 - acc: 1.000 - ETA: 1s - loss: 0.0093 - acc: 1.000 - ETA: 1s - loss: 0.0285 - acc: 0.996 - ETA: 1s - loss: 0.0246 - acc: 0.995 - ETA: 1s - loss: 0.0227 - acc: 0.996 - ETA: 1s - loss: 0.0205 - acc: 0.996 - ETA: 1s - loss: 0.0213 - acc: 0.996 - ETA: 1s - loss: 0.0208 - acc: 0.996 - ETA: 1s - loss: 0.0289 - acc: 0.994 - ETA: 1s - loss: 0.0326 - acc: 0.993 - ETA: 0s - loss: 0.0304 - acc: 0.993 - ETA: 0s - loss: 0.0299 - acc: 0.994 - ETA: 0s - loss: 0.0295 - acc: 0.993 - ETA: 0s - loss: 0.0320 - acc: 0.992 - ETA: 0s - loss: 0.0349 - acc: 0.991 - ETA: 0s - loss: 0.0339 - acc: 0.991 - ETA: 0s - loss: 0.0340 - acc: 0.991 - ETA: 0s - loss: 0.0344 - acc: 0.990 - ETA: 0s - loss: 0.0333 - acc: 0.991 - ETA: 0s - loss: 0.0338 - acc: 0.991 - ETA: 0s - loss: 0.0336 - acc: 0.991 - ETA: 0s - loss: 0.0332 - acc: 0.990 - ETA: 0s - loss: 0.0321 - acc: 0.991 - ETA: 0s - loss: 0.0332 - acc: 0.990 - ETA: 0s - loss: 0.0324 - acc: 0.991 - ETA: 0s - loss: 0.0330 - acc: 0.990 - ETA: 0s - loss: 0.0332 - acc: 0.990 - ETA: 0s - loss: 0.0333 - acc: 0.990 - 2s 239us/step - loss: 0.0335 - acc: 0.9901 - val_loss: 0.8019 - val_acc: 0.8263
#
# Epoch 00018: val_loss did not improve from 0.68225
# Epoch 19/20
# 6680/6680 [==============================] - ETA: 1s - loss: 0.0042 - acc: 1.000 - ETA: 1s - loss: 0.0160 - acc: 0.996 - ETA: 1s - loss: 0.0165 - acc: 0.995 - ETA: 1s - loss: 0.0246 - acc: 0.994 - ETA: 1s - loss: 0.0205 - acc: 0.995 - ETA: 1s - loss: 0.0271 - acc: 0.994 - ETA: 1s - loss: 0.0307 - acc: 0.992 - ETA: 1s - loss: 0.0283 - acc: 0.993 - ETA: 1s - loss: 0.0329 - acc: 0.992 - ETA: 1s - loss: 0.0336 - acc: 0.992 - ETA: 1s - loss: 0.0321 - acc: 0.992 - ETA: 1s - loss: 0.0322 - acc: 0.991 - ETA: 1s - loss: 0.0344 - acc: 0.991 - ETA: 0s - loss: 0.0319 - acc: 0.991 - ETA: 0s - loss: 0.0319 - acc: 0.991 - ETA: 0s - loss: 0.0307 - acc: 0.992 - ETA: 0s - loss: 0.0314 - acc: 0.991 - ETA: 0s - loss: 0.0315 - acc: 0.991 - ETA: 0s - loss: 0.0307 - acc: 0.991 - ETA: 0s - loss: 0.0296 - acc: 0.992 - ETA: 0s - loss: 0.0288 - acc: 0.992 - ETA: 0s - loss: 0.0281 - acc: 0.992 - ETA: 0s - loss: 0.0277 - acc: 0.992 - ETA: 0s - loss: 0.0294 - acc: 0.992 - ETA: 0s - loss: 0.0296 - acc: 0.991 - ETA: 0s - loss: 0.0289 - acc: 0.992 - ETA: 0s - loss: 0.0287 - acc: 0.992 - ETA: 0s - loss: 0.0284 - acc: 0.992 - ETA: 0s - loss: 0.0286 - acc: 0.992 - 2s 248us/step - loss: 0.0285 - acc: 0.9921 - val_loss: 0.7918 - val_acc: 0.8263
#
# Epoch 00019: val_loss did not improve from 0.68225
# Epoch 20/20
# 6680/6680 [==============================] - ETA: 1s - loss: 0.0033 - acc: 1.000 - ETA: 1s - loss: 0.0178 - acc: 0.996 - ETA: 1s - loss: 0.0234 - acc: 0.995 - ETA: 1s - loss: 0.0222 - acc: 0.995 - ETA: 1s - loss: 0.0223 - acc: 0.993 - ETA: 1s - loss: 0.0199 - acc: 0.994 - ETA: 1s - loss: 0.0194 - acc: 0.994 - ETA: 1s - loss: 0.0225 - acc: 0.994 - ETA: 1s - loss: 0.0205 - acc: 0.995 - ETA: 1s - loss: 0.0195 - acc: 0.995 - ETA: 1s - loss: 0.0214 - acc: 0.995 - ETA: 1s - loss: 0.0228 - acc: 0.995 - ETA: 0s - loss: 0.0226 - acc: 0.995 - ETA: 0s - loss: 0.0217 - acc: 0.995 - ETA: 0s - loss: 0.0210 - acc: 0.995 - ETA: 0s - loss: 0.0214 - acc: 0.994 - ETA: 0s - loss: 0.0205 - acc: 0.995 - ETA: 0s - loss: 0.0223 - acc: 0.994 - ETA: 0s - loss: 0.0218 - acc: 0.994 - ETA: 0s - loss: 0.0226 - acc: 0.994 - ETA: 0s - loss: 0.0235 - acc: 0.993 - ETA: 0s - loss: 0.0241 - acc: 0.993 - ETA: 0s - loss: 0.0235 - acc: 0.993 - ETA: 0s - loss: 0.0234 - acc: 0.993 - ETA: 0s - loss: 0.0226 - acc: 0.994 - ETA: 0s - loss: 0.0236 - acc: 0.993 - ETA: 0s - loss: 0.0238 - acc: 0.993 - ETA: 0s - loss: 0.0237 - acc: 0.993 - ETA: 0s - loss: 0.0242 - acc: 0.993 - ETA: 0s - loss: 0.0264 - acc: 0.993 - 2s 256us/step - loss: 0.0262 - acc: 0.9931 - val_loss: 0.8163 - val_acc: 0.8287
#
# Epoch 00020: val_loss did not improve from 0.68225

# %% [markdown]
# ### (IMPLEMENTATION) Load the Model with the Best Validation Loss

# %%
### TODO: Load the model weights with the best validation loss.
Resnet50_model.load_weights('saved_models/weights.best.Resnet50.hdf5')

# %% [markdown]
# ### (IMPLEMENTATION) Test the Model
#
# Try out your model on the test dataset of dog images. Ensure that your test accuracy is greater than 60%.

# %%
### TODO: Calculate classification accuracy on the test dataset.
# get index of predicted dog breed for each image in test set

Resnet50_predictions = [np.argmax(Resnet50_model.predict(np.expand_dims(feature, axis=0))) for feature in test_Resnet50]

# report test accuracy
test_accuracy = 100*np.sum(np.array(Resnet50_predictions)==np.argmax(test_targets, axis=1))/len(Resnet50_predictions)
print('Test accuracy: %.4f%%' % test_accuracy)
# Out:
# Test accuracy: 82.5359%

# %% [markdown]
# ### (IMPLEMENTATION) Predict Dog Breed with the Model
#
# Write a function that takes an image path as input and returns the dog breed (`Affenpinscher`, `Afghan_hound`, etc) that is predicted by your model.
#
# Similar to the analogous function in Step 5, your function should have three steps:
# 1. Extract the bottleneck features corresponding to the chosen CNN model.
# 2. Supply the bottleneck features as input to the model to return the predicted vector.  Note that the argmax of this prediction vector gives the index of the predicted dog breed.
# 3. Use the `dog_names` array defined in Step 0 of this notebook to return the corresponding breed.
#
# The functions to extract the bottleneck features can be found in `extract_bottleneck_features.py`, and they have been imported in an earlier code cell.  To obtain the bottleneck features corresponding to your chosen CNN architecture, you need to use the function
#
#     extract_{network}
#
# where `{network}`, in the above filename, should be one of `VGG19`, `Resnet50`, `InceptionV3`, or `Xception`.

# %%
### Write a function that takes a path to an image as input### Writ 
### and returns the dog breed that is predicted by the model.

from extract_bottleneck_features import *

def Resnet50_predict_breed(img_path):
    # extract bottleneck features for Resnet50 Model
    bottleneck_feature = extract_Resnet50(path_to_tensor(img_path))
    # obtain predicted vector
    predicted_vector = Resnet50_model.predict(bottleneck_feature)
    # return dog breed that is predicted by the model
    return dog_names[np.argmax(predicted_vector)]

# %% [markdown]
# ---
# <a id='step6'></a>
# ## Step 6: Write your Algorithm
#
# Write an algorithm that accepts a file path to an image and first determines whether the image contains a human, dog, or neither.  Then,
# - if a __dog__ is detected in the image, return the predicted breed.
# - if a __human__ is detected in the image, return the resembling dog breed.
# - if __neither__ is detected in the image, provide output that indicates an error.
#
# You are welcome to write your own functions for detecting humans and dogs in images, but feel free to use the `face_detector` and `dog_detector` functions developed above.  You are __required__ to use your CNN from Step 5 to predict dog breed.
#
# Some sample output for our algorithm is provided below, but feel free to design your own user experience!
#
# ![Sample Human Output](images/sample_human_output.png)
#
#
# ### (IMPLEMENTATION) Write your Algorithm

# %%
from keras.preprocessing import image                  
from os import walk
from os import listdir
from os.path import isfile, join
import random


def show_image(path):
    img = image.load_img(path, target_size=(224, 224))
    img = image.img_to_array(img)
    plt.imshow(img/255)
    plt.show()

# %%
### TODO: Write your algorithm.
### Feel free to use as many code cells as needed.

import numpy as np
import cv2

#Function
def predict_dog_breed_by_image(path):
    oriimage = cv2.imread(path,-1) #Takes the 
    newx,newy = 224,224 #new size (w,h)
    #Takes the original image and converts it into (224,224)
    img_path = cv2.resize(oriimage,(newx,newy))
    cv2.imwrite('test_edit.jpg',img_path)# saving the edited image as test_edit
    show_image('test_edit.jpg')
    
    
    if (face_detector(path)): #if it's a human
        print (" Image contains a human: ")
        dog_breed = Resnet50_predict_breed('test_edit.jpg')
        print (" Which looks like a : ", dog_breed )
    
    elif (dog_detector('test_edit.jpg')==1): #if it's a dog
        print("This is a dog ")
        dog_breed = Resnet50_predict_breed('test_edit.jpg')
        print (" The dog's breed is  :", dog_breed )

    else: #for something else
        print (" This is something else ")

# %% [markdown]
# ---
# <a id='step7'></a>
# ## Step 7: Test Your Algorithm
#
# In this section, you will take your new algorithm for a spin!  What kind of dog does the algorithm think that __you__ look like?  If you have a dog, does it predict your dog's breed accurately?  If you have a cat, does it mistakenly think that your cat is a dog?
#
# ### (IMPLEMENTATION) Test Your Algorithm on Sample Images!
#
# Test your algorithm at least six images on your computer.  Feel free to use any images you like.  Use at least two human and two dog images.
#
# __Question 6:__ Is the output better than you expected :) ?  Or worse :( ?  Provide at least three possible points of improvement for your algorithm.
#
# __Answer:__

# %%
## TODO: Execute your algorithm from Step 6 on
## at least 6 images on your computer.
## Feel free to use as many code cells as needed.

dog_breed = [predict_dog_breed_by_image(img) for img in sorted(glob("test_dogs/*"))]
custom_files = (list(zip(sorted(glob("test_dogs/*")), dog_breed)))

for item in custom_files:
    print("\nfile name : ", item[0])
    image_display(item[0])
    if item[1][0] == True: 
        print("Hello human, your resembling dog breed is: ", item[1][1])
    else : 
        print("Dog breed is: ", item[1][1])
# Out:
#  Hey ! This is a dog
# C:\Users\vroma\Anaconda3\envs\tensorflow\lib\site-packages\keras_applications\resnet50.py:263: UserWarning: The output shape of `ResNet50(include_top=False)` has been changed since Keras 2.2.0.
#   warnings.warn('The output shape of `ResNet50(include_top=False)` '
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-66-f39a969f4db5> in <module>()
#       3 ## Feel free to use as many code cells as needed.
#       4
# ----> 5 dog_breed = [predict_dog_breed_by_image(img) for img in sorted(glob("test_dogs/*"))]
#       6 custom_files = (list(zip(sorted(glob("test_dogs/*")), dog_breed)))
#       7
#
# <ipython-input-66-f39a969f4db5> in <listcomp>(.0)
#       3 ## Feel free to use as many code cells as needed.
#       4
# ----> 5 dog_breed = [predict_dog_breed_by_image(img) for img in sorted(glob("test_dogs/*"))]
#       6 custom_files = (list(zip(sorted(glob("test_dogs/*")), dog_breed)))
#       7
#
# <ipython-input-65-c34408c652e4> in predict_dog_breed_by_image(path)
#      22     elif (dog_detector('test_edit.jpg')==1): #if it's a dog
#      23         print(" Hey ! This is a dog ")
# ---> 24         dog_breed = Resnet50_predict_breed('test_edit.jpg')
#      25         print (" The dog's breed is  :", dog_breed )
#      26
#
# <ipython-input-63-98e32d3b6a5a> in Resnet50_predict_breed(img_path)
#       8     bottleneck_feature = extract_Resnet50(path_to_tensor(img_path))
#       9     # obtain predicted vector
# ---> 10     predicted_vector = Resnet50_model.predict(bottleneck_feature)
#      11     # return dog breed that is predicted by the model
#      12     return dog_names[np.argmax(predicted_vector)]
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\keras\engine\training.py in predict(self, x, batch_size, verbose, steps)
#    1145                              'argument.')
#    1146         # Validate user data.
# -> 1147         x, _, _ = self._standardize_user_data(x)
#    1148         if self.stateful:
#    1149             if x[0].shape[0] > batch_size and x[0].shape[0] % batch_size != 0:
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\keras\engine\training.py in _standardize_user_data(self, x, y, sample_weight, class_weight, check_array_lengths, batch_size)
#     747             feed_input_shapes,
#     748             check_batch_axis=False,  # Don't enforce the batch size.
# --> 749             exception_prefix='input')
#     750
#     751         if y is not None:
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\keras\engine\training_utils.py in standardize_input_data(data, names, shapes, check_batch_axis, exception_prefix)
#     135                             ': expected ' + names[i] + ' to have shape ' +
#     136                             str(shape) + ' but got array with shape ' +
# --> 137                             str(data_shape))
#     138     return data
#     139
#
# ValueError: Error when checking input: expected global_average_pooling2d_4_input to have shape (1, 1, 2048) but got array with shape (7, 7, 2048)

# %% [markdown]
# # Please download your notebook to submit
#
# In order to submit, please do the following:
# 1.  Download an HTML version of the notebook to your computer using 'File: Download as...'
# 2.  Click on the orange Jupyter circle on the top left of the workspace.
# 3.  Navigate into the dog-project folder to ensure that you are using the provided dog_images, lfw, and bottleneck_features folders; this means that those folders will *not* appear in the dog-project folder.  If they do appear because you downloaded them, delete them.
# 4.  While in the dog-project folder, upload the HTML version of this notebook you just downloaded.  The upload button is on the top right.
# 5.  Navigate back to the home folder by clicking on the two dots next to the folder icon, and then open up a terminal under the 'new' tab on the top right
# 6.  Zip the dog-project folder with the following command in the terminal:
#  `zip -r dog-project.zip dog-project`
# 7.  Download the zip file by clicking on the square next to it and selecting 'download'.  This will be the zip file you turn in on the next node after this workspace!
